# %%
import pandas as pd

# Adjusted to use local workspace CSV files
programs = pd.read_csv("programs.csv")
repos = pd.read_csv("repositories.csv")

# %%
iac_solutions = ["Terraform", "CDKTF", "Pulumi", "CloudFormation", "Bicep", "Ansible"]
subset = programs[programs["solution"].isin(iac_solutions)]

iac_ext = programs["directory"].str.contains(r"\.tf|cdktf\.json|Pulumi|\.bicep|\.yaml|\.yml", case=False, na=False)
subset = pd.concat([subset, programs[iac_ext]]).drop_duplicates()

merged = subset.merge(repos, left_on="repository", right_on="ID", how="left")
print("Columns:", merged.columns.tolist())
print("Shape:", merged.shape)
# Out:
# Columns: ['ID_x', 'repository', 'directory', 'solution', 'language', 'name_x', 'description_x', 'runtime', 'testing', 'tests', 'ID_y', 'url', 'downloaded', 'name_y', 'description_y', 'licenses', 'redistributable', 'created', 'updated', 'pushed', 'fork', 'forks', 'archive', 'programs']
# Shape: (13777, 24)

# %%
print(merged.columns.tolist())
# Out:
# ['ID_x', 'repository', 'directory', 'solution', 'language', 'name_x', 'description_x', 'runtime', 'testing', 'tests', 'ID_y', 'url', 'downloaded', 'name_y', 'description_y', 'licenses', 'redistributable', 'created', 'updated', 'pushed', 'fork', 'forks', 'archive', 'programs']

# %%
cleaned = merged[[
    "ID_y",        # repo ID
    "name_y",      # repo name
    "url",         # repo URL
    "directory",   # IaC folder inside repo
    "solution",
    "language"
]]

print("Cleaned shape:", cleaned.shape)
cleaned.head()
# Out:
# Cleaned shape: (13777, 6)
#         ID_y                                 name_y  \
# 0  386451159  phillipedwards/pulumi-ts-import-error
# 1  214975348                     jforge/iac-samples
# 2  457090491              eric-sherrill/ahoy-pulumi
# 3  453026331                RawkodeAcademy/platform
# 4  497668388        iac-factory/gitlab-runner-cdktf
#
#                                                  url  \
# 0  https://api.github.com/repos/phillipedwards/pu...
# 1    https://api.github.com/repos/jforge/iac-samples
# 2  https://api.github.com/repos/eric-sherrill/aho...
# 3  https://api.github.com/repos/RawkodeAcademy/pl...
# 4  https://api.github.com/repos/iac-factory/gitla...
#
#                      directory solution    language
# 0                    386451159   Pulumi  typescript
# 1  214975348/pulumi/quickstart   Pulumi  typescript
# 2                    457090491   Pulumi  typescript
# 3       453026331/src/index.ts   Pulumi  typescript
# 4              497668388/cdktf    CDKTF  typescript

# %%
import os

# Create download folder
os.makedirs("terraform_repos", exist_ok=True)

# Convert API URL → clone URL
def to_clone_url(api_url):
    return api_url.replace("api.github.com/repos", "github.com") + ".git"

# Pick first 20 repos for testing (you can increase later)
subset = cleaned.head(20)

for idx, row in subset.iterrows():
    clone_url = to_clone_url(row["url"])
    repo_name = row["name_y"].replace("/", "_")  # avoid folder conflicts
    print(f"Cloning {clone_url} into terraform_repos/{repo_name}...")
    os.system(f"git clone --depth 1 {clone_url} terraform_repos/{repo_name}")
# Out:
# Cloning https://github.com/phillipedwards/pulumi-ts-import-error.git into terraform_repos/phillipedwards_pulumi-ts-import-error...
# Cloning https://github.com/jforge/iac-samples.git into terraform_repos/jforge_iac-samples...
# Cloning https://github.com/eric-sherrill/ahoy-pulumi.git into terraform_repos/eric-sherrill_ahoy-pulumi...
# Cloning https://github.com/RawkodeAcademy/platform.git into terraform_repos/RawkodeAcademy_platform...
# Cloning https://github.com/iac-factory/gitlab-runner-cdktf.git into terraform_repos/iac-factory_gitlab-runner-cdktf...
# Cloning https://github.com/dimitor115/pulumi-instance-refresh-bug-reproduction.git into terraform_repos/dimitor115_pulumi-instance-refresh-bug-reproduction...
# Cloning https://github.com/phillipedwards/aws-ts-apigw-lambda.git into terraform_repos/phillipedwards_aws-ts-apigw-lambda...
# Cloning https://github.com/NewOrbit/ClientSideEncryption.Demo.git into terraform_repos/NewOrbit_ClientSideEncryption.Demo...
# Cloning https://github.com/ahmadalibagheri/cdktf-typescript-aws-iam.git into terraform_repos/ahmadalibagheri_cdktf-typescript-aws-iam...
# Cloning https://github.com/andrewlaskey/pulumi-example.git into terraform_repos/andrewlaskey_pulumi-example...
# Cloning https://github.com/andrewlaskey/pulumi-example.git into terraform_repos/andrewlaskey_pulumi-example...
# Cloning https://github.com/WaffleHacks/infrastructure.git into terraform_repos/WaffleHacks_infrastructure...
# Cloning https://github.com/Pocket/firefox-android-home-recommendations.git into terraform_repos/Pocket_firefox-android-home-recommendations...
# Cloning https://github.com/nojaf/ronnies.be.git into terraform_repos/nojaf_ronnies.be...
# Cloning https://github.com/wjrm500/heroku-clone.git into terraform_repos/wjrm500_heroku-clone...
# Cloning https://github.com/rohankumardubey/pulumi.git into terraform_repos/rohankumardubey_pulumi...
# Cloning https://github.com/rohankumardubey/pulumi.git into terraform_repos/rohankumardubey_pulumi...
# Cloning https://github.com/rohankumardubey/pulumi.git into terraform_repos/rohankumardubey_pulumi...
# Cloning https://github.com/rohankumardubey/pulumi.git into terraform_repos/rohankumardubey_pulumi...
# Cloning https://github.com/rohankumardubey/pulumi.git into terraform_repos/rohankumardubey_pulumi...

# %%
# If python-hcl2 is not installed, run: pip install python-hcl2

# %%
import os
import hcl2
import json

def find_iac_files(base_dir):
    iac_files = []
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(".tf") or file.endswith(".json"):
                iac_files.append(os.path.join(root, file))
    return iac_files

def parse_tf_file(file_path):
    try:
        with open(file_path, "r") as f:
            return hcl2.load(f)  # works for .tf
    except Exception:
        try:
            with open(file_path, "r") as f:
                return json.load(f)  # fallback if JSON
        except:
            return None

# Example: parse first few IaC files from cloned repos
sample_dir = "terraform_repos"
files = find_iac_files(sample_dir)
print("Found IaC files:", files[:10])

if files:
    parsed = parse_tf_file(files[0])
    print("Parsed content (sample):", parsed)
# Out:
# Found IaC files: ['terraform_repos\\ahmadalibagheri_cdktf-typescript-aws-iam\\cdktf.json', 'terraform_repos\\ahmadalibagheri_cdktf-typescript-aws-iam\\package-lock.json', 'terraform_repos\\ahmadalibagheri_cdktf-typescript-aws-iam\\package.json', 'terraform_repos\\ahmadalibagheri_cdktf-typescript-aws-iam\\tsconfig.json', 'terraform_repos\\andrewlaskey_pulumi-example\\package-lock.json', 'terraform_repos\\andrewlaskey_pulumi-example\\package.json', 'terraform_repos\\andrewlaskey_pulumi-example\\tsconfig.json', 'terraform_repos\\andrewlaskey_pulumi-example\\child-infra\\package-lock.json', 'terraform_repos\\andrewlaskey_pulumi-example\\child-infra\\package.json', 'terraform_repos\\andrewlaskey_pulumi-example\\child-infra\\tsconfig.json']
# Parsed content (sample): {'language': 'typescript', 'app': 'npx ts-node main.ts', 'projectId': 'e100a3f7-9187-4752-b3b5-9f5ef257eccd', 'terraformProviders': ['aws@~> 3.29.0'], 'terraformModules': [], 'context': {'excludeStackIdFromLogicalIds': 'true', 'allowSepCharsInLogicalIds': 'true'}}

# %%
import os
import hcl2
import json

def find_iac_files(base_dir):
    iac_files = []
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(".tf") or file == "cdktf.json" or "Pulumi" in file:
                iac_files.append(os.path.join(root, file))
    return iac_files

def parse_iac_file(file_path):
    try:
        if file_path.endswith(".tf"):
            with open(file_path, "r") as f:
                return hcl2.load(f)
        elif file_path.endswith(".json") or file_path.endswith(".yaml") or file_path.endswith(".yml"):
            with open(file_path, "r") as f:
                return json.load(f)
    except Exception as e:
        return {"error": str(e), "file": file_path}
    return None

# Example: parse IaC files
sample_dir = "terraform_repos"
files = find_iac_files(sample_dir)
print("IaC files found:", files[:10])

parsed_outputs = []
for f in files[:5]:   # try first 5
    parsed_outputs.append((f, parse_iac_file(f)))

for f, content in parsed_outputs:
    print("\nFile:", f)
    print("Parsed content (trimmed):", str(content)[:500])
# Out:
# IaC files found: ['terraform_repos\\ahmadalibagheri_cdktf-typescript-aws-iam\\cdktf.json', 'terraform_repos\\andrewlaskey_pulumi-example\\Pulumi.parent-stack.yaml', 'terraform_repos\\andrewlaskey_pulumi-example\\Pulumi.yaml', 'terraform_repos\\andrewlaskey_pulumi-example\\child-infra\\Pulumi.child-stack.yaml', 'terraform_repos\\andrewlaskey_pulumi-example\\child-infra\\Pulumi.yaml', 'terraform_repos\\dimitor115_pulumi-instance-refresh-bug-reproduction\\Pulumi.dev.yaml', 'terraform_repos\\dimitor115_pulumi-instance-refresh-bug-reproduction\\Pulumi.yaml', 'terraform_repos\\eric-sherrill_ahoy-pulumi\\Pulumi.yaml', 'terraform_repos\\iac-factory_gitlab-runner-cdktf\\cdktf\\cdktf.json', 'terraform_repos\\iac-factory_gitlab-runner-cdktf\\cdktf\\data.tf']
#
# File: terraform_repos\ahmadalibagheri_cdktf-typescript-aws-iam\cdktf.json
# Parsed content (trimmed): {'language': 'typescript', 'app': 'npx ts-node main.ts', 'projectId': 'e100a3f7-9187-4752-b3b5-9f5ef257eccd', 'terraformProviders': ['aws@~> 3.29.0'], 'terraformModules': [], 'context': {'excludeStackIdFromLogicalIds': 'true', 'allowSepCharsInLogicalIds': 'true'}}
#
# File: terraform_repos\andrewlaskey_pulumi-example\Pulumi.parent-stack.yaml
# Parsed content (trimmed): {'error': 'Expecting value: line 1 column 1 (char 0)', 'file': 'terraform_repos\\andrewlaskey_pulumi-example\\Pulumi.parent-stack.yaml'}
#
# File: terraform_repos\andrewlaskey_pulumi-example\Pulumi.yaml
# Parsed content (trimmed): {'error': 'Expecting value: line 1 column 1 (char 0)', 'file': 'terraform_repos\\andrewlaskey_pulumi-example\\Pulumi.yaml'}
#
# File: terraform_repos\andrewlaskey_pulumi-example\child-infra\Pulumi.child-stack.yaml
# Parsed content (trimmed): {'error': 'Expecting value: line 1 column 1 (char 0)', 'file': 'terraform_repos\\andrewlaskey_pulumi-example\\child-infra\\Pulumi.child-stack.yaml'}
#
# File: terraform_repos\andrewlaskey_pulumi-example\child-infra\Pulumi.yaml
# Parsed content (trimmed): {'error': 'Expecting value: line 1 column 1 (char 0)', 'file': 'terraform_repos\\andrewlaskey_pulumi-example\\child-infra\\Pulumi.yaml'}

# %%
def extract_features(parsed):
    features = {}
    if not parsed:
        return features

    # Providers
    providers = parsed.get("terraformProviders", [])
    features["num_providers"] = len(providers)
    features["providers"] = providers

    # Modules
    modules = parsed.get("terraformModules", [])
    features["num_modules"] = len(modules)
    features["modules"] = modules

    # Language
    features["language"] = parsed.get("language", "unknown")

    return features

# Run on first 5 parsed configs
for f, content in parsed_outputs:
    if content:
        feats = extract_features(content)
        print("\nFile:", f)
        print("Features:", feats)
# Out:
# File: terraform_repos\ahmadalibagheri_cdktf-typescript-aws-iam\cdktf.json
# Features: {'num_providers': 1, 'providers': ['aws@~> 3.29.0'], 'num_modules': 0, 'modules': [], 'language': 'typescript'}
#
# File: terraform_repos\andrewlaskey_pulumi-example\Pulumi.parent-stack.yaml
# Features: {'num_providers': 0, 'providers': [], 'num_modules': 0, 'modules': [], 'language': 'unknown'}
#
# File: terraform_repos\andrewlaskey_pulumi-example\Pulumi.yaml
# Features: {'num_providers': 0, 'providers': [], 'num_modules': 0, 'modules': [], 'language': 'unknown'}
#
# File: terraform_repos\andrewlaskey_pulumi-example\child-infra\Pulumi.child-stack.yaml
# Features: {'num_providers': 0, 'providers': [], 'num_modules': 0, 'modules': [], 'language': 'unknown'}
#
# File: terraform_repos\andrewlaskey_pulumi-example\child-infra\Pulumi.yaml
# Features: {'num_providers': 0, 'providers': [], 'num_modules': 0, 'modules': [], 'language': 'unknown'}

# %%
import pandas as pd

# Load metadata (local CSVs)
programs = pd.read_csv("programs.csv")
repos = pd.read_csv("repositories.csv")

# 1. Select by known IaC solutions
iac_solutions = ["Terraform", "CDKTF", "Pulumi", "CloudFormation", "Bicep", "Ansible"]
subset = programs[programs["solution"].isin(iac_solutions)]

# 2. Select by file extensions (for safety)
iac_ext = programs["directory"].str.contains(r"\.tf|cdktf\.json|Pulumi|\.bicep|\.yaml|\.yml", case=False, na=False)

# 3. Merge both and deduplicate
subset = pd.concat([subset, programs[iac_ext]]).drop_duplicates()

# 4. Merge with repos metadata
merged = subset.merge(repos, left_on="repository", right_on="ID", how="left")

# 5. Get unique repos
unique_repos = merged.drop_duplicates(subset=["repository"])
print("Unique IaC repos:", unique_repos.shape[0])

# 6. If repos < 5000, just take all
if unique_repos.shape[0] >= 5000:
    sampled_repos = unique_repos.sample(n=5000, random_state=42)
else:
    sampled_repos = unique_repos  # take all available
    print(f"Only {unique_repos.shape[0]} repos available, taking all.")

# Save list
sampled_repos[["repository", "name_y", "url", "directory"]].to_csv("iac_sampled.csv", index=False)
print("Saved sampled repo list to iac_sampled.csv")
# Out:
# Unique IaC repos: 3885
# Only 3885 repos available, taking all.
# Saved sampled repo list to iac_sampled.csv

# %%
print(unique_repos["solution"].value_counts())
# Out:
# solution
# Pulumi    3366
# CDKTF      519
# Name: count, dtype: int64

# %%
import os, subprocess, pandas as pd

# Load repo list
repos = pd.read_csv("iac_sampled.csv")

# Create folder for clones
os.makedirs("iac_repos", exist_ok=True)

# Clone first 50 repos as a test (safe for Review-2)
for i, row in repos.head(50).iterrows():
    repo_url = row["url"].replace("api.github.com/repos", "github.com")  # fix API → git URL
    repo_name = row["name_y"].replace("/", "_")
    target_dir = f"iac_repos/{repo_name}"

    if not os.path.exists(target_dir):
        try:
            print(f"Cloning {repo_url}...")
            subprocess.run(["git", "clone", repo_url, target_dir], check=True)
        except Exception as e:
            print(f"Failed {repo_url}: {e}")
# Out:
# Cloning https://github.com/RawkodeAcademy/platform...
# Failed https://github.com/RawkodeAcademy/platform: Command '['git', 'clone', 'https://github.com/RawkodeAcademy/platform', 'iac_repos/RawkodeAcademy_platform']' returned non-zero exit status 128.
# Cloning https://github.com/JIO93/Programming-With-Python-For-DevOps-Engineers-Bootcamp...
# Failed https://github.com/JIO93/Programming-With-Python-For-DevOps-Engineers-Bootcamp: Command '['git', 'clone', 'https://github.com/JIO93/Programming-With-Python-For-DevOps-Engineers-Bootcamp', 'iac_repos/JIO93_Programming-With-Python-For-DevOps-Engineers-Bootcamp']' returned non-zero exit status 128.
# Cloning https://github.com/nyamada43/demoPulumi...
# Failed https://github.com/nyamada43/demoPulumi: Command '['git', 'clone', 'https://github.com/nyamada43/demoPulumi', 'iac_repos/nyamada43_demoPulumi']' returned non-zero exit status 128.

# %%
import os, subprocess, pandas as pd, time

# Load repo list (already filtered IaC repos)
repos = pd.read_csv("iac_sampled.csv")

# Create folder to store repos
os.makedirs("iac_repos", exist_ok=True)

# Define the clone function again
def clone_repo(url, name):
    repo_url = url.replace("api.github.com/repos", "github.com")
    target_dir = f"iac_repos/{name.replace('/', '_')}"
    if os.path.exists(target_dir):
        print(f"Already exists: {name}")
        return

    try:
        print(f"Cloning {repo_url}...")
        subprocess.run(
            ["git", "clone", "--depth", "1", repo_url, target_dir],
            check=True
        )
    except Exception as e:
        print(f"Failed {repo_url}: {e}")

# Batch clone only 1000 repos (safe for Review 2)
for i, row in repos.iloc[:1000].iterrows():
    clone_repo(row["url"], row["name_y"])

    if i % 200 == 0 and i > 0:
        print("Pausing to avoid GitHub block...")
        time.sleep(60)  # 1 min pause every 200 repos
# Out:
# Already exists: phillipedwards/pulumi-ts-import-error
# Already exists: jforge/iac-samples
# Already exists: eric-sherrill/ahoy-pulumi
# Cloning https://github.com/RawkodeAcademy/platform...
# Failed https://github.com/RawkodeAcademy/platform: Command '['git', 'clone', '--depth', '1', 'https://github.com/RawkodeAcademy/platform', 'iac_repos/RawkodeAcademy_platform']' returned non-zero exit status 128.
# Already exists: iac-factory/gitlab-runner-cdktf
# Already exists: dimitor115/pulumi-instance-refresh-bug-reproduction
# Already exists: phillipedwards/aws-ts-apigw-lambda
# Already exists: NewOrbit/ClientSideEncryption.Demo
# Already exists: ahmadalibagheri/cdktf-typescript-aws-iam
# Already exists: andrewlaskey/pulumi-example
# Already exists: WaffleHacks/infrastructure
# Already exists: Pocket/firefox-android-home-recommendations
# Already exists: nojaf/ronnies.be
# Already exists: wjrm500/heroku-clone
# Already exists: rohankumardubey/pulumi
# Already exists: alek29c/tf
# Already exists: AdminTurnedDevOps/Live-Sessions-And-Conferences
# Already exists: andrekiba/FantasticBike
# Already exists: PHONGLEX/fastapi_pulumi_practice
# Already exists: cyrano5614/pulumi-gcp-network
# Already exists: hossambarakat/pulumi-demos
# Already exists: efleming18/pulumi-examples
# Already exists: GeertVL-zz/eventgrid1
# Already exists: ths83/pulumi-tutorials
# Already exists: uncefact/project-traceability
# Already exists: raeffs/ffhs-cas-acc-containers
# Already exists: fedemarchini/TestGitActions
# Already exists: dnhook123/dsfasdfasdfadsf
# Already exists: erpujabaidya/typescript
# Already exists: pulumi/pulumi-openfaas
# Already exists: Trojan295/pulumi-poc
# Already exists: sacloud/pulumi-sakuracloud
# Already exists: bloominlabs/baseplate-go
# Already exists: eladrapoportcybr/TerraformCdkNotesDemo
# Already exists: cunningj/pulumi_aws_basic
# Already exists: demiban/pulumi-localstack-lambda-example
# Cloning https://github.com/JIO93/Programming-With-Python-For-DevOps-Engineers-Bootcamp...
# Failed https://github.com/JIO93/Programming-With-Python-For-DevOps-Engineers-Bootcamp: Command '['git', 'clone', '--depth', '1', 'https://github.com/JIO93/Programming-With-Python-For-DevOps-Engineers-Bootcamp', 'iac_repos/JIO93_Programming-With-Python-For-DevOps-Engineers-Bootcamp']' returned non-zero exit status 128.
# Already exists: matrixbegins/uni-demo-deploy
# Already exists: Shyam-Chen/Micro-Fullstack
# Already exists: jaxxstorm/pulumi-automationapi-workshop
# Already exists: cloudspeak/pulumi-lambda-efs
# Already exists: aeons/aeons.dk
# Already exists: mitodl/ol-infrastructure
# Already exists: just-run-my/app-azure-edition
# Cloning https://github.com/nyamada43/demoPulumi...
# Failed https://github.com/nyamada43/demoPulumi: Command '['git', 'clone', '--depth', '1', 'https://github.com/nyamada43/demoPulumi', 'iac_repos/nyamada43_demoPulumi']' returned non-zero exit status 128.
# Already exists: skorfmann/cdktf-provider-aws
# Already exists: pulumi/pulumi-azure-quickstart-compute
# Already exists: joeduffy/pulumi-awsvpc
# Already exists: pulumi/pulumi-mailgun
# Already exists: melihyazgan/IaC_pipeline
# Already exists: EwanNoble/AppCatalog
# Already exists: ikovac/pulumi-workshop-1
# Already exists: nmora53/async-power-dialer-stone-poc
# Already exists: artcoded-net/vendure-pulumi-gcp
# Already exists: hmix/try-terraform-cdk-python
# Already exists: jessicaUP/CloudVisitCount
# Cloning https://github.com/strongishllama/cdktf-constructs...
# Failed https://github.com/strongishllama/cdktf-constructs: Command '['git', 'clone', '--depth', '1', 'https://github.com/strongishllama/cdktf-constructs', 'iac_repos/strongishllama_cdktf-constructs']' returned non-zero exit status 128.
# Already exists: pulumi/pulumi-mysql
# Already exists: brightsole/solosis
# Already exists: L0ndra/pulumi-do-ddos
# Already exists: neilkuan/pulumi-cdk-example
# Cloning https://github.com/somandr/ISaC...
# Failed https://github.com/somandr/ISaC: Command '['git', 'clone', '--depth', '1', 'https://github.com/somandr/ISaC', 'iac_repos/somandr_ISaC']' returned non-zero exit status 128.
# Already exists: einfachnuralex/gdeploy
# Already exists: abatilo/grpc-timeout-repro
# Already exists: korosuke613/playground
# Already exists: BelRarr/confoo2022-iac4devs
# Already exists: devopsjourney1/pulumi-helloworld
# Already exists: lmayorga1980/gcp-cdktf-example
# Already exists: DanielMSchmidt/cdktf-multi-stack-tfe
# Already exists: alfredoem/pulumi-js-aws-example
# Already exists: paiml/python_devops_book
# Already exists: nicholas-yong/Personal-Website
# Already exists: Tirke/try-pulumi
# Already exists: blakegreendev/pulumi-aws-django-voting-app
# Already exists: cloudreach/urly-wurly
# Already exists: Lonero-Team/Decentralized-Internet
# Already exists: SamEdwardes/rstudio-team-pulumi-recipes
# Already exists: tyrchen/pulumi-examples
# Already exists: gbaeke/pulumi-samples
# Cloning https://github.com/poikaa/iac-research...
# Failed https://github.com/poikaa/iac-research: Command '['git', 'clone', '--depth', '1', 'https://github.com/poikaa/iac-research', 'iac_repos/poikaa_iac-research']' returned non-zero exit status 128.
# Already exists: amielkov/test-pulumi
# Already exists: dahendel/pulumi-vsphere-k3s
# Cloning https://github.com/Nolan01m/CI-Project-CCDC...
# Failed https://github.com/Nolan01m/CI-Project-CCDC: Command '['git', 'clone', '--depth', '1', 'https://github.com/Nolan01m/CI-Project-CCDC', 'iac_repos/Nolan01m_CI-Project-CCDC']' returned non-zero exit status 128.
# Already exists: amkul99/pulumi-fargate
# Already exists: cmatskas/pulumi-aad-demo
# Already exists: mizzy/pulumi-playground
# Already exists: cfeenstra67/egghead
# Already exists: yoshieki1992-wk/gke
# Already exists: serverless-architecture/reference-architectures
# Already exists: jaxxstorm/pulumi-productionapp
# Already exists: nullify005/HomeAssistant
# Already exists: jslopeza/nx-cdktf-sls-experiment
# Already exists: AI2Incubator/AI2I_streamlitapp
# Cloning https://github.com/alisavch/iac-image-service...
# Failed https://github.com/alisavch/iac-image-service: Command '['git', 'clone', '--depth', '1', 'https://github.com/alisavch/iac-image-service', 'iac_repos/alisavch_iac-image-service']' returned non-zero exit status 128.
# Already exists: wrasdf/pulumi-world
# Already exists: wongcyrus/AzureCloudLabEnvironment
# Already exists: GopinathYadavAR/pulumi-workshop
# Cloning https://github.com/zhifanz/fanqiang-pulumi-python...
# Failed https://github.com/zhifanz/fanqiang-pulumi-python: Command '['git', 'clone', '--depth', '1', 'https://github.com/zhifanz/fanqiang-pulumi-python', 'iac_repos/zhifanz_fanqiang-pulumi-python']' returned non-zero exit status 128.
# Already exists: earafat-oak9/sample-terraform
# Already exists: NorthStNetworking/NorthStNetworking
# Already exists: pulumi/pulumi-policy-opa
# Already exists: displague/pulumi-linode-webserver-ts
# Already exists: mtrcn/georchestrator
# Already exists: wallabyjs/wallaby-pulumi
# Already exists: staslebedenko/perfect-infra-via-pulumi
# Already exists: Silver-birder/social-trend
# Already exists: pulumi-in-action/website
# Already exists: goldoneen/nft-marketplace
# Already exists: staeff/aws-infra
# Already exists: clstokes/pulumi-aws-ts-ecs-existing-vpc
# Cloning https://github.com/rmavuluri/terraform-docker...
# Failed https://github.com/rmavuluri/terraform-docker: Command '['git', 'clone', '--depth', '1', 'https://github.com/rmavuluri/terraform-docker', 'iac_repos/rmavuluri_terraform-docker']' returned non-zero exit status 128.
# Cloning https://github.com/swapnilmmane/ecommerce...
# Failed https://github.com/swapnilmmane/ecommerce: Command '['git', 'clone', '--depth', '1', 'https://github.com/swapnilmmane/ecommerce', 'iac_repos/swapnilmmane_ecommerce']' returned non-zero exit status 128.
# Already exists: WaryArchanid/Events
# Already exists: petabridge/AkkaDotNet.LargeNetworkTests
# Already exists: sturlath/MyTest
# Already exists: gmiretti/pulumi-aws-py-lambda-api-gateway-ecache
# Already exists: sdrush-mw/sr-cdktf-test
# Cloning https://github.com/slimdevl/pulumi-ssm-example...
# Failed https://github.com/slimdevl/pulumi-ssm-example: Command '['git', 'clone', '--depth', '1', 'https://github.com/slimdevl/pulumi-ssm-example', 'iac_repos/slimdevl_pulumi-ssm-example']' returned non-zero exit status 128.
# Already exists: jtrinklein/trinkle.in-site
# Already exists: codedevote/spartakiade2021-pulumi
# Already exists: azul915/cron-serverless-pulumi
# Already exists: Mauwii/azure-pipelines-with-github-repo
# Already exists: pulumi/pulumi-aiven
# Already exists: rjha0720/cdkterraform
# Already exists: state-alchemists/zaruba
# Already exists: hesbon-osoro/pulumi-gcp
# Already exists: pulumi/pulumi-databricks
# Already exists: shtakai/poc-pulumi-aws
# Cloning https://github.com/devnullroots/k3d_playground...
# Failed https://github.com/devnullroots/k3d_playground: Command '['git', 'clone', '--depth', '1', 'https://github.com/devnullroots/k3d_playground', 'iac_repos/devnullroots_k3d_playground']' returned non-zero exit status 128.
# Already exists: ServiTrace/ReplicationPackage
# Already exists: xai1983kbu/pulumi_appsync_with_direct_lambda_to_dynamodb
# Already exists: redhwannacef/youtube-tutorials
# Already exists: wanghao1891/sample
# Cloning https://github.com/dhairya137/heroku-clone...
# Failed https://github.com/dhairya137/heroku-clone: Command '['git', 'clone', '--depth', '1', 'https://github.com/dhairya137/heroku-clone', 'iac_repos/dhairya137_heroku-clone']' returned non-zero exit status 128.
# Already exists: sankarpa/iac
# Already exists: danieldspx/pulumi-ecs-example
# Already exists: benesch/pulumi-bug-eks
# Already exists: cpayret-KDM/KDM_API
# Already exists: neilkuan/cdk-terraform-aws-ecs-fargate
# Already exists: luizhlelis/auth0-IaC
# Already exists: blakegreendev/pulumi-lambda-workshop
# Already exists: c0bra/github-repo-freshness-api
# Already exists: joeduffy/pk8syaml
# Already exists: dirien/digitalocean-kubernetes-challenge
# Already exists: alexhwoods/super-pulumi
# Already exists: robertkotcher/robertkotcher.github.io
# Already exists: Kannakattisanjana/IRA-Arrant
# Already exists: sammck/apihub
# Already exists: janfabian/offtopic-slack-bot
# Already exists: sgrade/pulumi
# Already exists: SzymonSmykala/Pulumi-micro-stacks-csharp
# Already exists: squaremo/pulumi-ociregistry-provider
# Already exists: Mattaparthi321/my-teraform-code
# Already exists: jbogard/AzureMessagingServices
# Already exists: smartcontractkit/chainlink-solana
# Already exists: scrthq/js-aks-test
# Already exists: spaceoddite/pulumi-component-provider-py-boilerplate
# Already exists: squaremo/pulumi-localprocess
# Cloning https://github.com/NovatecConsulting/dot-translathor...
# Failed https://github.com/NovatecConsulting/dot-translathor: Command '['git', 'clone', '--depth', '1', 'https://github.com/NovatecConsulting/dot-translathor', 'iac_repos/NovatecConsulting_dot-translathor']' returned non-zero exit status 128.
# Already exists: rarous/rarousnet
# Already exists: CharlieDigital/dn6-mongo-react-valtio
# Already exists: wyx2014/yb.dev
# Already exists: scaffold-sh/aws-serverless-docker
# Already exists: levankhelo/pullantis
# Already exists: henriklagergren/azure-trigger-benchmark
# Already exists: Shatabdi2621/AzureResource---Pulumi
# Already exists: andrekiba/CrazyBike
# Already exists: ChristoMI/Web_Backend
# Already exists: pulumiverse/pulumi-aws-eksa
# Already exists: Nav-app/pulumiAwsS3LambdaDynamoDB
# Already exists: L03TJ3/gd-gc-hc
# Already exists: skill-collectors/agile-poker
# Already exists: mysticrenji/pulumi-yaml
# Already exists: pulumi/pulumi-snowflake
# Already exists: goawsgo/aws-ekk-pulumi
# Already exists: mskutin/lambda-nodejs-16
# Already exists: romcheck/pulumi-stackgres
# Already exists: StupidHackTH/stupid-hack-5-api-challenge
# Already exists: koffe0522/cdktf-templates
# Already exists: pulumi/actions-example-gke-rails
# Already exists: pulumi/automation-api-examples
# Already exists: hryang/pulumi-jenkins-example
# Already exists: tinkerbell/infrastructure
# Already exists: vetorsilence/website
# Cloning https://github.com/sol-eng/pulumi-recipes...
# Failed https://github.com/sol-eng/pulumi-recipes: Command '['git', 'clone', '--depth', '1', 'https://github.com/sol-eng/pulumi-recipes', 'iac_repos/sol-eng_pulumi-recipes']' returned non-zero exit status 128.
# Already exists: blakegreendev/vscode-fargate-pulumi
# Already exists: pulumi/pulumi-dnsimple
# Already exists: wgarcia79/pulumi-aws
# Already exists: DavidLeong98/pulumi
# Already exists: eesvara5512/terraform-samples
# Already exists: DanielMSchmidt/terraform-cdk-terraform-module-publishing-on-gh-packages
# Already exists: ahmadalibagheri/cdktf-typescript-aws-vpc
# Already exists: lwooden/sample-node-api-service
# Already exists: yanniz0r/sonq
# Already exists: CerusBots/website
# Already exists: ptavoni/forgeops
# Already exists: cobraz/pulumi-wordpress
# Already exists: vincetiu8/ee-project
# Already exists: nukdcbear/Pulumi-Python-AWS-VPC-EC2
# Already exists: aureq/pulumi-aws-ts-training-session-3
# Already exists: AustinWise/GrpcMicroservicesOnGoogleCloudRun
# Pausing to avoid GitHub block...
# Already exists: fjfdepedro/aws-pulumi-ror
# Already exists: shabados/viewer
# Already exists: whs-dot-hk/cdktf-test
# Already exists: AaronFriel/awsx-fargate-deps
# Already exists: quebic-source/aws-data-migration
# Already exists: phillipedwards/aws-plugin-issue
# Already exists: perlin-network/perlinx-dashboard
# Already exists: paulrobello/localstack-lambda-layer-bug
# Already exists: pulumi/pulumi-yaml
# Already exists: ramyaparthiban31/lender
# Already exists: pulumi/pulumi-hcloud
# Already exists: ReviakinAleksey/ls-example
# Already exists: ahmadalibagheri/cdktf-typescript-aws-ec2
# Already exists: spaceoddite/pulumi-azure-vm-component-resource-python
# Already exists: Othello1111/Decentralized_Internet
# Already exists: LachlanStevens/UntitledStack-3
# Already exists: dave-burke/rpn-calc
# Already exists: icgam/Pulumi.Samples
# Already exists: shazi7804/cdktf-samples-python
# Already exists: ksivamuthu/eks-pulumi-demo
# Already exists: ntonjeta/pulumi_integration_examples
# Already exists: pulumi/pulumi
# Already exists: ansgarm/cdktf-github-duty
# Already exists: recumbent/ddd-2020
# Already exists: rishirajbansal/Pulumi-IaC-Integrations-Automation
# Already exists: JustDjames/Go_api
# Already exists: rayct/herocool
# Already exists: pierskarsenbarg/pulumi-ts-entrypoint-demo
# Already exists: asynchronous-dev/pulumi-github-builder
# Already exists: timmyers/nirvana
# Already exists: go-sari/sari
# Already exists: pulumi/pulumi-azure-native
# Already exists: lindydonna/velocity-examples
# Already exists: gkonc001/pulumi-python-pmi
# Already exists: shanurrahman/aws_custom_infra_files
# Already exists: goawsgo/aws-cloud-edge-pulumi
# Already exists: vizv-pulumi/module-metallb
# Cloning https://github.com/pahud/cdktf-aws-eks...
# Failed https://github.com/pahud/cdktf-aws-eks: Command '['git', 'clone', '--depth', '1', 'https://github.com/pahud/cdktf-aws-eks', 'iac_repos/pahud_cdktf-aws-eks']' returned non-zero exit status 128.
# Already exists: jaxxstorm/brig.gs
# Already exists: BITOCTA/diagrams-article-example
# Already exists: tmeadon/clippings
# Cloning https://github.com/ysmoradi/Bit.TodoTemplatePlayground...
# Failed https://github.com/ysmoradi/Bit.TodoTemplatePlayground: Command '['git', 'clone', '--depth', '1', 'https://github.com/ysmoradi/Bit.TodoTemplatePlayground', 'iac_repos/ysmoradi_Bit.TodoTemplatePlayground']' returned non-zero exit status 128.
# Already exists: sasidiropoulos/market
# Cloning https://github.com/endymion1818/quantumleap-online...
# Failed https://github.com/endymion1818/quantumleap-online: Command '['git', 'clone', '--depth', '1', 'https://github.com/endymion1818/quantumleap-online', 'iac_repos/endymion1818_quantumleap-online']' returned non-zero exit status 128.
# Cloning https://github.com/ChanghoonHyun/cdktf-example...
# Cloning https://github.com/harrismcc/monorepo-starter...
# Cloning https://github.com/Welsh-Boogie/jkdkajsdnkkkpmplkqwe...
# Cloning https://github.com/phanimullapudi/pulumi-learning...
# Cloning https://github.com/noemiko/iac_examples...
# Cloning https://github.com/kaiquelupo/preview-dialer...
# Cloning https://github.com/dgg32/pulumi_quickstart...
# Cloning https://github.com/bencematyasi/nginx-aws-demo...
# Cloning https://github.com/simonzhow/hello-pulumi...
# Cloning https://github.com/provenian/judge...
# Cloning https://github.com/pulumi/qcon-workshop...
# Cloning https://github.com/fuluteam/honeycomb...
# Cloning https://github.com/cveld/pulumi-tester...
# Cloning https://github.com/vaspoz/pgadmin-aws...
# Cloning https://github.com/thakkaryash94/terraform-cdk-react-example...
# Cloning https://github.com/jjgrinwis/pulumi-property...
# Cloning https://github.com/davidNHK/project-bootstrap...
# Cloning https://github.com/gravitee-io/gravitee-fargate...
# Failed https://github.com/gravitee-io/gravitee-fargate: Command '['git', 'clone', '--depth', '1', 'https://github.com/gravitee-io/gravitee-fargate', 'iac_repos/gravitee-io_gravitee-fargate']' returned non-zero exit status 128.
# Cloning https://github.com/jsdeveloperpro/nextjs-gcp-storage...
# Cloning https://github.com/jaxxstorm/pulumi-secure-eks-workloads...
# Cloning https://github.com/steinko/AIMTutorial...
# Cloning https://github.com/ddunkin/pulumi-docker...
# Cloning https://github.com/pulumi/pulumi-azure-quickstart-acr-geo-replication...
# Cloning https://github.com/BoredTweak/Miscellaneous...
# Cloning https://github.com/yyvess/kubpoc...
# Cloning https://github.com/zack-schrag/snap-secret...
# Cloning https://github.com/Vake93/cca.server...
# Cloning https://github.com/gobengo/activitypub.com...
# Cloning https://github.com/LeonidChetverikov/pulumi...
# Cloning https://github.com/mikhailshilkov/fsharp-advent-pulumi...
# Cloning https://github.com/cheab-org/infra...
# Cloning https://github.com/defn/cdktf-provider-cloudflare...
# Failed https://github.com/defn/cdktf-provider-cloudflare: Command '['git', 'clone', '--depth', '1', 'https://github.com/defn/cdktf-provider-cloudflare', 'iac_repos/defn_cdktf-provider-cloudflare']' returned non-zero exit status 128.
# Cloning https://github.com/ameiji/pulumi-demo...
# Failed https://github.com/ameiji/pulumi-demo: Command '['git', 'clone', '--depth', '1', 'https://github.com/ameiji/pulumi-demo', 'iac_repos/ameiji_pulumi-demo']' returned non-zero exit status 128.
# Cloning https://github.com/elbetasal/app-playground...
# Cloning https://github.com/shraddhamkandpal/healthrecord-verifier...
# Cloning https://github.com/cloudvietnam18/git-pulumi...
# Cloning https://github.com/phillipedwards/azure-dashboard-error...
# Cloning https://github.com/dailydotdev/daily-monetization...
# Cloning https://github.com/clstokes/example-multicloud-webserver...
# Cloning https://github.com/lakindu2002/pulumi-micro-stacks...
# Cloning https://github.com/ederst/pulumi-in-a-pickle...
# Cloning https://github.com/Pocket/curated-corpus-api...
# Cloning https://github.com/gabrielstellini/pulumi-playground...
# Cloning https://github.com/Pjatac/KubTest...
# Cloning https://github.com/s1ntaxe770r/do-pl-k8s...
# Cloning https://github.com/tonskey/my-instagram-web...
# Failed https://github.com/tonskey/my-instagram-web: Command '['git', 'clone', '--depth', '1', 'https://github.com/tonskey/my-instagram-web', 'iac_repos/tonskey_my-instagram-web']' returned non-zero exit status 128.
# Cloning https://github.com/jeanpaulsmit/blog-posts...
# Cloning https://github.com/foundry-infra/foundry-infra-cs...
# Cloning https://github.com/dixler/jdconf-2022-platform-stack...
# Cloning https://github.com/RichardWLaub/pulumi-repro...
# Cloning https://github.com/sarwe100/dotnetprod...
# Cloning https://github.com/unmango/safir-infra...
# Cloning https://github.com/swgillespie/dockercon18...
# Cloning https://github.com/macneib/cicd...
# Cloning https://github.com/canveshh1/eks-01...
# Cloning https://github.com/nszaaa3/shididev.com...
# Cloning https://github.com/aaronaddleman/cdktf-typescript-docker...
# Cloning https://github.com/rumsrami/drone-ecs...
# Cloning https://github.com/jaxxstorm/containers-from-the-couch...
# Cloning https://github.com/iiglesiasg/elastic-pulumi...
# Cloning https://github.com/byhbt/cdktf-python...
# Cloning https://github.com/natmarek/cdktf-learning...
# Cloning https://github.com/pedramha/cdktf-azureappservice...
# Cloning https://github.com/cpaton/aws-configuration...
# Cloning https://github.com/creatorsgarten/configuration...
# Cloning https://github.com/exobase-inc/exobase-stack-builders...
# Cloning https://github.com/DanManson/gcp.iamCustomRole...
# Cloning https://github.com/codegram/pulumi-dnsimple...
# Cloning https://github.com/eminetto/post-pulumi...
# Cloning https://github.com/philjhale/pulumi-gcp...
# Cloning https://github.com/JulesP96/Sample-Pulumi...
# Cloning https://github.com/camilovarela/jenkins-test...
# Cloning https://github.com/MitchellGerdisch/pulumi-codefresh...
# Cloning https://github.com/unmango/pulumi-homelab...
# Cloning https://github.com/martinjt/pulumi-dotnet5...
# Cloning https://github.com/codegram/regalocal...
# Cloning https://github.com/DanielMSchmidt/cdktf-github-actions-local-demo...
# Cloning https://github.com/David-VTUK/pulumi-rancher-demos...
# Cloning https://github.com/gs-gs/pulumi-library...
# Cloning https://github.com/dvargas92495/terraform-aws-clerk...
# Cloning https://github.com/verygoodsoftwareorg/PulumiReactSSRExample...
# Failed https://github.com/verygoodsoftwareorg/PulumiReactSSRExample: Command '['git', 'clone', '--depth', '1', 'https://github.com/verygoodsoftwareorg/PulumiReactSSRExample', 'iac_repos/verygoodsoftwareorg_PulumiReactSSRExample']' returned non-zero exit status 128.
# Cloning https://github.com/mikhailshilkov/fosdem2019...
# Cloning https://github.com/mattstratton/awesome-azure...
# Cloning https://github.com/CliffJumper/pulumi-py-tf2-server...
# Cloning https://github.com/ryuheechul/tf-cloud...
# Cloning https://github.com/kenshoo/devops-bot...
# Failed https://github.com/kenshoo/devops-bot: Command '['git', 'clone', '--depth', '1', 'https://github.com/kenshoo/devops-bot', 'iac_repos/kenshoo_devops-bot']' returned non-zero exit status 128.
# Cloning https://github.com/ikedaosushi/python-sandbox...
# Failed https://github.com/ikedaosushi/python-sandbox: Command '['git', 'clone', '--depth', '1', 'https://github.com/ikedaosushi/python-sandbox', 'iac_repos/ikedaosushi_python-sandbox']' returned non-zero exit status 128.
# Cloning https://github.com/kmkatsma/pulumi-az-xwalk...
# Cloning https://github.com/markeytos/PulumiAzureSample...
# Cloning https://github.com/Aletrevi/Postchain...
# Cloning https://github.com/Bharathkumarraju/gcp_for_fun...
# Cloning https://github.com/swapnilmmane/cicd...
# Cloning https://github.com/roylee0704/hello-webiny...
# Cloning https://github.com/codegram/dashy...
# Cloning https://github.com/ringge/DevSecOps...
# Cloning https://github.com/ever-co/dev-pulumi...
# Cloning https://github.com/nmora53/PowerDialer_quero_educ...
# Cloning https://github.com/yoshikyoto/cdktf-sample-app...
# Cloning https://github.com/davetrainer/api-container-app...
# Cloning https://github.com/blampe/rocketpool-pulumi...
# Cloning https://github.com/anandvimal/pulumi-examples...
# Cloning https://github.com/epomatti/az-static-webapps-pulumi...
# Cloning https://github.com/adekoyadapo/managed-k8s...
# Cloning https://github.com/OctopusSamples/pulumi-python-azure...
# Cloning https://github.com/pulumi/pulumi-rke...
# Cloning https://github.com/RainRush/generator-react-ci-iac...
# Cloning https://github.com/dgg32/ncbi-taxonomy-pulumi...
# Cloning https://github.com/soulasvalentin/pulumi-poc...
# Cloning https://github.com/kksudo/devoops-cdktf...
# Cloning https://github.com/JakeGinnivan/pulumi-ecs-debugging...
# Cloning https://github.com/jdwelch/examples...
# Cloning https://github.com/leapingbytes/kenesis-or-bust...
# Cloning https://github.com/ShengzhenFu/azure-pulumi-demo...
# Cloning https://github.com/chrsmith/pulumi-aws-travis-cicd-demo...
# Cloning https://github.com/acald-creator/deploy-sigstore-gcp...
# Failed https://github.com/acald-creator/deploy-sigstore-gcp: Command '['git', 'clone', '--depth', '1', 'https://github.com/acald-creator/deploy-sigstore-gcp', 'iac_repos/acald-creator_deploy-sigstore-gcp']' returned non-zero exit status 128.
# Cloning https://github.com/krsche/scratchpad...
# Cloning https://github.com/AaronFriel/awsx-example...
# Cloning https://github.com/janegilring/pspulumidemo...
# Cloning https://github.com/clstokes/pulumi-policy-aws-iam-accessanalyzer...
# Cloning https://github.com/pavan8855/enthire...
# Cloning https://github.com/etherdata-blockchain/config...
# Cloning https://github.com/chrisguest75/terraform_examples...
# Cloning https://github.com/aochagavia/buy-me-a-beer...
# Failed https://github.com/aochagavia/buy-me-a-beer: Command '['git', 'clone', '--depth', '1', 'https://github.com/aochagavia/buy-me-a-beer', 'iac_repos/aochagavia_buy-me-a-beer']' returned non-zero exit status 128.
# Cloning https://github.com/wwt/pulumi-templates...
# Cloning https://github.com/lordabhi1/cdk-for-terraform...
# Cloning https://github.com/hpcjmart/ejemplo_1...
# Cloning https://github.com/Yarel/IaC-with-Pulumi...
# Cloning https://github.com/marcindulak/azure-ml-aks-intro...
# Cloning https://github.com/decentraland/documentation...
# Cloning https://github.com/Kurabu-chan/Kurabu...
# Cloning https://github.com/Eric-Swiftly/PulumiCDNEndpointIssue...
# Cloning https://github.com/muellermatthias/blog-pulumi-modules...
# Cloning https://github.com/RahulMR42/oci-pulumi-java-objectstore...
# Cloning https://github.com/stack72/aws-stackreference-architecture...
# Cloning https://github.com/justinvp/templates...
# Cloning https://github.com/pg94au/TerraformGoal...
# Cloning https://github.com/ihoro-epam/cloudx-aws...
# Cloning https://github.com/mpnsk/xingedin...
# Cloning https://github.com/jstans/kubernetes-dashboard...
# Cloning https://github.com/abvijaykumar/contactlist-blog-infra...
# Cloning https://github.com/AlfredoPardo-zz/python-for-devsecops...
# Cloning https://github.com/mastoj/sweetspot...
# Cloning https://github.com/pierskarsenbarg/static-website-component...
# Cloning https://github.com/peytoncasper/tf-cdk-examples...
# Cloning https://github.com/DanielMSchmidt/cdktf-aws-networking-demo...
# Cloning https://github.com/FriendlyUser/stock-pulumi...
# Cloning https://github.com/discovery-chander/pulumi...
# Cloning https://github.com/imod/azure-nextgen-migration...
# Cloning https://github.com/lolverae/azure-infra-with-pulumi...
# Failed https://github.com/lolverae/azure-infra-with-pulumi: Command '['git', 'clone', '--depth', '1', 'https://github.com/lolverae/azure-infra-with-pulumi', 'iac_repos/lolverae_azure-infra-with-pulumi']' returned non-zero exit status 128.
# Cloning https://github.com/rv-terraform/cdktf-test...
# Cloning https://github.com/MarcinGadz/iaac-comparision...
# Cloning https://github.com/stack72/pulumi-gitlab-runner...
# Cloning https://github.com/sammck/cloud-dev-box...
# Cloning https://github.com/twilio-infra-as-code/taskrouter-contact-center...
# Cloning https://github.com/hashicorp/cdktf-provider-random...
# Cloning https://github.com/DevOpsRandD/iac_cdk_pulumi_terraform...
# Pausing to avoid GitHub block...
# Cloning https://github.com/vumdao/aws-guardduty-sechub...
# Cloning https://github.com/shabados/infrastructure...
# Cloning https://github.com/nidhiben/terraform-typescript...
# Cloning https://github.com/s4nchez/storage-example...
# Cloning https://github.com/ludesdeveloper/pulumi-managed-nodes-autoscale-eks...
# Cloning https://github.com/fsainovich/tcb-azure-m6...
# Cloning https://github.com/jguadagno/jjgnet-broadcast...
# Cloning https://github.com/khaiyik2612/PulumiCICS...
# Failed https://github.com/khaiyik2612/PulumiCICS: Command '['git', 'clone', '--depth', '1', 'https://github.com/khaiyik2612/PulumiCICS', 'iac_repos/khaiyik2612_PulumiCICS']' returned non-zero exit status 128.
# Cloning https://github.com/milanpollock/dark-rush-photography...
# Cloning https://github.com/Kapernikov/skaffold-helm-tutorial...
# Cloning https://github.com/Pocket/recommendation-api...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 28
#      26 # Batch clone only 1000 repos (safe for Review 2)
#      27 for i, row in repos.iloc[:1000].iterrows():
# ---> 28     clone_repo(row["url"], row["name_y"])
#      30     if i % 200 == 0 and i > 0:
#      31         print("Pausing to avoid GitHub block...")
#
# Cell In[13], line 19, in clone_repo(url, name)
#      17 try:
#      18     print(f"Cloning {repo_url}...")
# ---> 19     subprocess.run(
#      20         ["git", "clone", "--depth", "1", repo_url, target_dir],
#      21         check=True
#      22     )
#      23 except Exception as e:
#      24     print(f"Failed {repo_url}: {e}")
#
# File C:\Program Files\Python311\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File C:\Program Files\Python311\Lib\subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File C:\Program Files\Python311\Lib\subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File C:\Program Files\Python311\Lib\subprocess.py:1588, in Popen._wait(self, timeout)
#    1585     timeout_millis = int(timeout * 1000)
#    1586 if self.returncode is None:
#    1587     # API note: Returns immediately if timeout_millis == 0.
# -> 1588     result = _winapi.WaitForSingleObject(self._handle,
#    1589                                          timeout_millis)
#    1590     if result == _winapi.WAIT_TIMEOUT:
#    1591         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:

# %%
import shutil, os

base = "iac_repos"
remove_dirs = ["node_modules", ".git", "vendor", "__pycache__"]

for repo in os.listdir(base):
    for root, dirs, files in os.walk(os.path.join(base, repo)):
        for d in dirs:
            if d in remove_dirs:
                path = os.path.join(root, d)
                try:
                    shutil.rmtree(path)
                    print("Removed", path)
                except Exception as e:
                    pass
# Out:
# Removed iac_repos/gobengo_activitypub.com/.git
# Removed iac_repos/rgl_dotnet-pulumi-libvirt-rke-example/.git
# Removed iac_repos/sinanbekar_turborepo-terraform-cdk-aws-vercel/.git
# Removed iac_repos/paiml_python_devops_book/.git
# Removed iac_repos/paiml_python_devops_book/src/chap13-Serverless/google-python-simple-http-endpoint/node_modules
# Removed iac_repos/phillipedwards_pulumi-ts-import-error/.git
# Removed iac_repos/cjh-cloud_esp32_pwa_starter/.git
# Removed iac_repos/Addono_guide-to-pulumi-demo--common-infra/.git
# Removed iac_repos/JessicaRudd_mlplatform-infra/.git
# Removed iac_repos/pierskarsenbarg_aws-iam-demo/.git
# Removed iac_repos/Ishanamgai_NFT-DApp/.git
# Removed iac_repos/Ishanamgai_NFT-DApp/webapp/src/modules/vendor
# Removed iac_repos/MarcinGadz_iaac-comparision/.git
# Removed iac_repos/w9n_pulumi-kind/.git
# Removed iac_repos/sthuck_duckduckstay/.git
# Removed iac_repos/hashicorp_cdktf-provider-random/.git
# Removed iac_repos/DanielMSchmidt_cdktf-multi-stack-tfe/.git
# Removed iac_repos/anonymousliem_pulearnmi/.git
# Removed iac_repos/pulumi_pulumi-auth0/.git
# Removed iac_repos/muhannad0_pulumi-typescript-aws-template/.git
# Removed iac_repos/sankarpa_iac/.git
# Removed iac_repos/dtorresf_iac/.git
# Removed iac_repos/AaronFriel_awsx-example/.git
# Removed iac_repos/shanurrahman_aws_custom_infra_files/.git
# Removed iac_repos/mysticrenji_pulumi-yaml/.git
# Removed iac_repos/staslebedenko_perfect-infra-via-pulumi/.git
# Removed iac_repos/metral_crosswalk-apps/.git
# Removed iac_repos/andlju_swetugg-tix/.git
# Removed iac_repos/xai1983kbu_pulumi_appsync_with_direct_lambda_to_dynamodb/.git
# Removed iac_repos/CerusBots_website/.git
# Removed iac_repos/romcheck_pulumi-stackgres/.git
# Removed iac_repos/elbetasal_app-playground/.git
# Removed iac_repos/phillipedwards_aws-ts-textract/.git
# Removed iac_repos/NewOrbit_ClientSideEncryption.Demo/.git
# Removed iac_repos/naveensrinivasan_codeserver/.git
# Removed iac_repos/shraddhamkandpal_healthrecord-verifier/.git
# Removed iac_repos/freyp567_webinyeval2/.git
# Removed iac_repos/jeanpaulsmit_blog-posts/.git
# Removed iac_repos/akash-viswan_spot-mig/.git
# Removed iac_repos/akash-viswan_spot-mig/venv/lib/python3.8/site-packages/yaml/__pycache__
# Removed iac_repos/tenwit_pulumi_examples/.git
# Removed iac_repos/dvargas92495_terraform-aws-clerk/.git
# Removed iac_repos/rarous_rarousnet/.git
# Removed iac_repos/pierskarsenbarg_policy-pack-stack/.git
# Removed iac_repos/asixdev0082_nft-market/.git
# Removed iac_repos/asixdev0082_nft-market/webapp/src/modules/vendor
# Removed iac_repos/skurik_pulumi-workspace-repro/.git
# Removed iac_repos/dixler_jdconf-2022-platform-stack/.git
# Removed iac_repos/alek29c_tf/.git
# Removed iac_repos/CerusBots_api/.git
# Removed iac_repos/creatorsgarten_configuration/.git
# Removed iac_repos/codegram_regalocal/.git
# Removed iac_repos/danieldspx_pulumi-ecs-example/.git
# Removed iac_repos/jjgrinwis_pulumi-property/.git
# Removed iac_repos/AI2Incubator_AI2I_webapp/.git
# Removed iac_repos/Welsh-Boogie_jkdkajsdnkkkpmplkqwe/.git
# Removed iac_repos/Welsh-Boogie_jkdkajsdnkkkpmplkqwe/webapp/src/modules/vendor
# Removed iac_repos/phanimullapudi_pulumi-learning/.git
# Removed iac_repos/ihoro-epam_cloudx-aws/.git
# Removed iac_repos/spareslant_oci_multi_stack_terraform_cdk_python/.git
# Removed iac_repos/shabados_viewer/.git
# Removed iac_repos/matthewzhaocc_cdktf-wordpress/.git
# Removed iac_repos/sammck_cloud-dev-box/.git
# Removed iac_repos/ths83_pulumi-tutorials/.git
# Removed iac_repos/skorfmann_drop-kick/.git
# Removed iac_repos/harrismcc_monorepo-starter/.git
# Removed iac_repos/andrewlaskey_pulumi-example/.git
# Removed iac_repos/taiyeoguns_pulumi-azure-func-trial/.git
# Removed iac_repos/magoolation_Xamarin.Bookshelf/.git
# Removed iac_repos/ederst_pulumi-in-a-pickle/.git
# Removed iac_repos/petabridge_AkkaDotNet.LargeNetworkTests/.git
# Removed iac_repos/cwinters8_pulumi-aws-godaddy-dns/.git
# Removed iac_repos/Coren_traefik/.git
# Removed iac_repos/JulesP96_Sample-Pulumi/.git
# Removed iac_repos/CPHTer_iac_w_openscap/.git
# Removed iac_repos/sirJiggles_enabler/.git
# Removed iac_repos/squaremo_stellar-examples/.git
# Removed iac_repos/decentraland_agora/.git
# Removed iac_repos/katcosgrove_iac-fundamentals/.git
# Removed iac_repos/rhyek_ynab-banco-industrial-connector/.git
# Removed iac_repos/adyavanapalli_PulumiTemplate/.git
# Removed iac_repos/vumdao_aws-guardduty-sechub/.git
# Removed iac_repos/dixler_jdconf-2022-app-dev-stack/.git
# Removed iac_repos/e-dang_App/.git
# Removed iac_repos/Dev-Thought_nx-deploy-it-examples/.git
# Removed iac_repos/puppetninja_pulumi-polkadot-legacy/.git
# Removed iac_repos/juniorcesar_apresentacao-pulumi/.git
# Removed iac_repos/Bharathkumarraju_gcp_for_fun/.git
# Removed iac_repos/vinicinbgs_poc-pulumi/.git
# Removed iac_repos/jmgilman_glab/.git
# Removed iac_repos/fuluteam_honeycomb/.git
# Removed iac_repos/rraval_zeroindexed/.git
# Removed iac_repos/zachtjones_minecraft-server/.git
# Removed iac_repos/CampbellPedersen_bsdac-api/.git
# Removed iac_repos/PranjayVats_resonate-hackathon/.git
# Removed iac_repos/MattDevy_pulumi-example/.git
# Removed iac_repos/chrisjensenuk_pulumi/.git
# Removed iac_repos/rugwirobaker_pulumi-example/.git
# Removed iac_repos/djsd123_s3-static-website-native/.git
# Removed iac_repos/pulumi_pulumi-component-provider-go-boilerplate/.git
# Removed iac_repos/sammck_apihub/.git
# Removed iac_repos/http4k_examples/.git
# Removed iac_repos/esomore_pulumi-infra/.git
# Removed iac_repos/jdwelch_examples/.git
# Removed iac_repos/ddunkin_pulumi-docker/.git
# Removed iac_repos/jpeach_pulumi-stacks/.git
# Removed iac_repos/efleming18_pulumi-examples/.git
# Removed iac_repos/kaiquelupo_async-power-dialer/.git
# Removed iac_repos/lreimer_clean-infrastructure-as-code/.git
# Removed iac_repos/eladrapoportcybr_TerraformCdkNotesDemo/.git
# Removed iac_repos/justinvp_templates/.git
# Removed iac_repos/nikmel2803_pulumi-test/.git
# Removed iac_repos/hemantmay07_test/.git
# Removed iac_repos/lwooden_sample-node-api-service/.git
# Removed iac_repos/phillipedwards_aws-ts-apigw-lambda/.git
# Removed iac_repos/jaxxstorm_pulumi-automationapi-workshop/.git
# Removed iac_repos/MalleshBonla_pulumi-docs/.git
# Removed iac_repos/likecoin_likecoin-chain/.git
# Removed iac_repos/janegilring_pspulumidemo/.git
# Removed iac_repos/abatilo_grpc-timeout-repro/.git
# Removed iac_repos/ringods_aws-lambda-changelogger/.git
# Removed iac_repos/tomca32_aws-tomislav/.git
# Removed iac_repos/andrekiba_FantasticBike/.git
# Removed iac_repos/chrsmith_browserhack-demo/.git
# Removed iac_repos/chrisguest75_terraform_examples/.git
# Removed iac_repos/jdj333_aws-eks-deployment/.git
# Removed iac_repos/devinmcguireOrion_tagging-policy/.git
# Removed iac_repos/spaceoddite_pulumi-azure-vm-component-resource-python/.git
# Removed iac_repos/lakindu2002_pulumi-micro-stacks/.git
# Removed iac_repos/jaxxstorm_pulumi-secure-eks-workloads/.git
# Removed iac_repos/pulumi_pulumi-rke/.git
# Removed iac_repos/dailydotdev_daily-scraper/.git
# Removed iac_repos/twecker137_pulumi_azr_kubernetes/.git
# Removed iac_repos/claudiordgz_udacity--data-engineering-nanodegree/.git
# Removed iac_repos/DavidHe1127_Platy/.git
# Removed iac_repos/sturlath_MyTest/.git
# Removed iac_repos/UnoSD_Pulumi.FSharp.Extensions/.git
# Removed iac_repos/cobraz_pulumi-wordpress/.git
# Removed iac_repos/drrufus_rss/.git
# Removed iac_repos/pulumi_pulumi-policy-opa/.git
# Removed iac_repos/deepakkt_digitalocean-pulumi/.git
# Removed iac_repos/pulumi_pulumi-confluentcloud/.git
# Removed iac_repos/jayeshsadhwani99_infrastructure_provision/.git
# Removed iac_repos/jaxxstorm_brig.gs/.git
# Removed iac_repos/undrash_pulumi-testing/.git
# Removed iac_repos/aaronaddleman_cdktf-typescript-docker/.git
# Removed iac_repos/AustinWise_GrpcMicroservicesOnGoogleCloudRun/.git
# Removed iac_repos/Scsabiii_vcf-automation/vendor
# Removed iac_repos/Scsabiii_vcf-automation/.git
# Removed iac_repos/Bizhop_pulumi-kube/.git
# Removed iac_repos/trif0lium_stellaris/.git
# Removed iac_repos/vincetiu8_ee-project/.git
# Removed iac_repos/varokas_db-trends/.git
# Removed iac_repos/donbing_Pairy/.git
# Removed iac_repos/BITOCTA_diagrams-article-example/.git
# Removed iac_repos/skorfmann_cdktf-container-demo/.git
# Removed iac_repos/metral_multicloud-apps/.git
# Removed iac_repos/David-VTUK_pulumi-rancher-demos/.git
# Removed iac_repos/lstkz_live-ide/.git
# Removed iac_repos/zedex11_pulumi/.git
# Removed iac_repos/L03TJ3_gd-gc-hc/.git
# Removed iac_repos/aydrian_sparkpost-consumer/.git
# Removed iac_repos/weijing329_pulumi-azure-kubernetes-guestbook/.git
# Removed iac_repos/vetorsilence_website/.git
# Removed iac_repos/dahendel_pulumi-vsphere-k3s/vendor
# Removed iac_repos/dahendel_pulumi-vsphere-k3s/.git
# Removed iac_repos/viveklak_empty-stack/.git
# Removed iac_repos/liubarnabas_linkfire-demo-pulumi-ts-eks/.git
# Removed iac_repos/cloudy-sky-software_pulumi-k8s/.git
# Removed iac_repos/ahmadalibagheri_cdktf-typescript-aws-ec2/.git
# Removed iac_repos/skorfmann_cdktf-provider-aws/.git
# Removed iac_repos/igalfsg_PulumiPlayground/.git
# Removed iac_repos/JustDjames_Go_api/.git
# Removed iac_repos/MatthewNeo_frudevops-forgeops-init/.git
# Removed iac_repos/pedramha_cdktf-azureappservice/.git
# Removed iac_repos/AntPAllen_pulumi-cue-examples/.git
# Removed iac_repos/DanielMSchmidt_cdktf-issue-1724/.git
# Removed iac_repos/macagr_cloud-metadata-endpoints-examples/.git
# Removed iac_repos/nicholas-yong_Personal-Website/.git
# Removed iac_repos/vigneshsweekaran_pulumi/.git
# Removed iac_repos/lreimer_k8s-experts-day/.git
# Removed iac_repos/jforge_iac-samples/.git
# Removed iac_repos/vidarbha_pulumi/.git
# Removed iac_repos/dailydotdev_daily-monetization/.git
# Removed iac_repos/roylee0704_hello-webiny/.git
# Removed iac_repos/daveholst_lawn-man-mono/.git
# Removed iac_repos/MitchellGerdisch_github-actions-play/.git
# Removed iac_repos/danfhernandez_ecs-cluster/.git
# Removed iac_repos/cunningj_pulumi_aws_basic/.git
# Removed iac_repos/mphillips97_pulumi-quickstart/.git
# Removed iac_repos/vavsab_pulumi-aiven-import-issue/.git
# Removed iac_repos/ronakbanka_pulumi-kubernetes-aws/.git
# Removed iac_repos/cloud-hybrid_cloud-factory/.git
# Removed iac_repos/milanpollock_dark-rush-photography/.git
# Removed iac_repos/X00159364_aws-py-serverless-webapp/.git
# Removed iac_repos/goFrendiAsgard_pyconid-pulumi/.git
# Removed iac_repos/blakegreendev_pulumi-lambda-workshop/.git
# Removed iac_repos/zeagord_lightsail-wordpress-cdk-starter/.git
# Removed iac_repos/franciscocunha55_Pulumi-Network-config-AWS/.git
# Removed iac_repos/aeons_aeons.dk/.git
# Removed iac_repos/thakkaryash94_terraform-cdk-react-example/.git
# Removed iac_repos/ansgarm_test-cdktf-go-count/.git
# Removed iac_repos/cnunciato_mern-on-aws/.git
# Removed iac_repos/pulumi_pulumi-hcloud/.git
# Removed iac_repos/emilytrau_cloudburst/.git
# Removed iac_repos/kay-is_pulumi-cloudflare-upstash/.git
# Removed iac_repos/EvanBoyle_react-serverless/.git
# Removed iac_repos/Sylvestre67_pulumi-site/.git
# Removed iac_repos/hashicorp_cdktf-provider-postgresql/.git
# Removed iac_repos/audunsolemdal_pulumi-demo/.git
# Removed iac_repos/rrajesh1979_pulumi-ublob/.git
# Removed iac_repos/trifoliumproj_infrastructure/.git
# Removed iac_repos/levankhelo_pullantis/.git
# Removed iac_repos/hashicorp_cdktf-provider-ionoscloud/.git
# Removed iac_repos/DanielMSchmidt_terraform-cdk-terraform-module-publishing-on-gh-packages/.git
# Removed iac_repos/cloudspeak_brew-install-efs-poc/.git
# Removed iac_repos/takrig_takrig.core/.git
# Removed iac_repos/RawkodeAcademy_klustered/.git
# Removed iac_repos/RawkodeAcademy_klustered/notes/klustered/episode-16/andy-v-h/vendor
# Removed iac_repos/Pocket_recommendation-api/.git
# Removed iac_repos/ramene_pulumi-k8s-kubeflow/.git
# Removed iac_repos/ahmadalibagheri_cdktf-typescript-aws-vpc/.git
# Removed iac_repos/revblock_Elastic-Cloud-Terraform-CDK-Example/.git
# Removed iac_repos/jonashackt_element-web-azure-pulumi/.git
# Removed iac_repos/annyu321_vpc_redis_mango/.git
# Removed iac_repos/ajhool_pulumi-aws-apigateway-lambda/.git
# Removed iac_repos/kane-armstrong_kanebernetes/.git
# Removed iac_repos/pulumi_pulumi-kubernetesx/.git
# Removed iac_repos/michaeldbianchi_mercury-platform/.git
# Removed iac_repos/crybaby007_map_aws/.git
# Removed iac_repos/jahskee_mono-seven/.git
# Removed iac_repos/spaceoddite_pulumi-component-provider-py-boilerplate/.git
# Removed iac_repos/hashicorp_cdktf-provider-time/.git
# Removed iac_repos/andperks6_otterEats/.git
# Removed iac_repos/kpitzen_pulumi-aws-py-eks-nginx/.git
# Removed iac_repos/madhank93_android-automation-gcp-pulumi/.git
# Removed iac_repos/perlin-network_perlinx-dashboard/.git
# Removed iac_repos/codegram_pulumi-dnsimple/.git
# Removed iac_repos/pavan8855_enthire/.git
# Removed iac_repos/lmayorga1980_gcp-cdktf-example/.git
# Removed iac_repos/StupidHackTH_stupid-hack-5-api-challenge/.git
# Removed iac_repos/asadtariq96_pulumi-test/.git
# Removed iac_repos/mobin-ux_marketplace-master/.git
# Removed iac_repos/mobin-ux_marketplace-master/webapp/src/modules/vendor
# Removed iac_repos/pierskarsenbarg_pk-test/.git
# Removed iac_repos/rsinden_gophercon/.git
# Removed iac_repos/joeduffy_pulumi-awsvpc/.git
# Removed iac_repos/pulumi_docs/.git
# Removed iac_repos/Pocket_firefox-android-home-recommendations/.git
# Removed iac_repos/CharlieDigital_dn6-mongo-react-valtio/.git
# Removed iac_repos/cphillips17_terraform-tutorials/.git
# Removed iac_repos/Silver-birder_social-trend/.git
# Removed iac_repos/pierskarsenbarg_pulumi-ts-entrypoint-demo/.git
# Removed iac_repos/cloudvietnam18_git-pulumi/.git
# Removed iac_repos/mbergal_sam-app/.git
# Removed iac_repos/elmoura_backend-restaurant-manager/.git
# Removed iac_repos/phillipedwards_aws-plugin-issue/.git
# Removed iac_repos/cloudreach_urly-wurly/.git
# Removed iac_repos/ansgarm_cdktf-github-duty/.git
# Removed iac_repos/sasidiropoulos_market/.git
# Removed iac_repos/sasidiropoulos_market/webapp/src/modules/vendor
# Removed iac_repos/adekoyadapo_managed-k8s/.git
# Removed iac_repos/ptavoni_forgeops/.git
# Removed iac_repos/shazi7804_cdktf-aws-deployment-anywhere/.git
# Removed iac_repos/awelsh_pulumi-blog-post/.git
# Removed iac_repos/purton-tech_rust-on-nails/.git
# Removed iac_repos/trustfractal_substrate-node-provisioning/.git
# Removed iac_repos/goldoneen_nft-marketplace/.git
# Removed iac_repos/goldoneen_nft-marketplace/webapp/src/modules/vendor
# Removed iac_repos/anjosluc_pulumi-k8s-stack-base-python/.git
# Removed iac_repos/RichardWLaub_pulumi-repro/.git
# Removed iac_repos/s1ntaxe770r_do-pl-k8s/.git
# Removed iac_repos/maxmlv_paas-coud/.git
# Removed iac_repos/Octirke_pulumi-import-bug/.git
# Removed iac_repos/joeduffy_pk8syaml/.git
# Removed iac_repos/pulumi_pulumi-azure-native/.git
# Removed iac_repos/cheab-org_infra/.git
# Removed iac_repos/Othello1111_Decentralized_Internet/.git
# Removed iac_repos/Othello1111_Decentralized_Internet/clusterpost/src/clusterpost-model/node_modules
# Removed iac_repos/Othello1111_Decentralized_Internet/clusterpost/src/clusterpost-fs/node_modules
# Removed iac_repos/Othello1111_Decentralized_Internet/clusterpost/src/clusterpost-server/node_modules
# Removed iac_repos/SamEdwardes_rstudio-team-pulumi-recipes/.git
# Removed iac_repos/cesmunoz_cemdev-twitch/.git
# Removed iac_repos/nimbinatus_pulumi-docker-testing/.git
# Removed iac_repos/jessicaUP_CloudVisitCount/.git
# Removed iac_repos/mskutin_lambda-nodejs-16/.git
# Removed iac_repos/GopinathYadavAR_pulumi-workshop/.git
# Removed iac_repos/koffe0522_cdktf-templates/.git
# Removed iac_repos/moment-eng_emojibot/.git
# Removed iac_repos/AaronFriel_pulumi-wordle/.git
# Removed iac_repos/marco-stripe_cluster/.git
# Removed iac_repos/alexlapinski_meal-planner/.git
# Removed iac_repos/phiroict_training-kube-certification/.git
# Removed iac_repos/n0npax_lime-comb/.git
# Removed iac_repos/davidNHK_spotify-music-player/.git
# Removed iac_repos/WaffleHacks_infrastructure/.git
# Removed iac_repos/rekibnikufesin_nextjs-demo/.git
# Removed iac_repos/ryuheechul_tf-cloud/.git
# Removed iac_repos/scratchmex_mixtemi_infrastructure/.git
# Removed iac_repos/jsteinich_cdktf-ecs-fargate-tokens/.git
# Removed iac_repos/scrthq_js-aks-test/.git
# Removed iac_repos/syahiaoui_pulumi-deploy-clourun/.git
# Removed iac_repos/codedevote_spartakiade2021-pulumi/.git
# Removed iac_repos/moj-analytical-services_data-engineering-database-access-deploy/.git
# Removed iac_repos/umerpirwani_Nft.marketplace/.git
# Removed iac_repos/umerpirwani_Nft.marketplace/webapp/src/modules/vendor
# Removed iac_repos/MonseGuzman_pulumi-go-learning/.git
# Removed iac_repos/TechWatching_FunctionAppWithoutSecretConnectionString/.git
# Removed iac_repos/Pjatac_KubTest/.git
# Removed iac_repos/philjhale_pulumi-gcp/.git
# Removed iac_repos/asrivastava786_pulumi/.git
# Removed iac_repos/state-alchemists_amalgam/.git
# Removed iac_repos/state-alchemists_amalgam/my-project/__pycache__
# Removed iac_repos/brightsole_solosis/.git
# Removed iac_repos/JohannesKonings_test-cdktf/.git
# Removed iac_repos/tec-2000_turborepo/.git
# Removed iac_repos/gabrielstellini_pulumi-playground/.git
# Removed iac_repos/swapnilmmane_cicd/.git
# Removed iac_repos/squaremo_pulumi-warmup/.git
# Removed iac_repos/pulumi_pulumi-minio/.git
# Removed iac_repos/SDuck4_pulumi-in-practice/.git
# Removed iac_repos/galaxyglobespace_galaxymarket/.git
# Removed iac_repos/galaxyglobespace_galaxymarket/webapp/src/modules/vendor
# Removed iac_repos/modern-energy_wordpress-pulumi-cljs/.git
# Removed iac_repos/TheTechCompany_HexHive/.git
# Removed iac_repos/Kapernikov_skaffold-helm-tutorial/.git
# Removed iac_repos/arschles_athens-azure/.git
# Removed iac_repos/sepeng_Dash_Template/.git
# Removed iac_repos/fpommerening_DevOpenSpace2019/.git
# Removed iac_repos/streamprocessor_starter/.git
# Removed iac_repos/akgood_cdp-ann-arbor/.git
# Removed iac_repos/recumbent_ddd-2020/.git
# Removed iac_repos/amart78_tinderFurever/.git
# Removed iac_repos/AaronFriel_awsx-fargate-deps/.git
# Removed iac_repos/fanout_apollo-serverless-demo/.git
# Removed iac_repos/goawsgo_aws-cloud-edge-pulumi/__pycache__
# Removed iac_repos/goawsgo_aws-cloud-edge-pulumi/.git
# Removed iac_repos/bjerkio_bot/.git
# Removed iac_repos/pierskarsenbarg_pulumi-snowflake-repo/.git
# Removed iac_repos/etherdata-blockchain_config/.git
# Removed iac_repos/rgl_dotnet-pulumi-rke-vsphere-cloud-provider-example/.git
# Removed iac_repos/decentraland_builder-server/.git
# Removed iac_repos/pierskarsenbarg_static-website-component/.git
# Removed iac_repos/binhrobles_SkeletonVueNuxt/.git
# Removed iac_repos/SzymonSmykala_Pulumi-micro-stacks-csharp/.git
# Removed iac_repos/unmango_pulumi-homelab/.git
# Removed iac_repos/scaffold-sh_aws-serverless-docker/.git
# Removed iac_repos/hpcjmart_ejemplo_1/node_modules
# Removed iac_repos/hpcjmart_ejemplo_1/.git
# Removed iac_repos/erpujabaidya_typescript/.git
# Removed iac_repos/leapingbytes_kenesis-or-bust/.git
# Removed iac_repos/pulumi_pulumi-aiven/.git
# Removed iac_repos/luistrigueiros_quickstart-pulumi-k8s-kotlin/.git
# Removed iac_repos/Kurabu-chan_Kurabu/.git
# Removed iac_repos/MitchellGerdisch_pulumi-play/.git
# Removed iac_repos/Pocket_curation-tools-data-sync/.git
# Removed iac_repos/keyamin_pulumi-tutorial/.git
# Removed iac_repos/pulumi_pulumi-cloud/.git
# Removed iac_repos/bnabis93_model-template/.git
# Removed iac_repos/pulumi_pulumi-mailgun/.git
# Removed iac_repos/gofort_lambda-pulumi/.git
# Removed iac_repos/mattcanty-photography_platform/.git
# Removed iac_repos/Internet2_CLASS-Advanced/.git
# Removed iac_repos/Mauwii_azure-pipelines-with-github-repo/.git
# Removed iac_repos/evleria_pulumi-ecs-fargate-poc/.git
# Removed iac_repos/cveld_pulumi-tester/.git
# Removed iac_repos/einfachnuralex_gdeploy/.git
# Removed iac_repos/NillsF_blog/.git
# Removed iac_repos/jsdeveloperpro_nextjs-gcp-storage/.git
# Removed iac_repos/ethan-stone_nodejs-cloud-run/.git
# Removed iac_repos/weaveworks-training_gitopsdays-2020/.git
# Removed iac_repos/metral_modify-default-eks-sg/.git
# Removed iac_repos/cjh-cloud_pulumi_ecr_example/.git
# Removed iac_repos/Faucitas_aws-lightsail-deploy/.git
# Removed iac_repos/0kate_serverless-revshell/.git
# Removed iac_repos/BelRarr_confoo2022-iac4devs/.git
# Removed iac_repos/drsahook_pulumi-jenkins-app-deploy-new/node_modules
# Removed iac_repos/drsahook_pulumi-jenkins-app-deploy-new/.git
# Removed iac_repos/iotv_web/.git
# Removed iac_repos/coding-flamingo_PulumiAKVwithServicebus/.git
# Removed iac_repos/pulumi_get.pulumi.com/.git
# Removed iac_repos/pulumi_actions-example-gke-rails/.git
# Removed iac_repos/pulumi_actions-example-gke-rails/app/vendor
# Removed iac_repos/swen128_k8s-pulumi/.git
# Removed iac_repos/provenian_judge/.git
# Removed iac_repos/rawlingsj_gcp-go/.git
# Removed iac_repos/shineyid_tgik-playlist/.git
# Removed iac_repos/shineyid_tgik-playlist/episodes/052/vendor
# Removed iac_repos/shineyid_tgik-playlist/episodes/040/live/vendor
# Removed iac_repos/shineyid_tgik-playlist/episodes/040/live/docs/reference/build/node_modules
# Removed iac_repos/pierskarsenbarg_workshop-labs/.git
# Removed iac_repos/mikesupertrampster-corp_pulumi-azure-csharp/.git
# Removed iac_repos/DanielMSchmidt_terraform-cdk-hybrid-module-publishing-on-gh-packages/.git
# Removed iac_repos/blakegreendev_vscode-fargate-pulumi/.git
# Removed iac_repos/adinda-ratna_EncodeHackAfrica/.git
# Removed iac_repos/Lonero-Team_Decentralized-Internet/.git
# Removed iac_repos/Lonero-Team_Decentralized-Internet/clusterpost/src/clusterpost-model/node_modules
# Removed iac_repos/Lonero-Team_Decentralized-Internet/clusterpost/src/clusterpost-fs/node_modules
# Removed iac_repos/Lonero-Team_Decentralized-Internet/clusterpost/src/clusterpost-server/node_modules
# Removed iac_repos/universam1_pulumi-operator/.git
# Removed iac_repos/blakegreendev_pulumi-aws-django-voting-app/.git
# Removed iac_repos/stack72_testing-pulumi-template/.git
# Removed iac_repos/Avanade_emtech-stretch-labs/.git
# Removed iac_repos/cloud-hybrid_constructs/.git
# Removed iac_repos/igoran_dnc-mlops-model-serving/.git
# Removed iac_repos/raeffs_ffhs-cas-acc-containers/.git
# Removed iac_repos/amielkov_test-pulumi/.git
# Removed iac_repos/artcoded-net_vendure-pulumi-gcp/.git
# Removed iac_repos/muhannad0_pulumi-example-iac/.git
# Removed iac_repos/GeertVL-zz_eventgrid1/.git
# Removed iac_repos/wanghq_image-process-examples/.git
# Removed iac_repos/serverless-architecture_reference-architectures/.git
# Removed iac_repos/SimonHoiberg_saas-template/.git
# Removed iac_repos/kim-hangyeol_hcp/.git
# Removed iac_repos/kim-hangyeol_hcp/Hybrid_Cluster/node_modules
# Removed iac_repos/kim-hangyeol_hcp/Hybrid_Cluster/vendor
# Removed iac_repos/kim-hangyeol_hcp/Hybrid_Cluster/terraform/terraform-provider-kubernetes-alpha-0.5.0/vendor
# Removed iac_repos/kksudo_devoops-cdktf/.git
# Removed iac_repos/pulumi_pulumi-sumologic/.git
# Removed iac_repos/gabomgp4_general_learning/.git
# Removed iac_repos/AlfredoPardo-zz_python-for-devsecops/.git
# Removed iac_repos/mitodl_ol-infrastructure/.git
# Removed iac_repos/nunciato_infra/.git
# Removed iac_repos/CerusBots_runner/.git
# Removed iac_repos/si3mshady_Pulumi_Practice/.git
# Removed iac_repos/squaremo_pulumi-k8s-ssa-examples/.git
# Removed iac_repos/eric-sherrill_ahoy-pulumi/.git
# Removed iac_repos/PatriciaAnong_Blog/.git
# Removed iac_repos/PatriciaAnong_Blog/CDK/AWS_CDK/automation_rocks/__pycache__
# Removed iac_repos/alfredoem_pulumi-js-aws-example/.git
# Removed iac_repos/mattiasholm_code/.git
# Removed iac_repos/CouncilDataProject_alameda/.git
# Removed iac_repos/stack72_pulumi-azure-function/.git
# Removed iac_repos/lbrlabs_pulumi-nginx-ingress/.git
# Removed iac_repos/rayct_herocool/.git
# Removed iac_repos/shaan1337_ssh2_conn_reset_poc/.git
# Removed iac_repos/nidhiben_terraform-typescript/.git
# Removed iac_repos/djr-taureau_ideal-parakeet/.git
# Removed iac_repos/creatorsgarten_eventkit/.git
# Removed iac_repos/evamaxfield_cdp-dev/.git
# Removed iac_repos/sidpalas_cloud-resume-challenge-aws/.git
# Removed iac_repos/chris-t-fernando_iac-exercises/.git
# Removed iac_repos/rohankumardubey_pulumi/.git
# Removed iac_repos/lindydonna_velocity-examples/.git
# Removed iac_repos/Asterium-Blockchain_cardano-explorer/.git
# Removed iac_repos/eren-year21_skand/.git
# Removed iac_repos/pulumi_pulumi-kubernetes-ingress-nginx/.git
# Removed iac_repos/pulumi_pulumi-f5bigip/.git
# Removed iac_repos/Addono_guide-to-pulumi-demo--frontend-app/.git
# Removed iac_repos/go-sari_sari/.git
# Removed iac_repos/cpretzer_demos/.git
# Removed iac_repos/pulumi_pulumi-mysql/.git
# Removed iac_repos/wgarcia79_pulumi-aws/.git
# Removed iac_repos/spara_aws-py-faargate/__pycache__
# Removed iac_repos/spara_aws-py-faargate/.git
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/attr/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/_distutils_hack/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/parver/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/network/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/req/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/metadata/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/locations/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/distributions/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/models/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/utils/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/cli/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/commands/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/resolution/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/resolution/legacy/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/index/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/vcs/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/operations/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/operations/build/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_internal/operations/install/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/pep517/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/pep517/in_process/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/html5lib/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/html5lib/treeadapters/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/html5lib/filters/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/html5lib/_trie/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/html5lib/treebuilders/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/html5lib/treewalkers/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/packaging/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/msgpack/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/webencodings/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/resolvelib/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/resolvelib/compat/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/progress/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/cachecontrol/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/cachecontrol/caches/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/requests/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/util/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/contrib/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/contrib/_securetransport/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/packages/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/packages/backports/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/packages/ssl_match_hostname/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/distlib/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/distlib/_backport/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/tenacity/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/chardet/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/chardet/metadata/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/chardet/cli/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/toml/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/colorama/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/certifi/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pip/_vendor/idna/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/setuptools/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/setuptools/_distutils/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/setuptools/_distutils/command/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/setuptools/extern/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/setuptools/command/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/setuptools/_vendor/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/setuptools/_vendor/packaging/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/setuptools/_vendor/more_itertools/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ec2transitgateway/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/xray/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ram/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/devicefarm/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/mq/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/accessanalyzer/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/iam/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/backup/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/glacier/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/sfn/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/elasticloadbalancing/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ses/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/timestreamwrite/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/s3control/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/lambda_/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/workspaces/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/cloudformation/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/directconnect/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/codepipeline/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/cloudwatch/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/docdb/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/alb/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/resourcegroups/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/globalaccelerator/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/apigateway/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ebs/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/elb/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/efs/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/route53/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/gamelift/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/eks/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/pricing/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/dynamodb/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/lex/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/datapipeline/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/glue/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/resourcegroupstaggingapi/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/mediastore/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/cur/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/fsx/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/config/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/elasticache/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/batch/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/outposts/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/redshift/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/acmpca/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/worklink/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/quicksight/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/kinesis/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/securityhub/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/licensemanager/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/dms/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/iot/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/neptune/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/pinpoint/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/sagemaker/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/mwaa/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/secretsmanager/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/identitystore/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/simpledb/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/inspector/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/transfer/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/servicecatalog/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/codebuild/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/qldb/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/storagegateway/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/signer/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/dax/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/amp/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/kms/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/lightsail/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/macie2/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/macie/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/fms/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/waf/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/appmesh/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ecs/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/mediapackage/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/swf/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/apprunner/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/wafv2/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/budgets/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/elasticloadbalancingv2/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/apigatewayv2/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/cloudhsmv2/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/codeartifact/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/sqs/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/autoscaling/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/servicequotas/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/codedeploy/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/serverlessrepository/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ssm/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/appsync/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/codestarconnections/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/cognito/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/datasync/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/autoscalingplans/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/mediaconvert/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/elasticbeanstalk/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/s3/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/kinesisanalyticsv2/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/cloudfront/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/lb/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/codecommit/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/cfg/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/msk/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/athena/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ecrpublic/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/emr/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/acm/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ecr/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/guardduty/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/cloud9/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/elasticsearch/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/codestarnotifications/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/directoryservice/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/servicediscovery/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/organizations/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/sns/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/imagebuilder/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/appautoscaling/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/synthetics/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ec2/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/wafregional/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/applicationloadbalancing/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/networkfirewall/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/elastictranscoder/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ec2clientvpn/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/shield/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/ssoadmin/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/lakeformation/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/cloudtrail/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/s3outposts/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/rds/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/dlm/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_aws/opsworks/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi_random/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi/policy/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi/provider/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi/automation/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi/dynamic/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi/runtime/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/pulumi/runtime/proto/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/_yaml/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/yaml/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/dill/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/dill/tests/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/google/protobuf/__pycache__
# Removed iac_repos/spara_aws-py-faargate/app/venv/lib/python3.8/site-packages/google/protobuf/util/__pycache__
# ...
# Removed iac_repos/wyx2014_yb.dev/.git
# Removed iac_repos/jjgrinwis_create_cname_records/.git
# Removed iac_repos/abhirockzz_azure-pulumi-appservice/.git
# Removed iac_repos/vssn_terraform-typescript-docker/.git
# Removed iac_repos/yoshieki1992-wk_gke/.git
# Removed iac_repos/ramyaparthiban31_lender/.git
# Removed iac_repos/ever-co_dev-pulumi/.git
# Removed iac_repos/canveshh1_nginx-eks/.git
# Removed iac_repos/frezbo_infra-do/.git
# Removed iac_repos/mehmettahameral_IaC-Function-with-Pulumi/.git
# Removed iac_repos/rohankumardubey_kubernetes-operator/.git
# Removed iac_repos/addme96_pulumi-first-golang-iaac/.git
# Removed iac_repos/OrejiNet_Practica-Pulumi/.git
# Removed iac_repos/vizv-pulumi_pulumi-hacks/.git
# Removed iac_repos/tangledeveloper_blog-migrating-to-pulumi/.git
# Removed iac_repos/Yarel_IaC-with-Pulumi/.git
# Removed iac_repos/shanehull_pulumi-provider-assume-role-repro/.git
# Removed iac_repos/ameier38_infrastructure/.git
# Removed iac_repos/dirien_digitalocean-kubernetes-challenge/.git
# Removed iac_repos/psconfeu_2022/.git
# Removed iac_repos/casimirrex_UntitledStack/.git
# Removed iac_repos/debu99_pulumi_test/.git
# Removed iac_repos/hemantmay07_AWSCODEPIPELINE/.git
# Removed iac_repos/24HourDeveloper_webiny-demo/.git
# Removed iac_repos/danfhernandez_pulumi-template-app/.git
# Removed iac_repos/eugenestarchenko_crypto-api-demo/.git
# Removed iac_repos/stevesloka_pulumi-sample/.git
# Removed iac_repos/Pondidum_pulumi-aws-nomad/.git
# Removed iac_repos/foundry-infra_foundry-infra-cs/.git
# Removed iac_repos/eesvara5512_terraform-samples/.git
# Removed iac_repos/eesvara5512_terraform-samples/terraform-provider-kubernetes/vendor
# Removed iac_repos/eesvara5512_terraform-samples/terraform-provider-azuread/vendor
# Removed iac_repos/caiokf_service-template/.git
# Removed iac_repos/lukemerrett_PythonLambdaPulumiExample/.git
# Removed iac_repos/mikiya771_terraform-cdk-examples/.git
# Removed iac_repos/PhilAndrew_AWSDockerPulumi/.git
# Removed iac_repos/yyvess_kubpoc/.git
# Removed iac_repos/Kannakattisanjana_IRA-Arrant/.git
# Removed iac_repos/UnoSD_UnoCash.Fable/.git
# Removed iac_repos/binzcodes_pulumi-minimal-dynamodb-api/.git
# Removed iac_repos/lbrlabs_pulumi-homelab/.git
# Removed iac_repos/Tirke_try-pulumi/.git
# Removed iac_repos/mtrcn_georchestrator/.git
# Removed iac_repos/timmyers_brewed-here/.git
# Removed iac_repos/garylirocks_terraform-demos/.git
# Removed iac_repos/just-run-my_app-azure-edition/.git
# Removed iac_repos/ludesdeveloper_pulumi-component-resource-ts/.git
# Removed iac_repos/jaxxstorm_pulumi-examples/.git
# Removed iac_repos/LeonidChetverikov_pulumi/.git
# Removed iac_repos/ChristoMI_Web_Backend/.git
# Removed iac_repos/avinashpancham_cdktf-explore/.git
# Removed iac_repos/pulumi_pulumi-terraform/.git
# Removed iac_repos/tmeadon_clippings/.git
# Removed iac_repos/simonzhow_hello-pulumi/.git
# Removed iac_repos/kuongknight_cdktf-ts-kuber/.git
# Removed iac_repos/Fortify-Labs_Fortify/.git
# Removed iac_repos/ikedaosushi_python-sandbox/.git
# Removed iac_repos/cnunciato_pulumi-jamstack-aws/.git
# Removed iac_repos/ludesdeveloper_pulumi-managed-nodes-autoscale-eks/.git
# Removed iac_repos/SSWConsulting_Superpowers.Net5.Brendan/.git
# Removed iac_repos/AdminTurnedDevOps_pulumi-in-aws-go/.git
# Removed iac_repos/phillipedwards_azure-dashboard-error/.git
# Removed iac_repos/macneib_cicd/.git
# Removed iac_repos/nunciato_identity/.git
# Removed iac_repos/x0techdad_minecraft-vending-machine/.git
# Removed iac_repos/filip-zyzniewski_pulumi/.git
# Removed iac_repos/aleksejkozin_hashnode-cover/.git
# Removed iac_repos/ajeetrai266_PULUMI-K8S-wordpress/.git
# Removed iac_repos/RahulMR42_oci-pulumi-java-objectstore/.git
# Removed iac_repos/ringge_DevSecOps/.git
# Removed iac_repos/ahmadalibagheri_cdktf-typescript-aws-s3bucket/.git
# Removed iac_repos/rishirajbansal_Pulumi-IaC-Integrations-Automation/.git
# Removed iac_repos/binhrobles_improved-parakeet/.git
# Removed iac_repos/matrixbegins_uni-demo-deploy/.git
# Removed iac_repos/VestiDev_python_devops_2019-book/.git
# Removed iac_repos/VestiDev_python_devops_2019-book/src/chap13-Serverless/google-python-simple-http-endpoint/node_modules
# Removed iac_repos/mescam_psr2021/.git
# Removed iac_repos/cdkmeetup_taiwan-meetup-august2020/.git
# Removed iac_repos/quebic-source_aws-data-migration/.git
# Removed iac_repos/brunoa19_wordpress-shipa-pulumi/node_modules
# Removed iac_repos/brunoa19_wordpress-shipa-pulumi/.git
# Removed iac_repos/rballeba_pulumiHelloWorld/.git
# Removed iac_repos/clstokes_example-multicloud-webserver/.git
# Removed iac_repos/visheshgargavi_visheshgargavi-CDKTF-CDK-for-Terraform/.git
# Removed iac_repos/decentraland_documentation/.git
# Removed iac_repos/BKirov_aws-fargate/.git
# Removed iac_repos/OctopusSamples_pulumi-python-azure/.git
# Removed iac_repos/demiban_pulumi-localstack-lambda-example/.git
# Removed iac_repos/shabados_infrastructure/.git
# Removed iac_repos/Pro-Coded_pro-hybrid-serverless/.git
# Removed iac_repos/soulasvalentin_pulumi-poc/.git
# Removed iac_repos/ahmadalibagheri_cdktf-typescript-aws-iam/.git
# Removed iac_repos/RainRush_generator-react-ci-iac/.git
# Removed iac_repos/nmora53_PowerDialer_quero_educ/.git
# Removed iac_repos/cjh-cloud_pulumi_fargate/.git
# Removed iac_repos/cloudspeak_pulumi-lambda-efs/.git
# Removed iac_repos/terekete_eventrun_test/.git
# Removed iac_repos/sdrush-mw_sr-cdktf-test/.git
# Removed iac_repos/xiehan_cdktf-integration-alexa-example/.git
# Removed iac_repos/ntonjeta_pulumi_integration_examples/.git
# Removed iac_repos/jbogard_AzureMessagingServices/.git
# Removed iac_repos/Trojan295_pulumi-poc/.git
# Removed iac_repos/drsahook_pulumirepo/.git
# Removed iac_repos/pedrodotmc_raki-aws/.git
# Removed iac_repos/anandvimal_pulumi-examples/.git
# Removed iac_repos/noemiko_iac_examples/.git
# Removed iac_repos/dixler_apigateway-switchover/.git
# Removed iac_repos/RahulMR42_pulumi-python-oci-instances/.git
# Removed iac_repos/ukautz_cdktf-inconsistent-name-bug/.git
# Removed iac_repos/hmix_try-terraform-cdk-python/.git
# Removed iac_repos/MiguelPazo_pulumi_aws_create_database/.git
# Removed iac_repos/vennabharath_aws/.git
# Removed iac_repos/losnir_lmade-http-echo/.git
# Removed iac_repos/pulumi_pulumi-azure-quickstart-compute/.git
# Removed iac_repos/spron-in_blog-data/.git
# Removed iac_repos/Aristohack_jowen/.git
# Removed iac_repos/MiguelPazo_pulumi_aws_base_infrastructure/.git
# Removed iac_repos/pulumi_pulumi-aws-quickstart-redshift/.git
# Removed iac_repos/pulumi_demo-kubecrash-2022/.git
# Removed iac_repos/mikhailshilkov_fosdem2019/.git
# Removed iac_repos/noriyuki-shimizu_cdk_for_terraform_sample_ec2/.git
# Removed iac_repos/Nav-app_pulumiAwsS3LambdaDynamoDB/.git
# Removed iac_repos/marcindulak_azure-ml-aks-intro/.git
# Removed iac_repos/moinulm_terraform-course/.git
# Removed iac_repos/eminetto_post-pulumi/.git
# Removed iac_repos/rlyders_guide-me/.git
# Removed iac_repos/byhbt_cdktf-python/.git
# Removed iac_repos/mattstratton_awesome-azure/.git
# Removed iac_repos/dirien_infrastructure-as-code-workshop/.git
# Removed iac_repos/Shyam-Chen_Micro-Fullstack/.git
# Removed iac_repos/bdelmas_pulumi-quickstart/.git
# Removed iac_repos/steinko_tododeployment2/.git
# Removed iac_repos/squaremo_pulumi-localprocess/.git
# Removed iac_repos/catrielmuller_home-k8s/.git
# Removed iac_repos/chrislennon_pulumi-discord-bot/.git
# Removed iac_repos/diego3g_pulumi-lambda-mail-queue/.git
# Removed iac_repos/PHONGLEX_fastapi_pizzadelivery_api/__pycache__
# Removed iac_repos/PHONGLEX_fastapi_pizzadelivery_api/.git
# Removed iac_repos/mikhailshilkov_pulumi-provider-boilerplate-openapi/.git
# Removed iac_repos/neilkuan_cdk-terraform-aws-ecs-fargate/.git
# Removed iac_repos/hashicorp_docker-on-aws-ecs-with-terraform-cdk-using-typescript/.git
# Removed iac_repos/marcaurele_pulumi-cloud-demo/.git
# Removed iac_repos/DanielMSchmidt_cdktf-github-actions-local-demo/.git
# Removed iac_repos/mpnsk_xingedin/.git
# Removed iac_repos/djsd123_s3-static-website/.git
# Removed iac_repos/vijayringale_Working_With_Terraform/.git
# Removed iac_repos/srkischa_pulumi-azure/.git
# Removed iac_repos/dangitsdavid_pulumi-clnode/.git
# Removed iac_repos/devopsjourney1_pulumi-helloworld/.git
# Removed iac_repos/alexhwoods_super-pulumi/.git
# Removed iac_repos/AllSafeCyberSecur1ty_Heroku-s/.git
# Removed iac_repos/yreynhout_escargo/.git
# Removed iac_repos/tilt-dev_tilt-extensions/.git
# Removed iac_repos/gbaeke_pulumi-samples/.git
# Removed iac_repos/ese-erigha_grpc-graphql-kubernetes-microservice/.git
# Removed iac_repos/dimitor115_pulumi-instance-refresh-bug-reproduction/.git
# Removed iac_repos/martinothamar_EasyAzureWebApp/.git
# Removed iac_repos/ChanghoonHyun_cdktf-example/.git
# Removed iac_repos/pulumi-in-action_website/.git
# Removed iac_repos/pulumi_eks-blueprint/.git
# Removed iac_repos/jonashackt_tekton-argocd-eks/.git
# Removed iac_repos/TsundereChen_terraform-aws-cloud-gaming/.git
# Removed iac_repos/smpnet74_pulumi-eks/.git
# Removed iac_repos/dgg32_pulumi_quickstart/.git
# Removed iac_repos/amrom66_my-practice/.git
# Removed iac_repos/amrom66_my-practice/gitlab-practice/gitlab-ci-k8s-demo/vendor
# Removed iac_repos/jstans_kubernetes-dashboard/.git
# Removed iac_repos/gmiretti_pulumi-aws-py-lambda-api-gateway-ecache/.git
# Removed iac_repos/mastoj_sweetspot/.git
# Removed iac_repos/aitomatic_melody/.git
# Removed iac_repos/himsh_pulumi-POC/.git
# Removed iac_repos/nszaaa3_shididev.com/.git
# Removed iac_repos/pulumi_pulumi-aws/.git
# Removed iac_repos/iorchard_bkos/.git
# Removed iac_repos/cappyzawa_terraform-provider-concourse/.git
# Removed iac_repos/AI2Incubator_AI2I_streamlitapp/.git
# Removed iac_repos/nimbinatus_circleci-pulumi-sample/.git
# Removed iac_repos/pulumi_pulumi-artifactory/.git
# Removed iac_repos/ryandcoates_bcw-demos/.git
# Removed iac_repos/shaed-parkar_ss-dotnet-api/.git
# Removed iac_repos/sarwe100_dotnetprod/.git
# Removed iac_repos/lordabhi1_cdk-for-terraform/.git
# Removed iac_repos/viveklak_npm-install/.git
# Removed iac_repos/rasmus-bn_poetry-example-project/.git
# Removed iac_repos/philhub85_51922/node_modules
# Removed iac_repos/philhub85_51922/.git
# Removed iac_repos/XavierGeerinck_PublicProjects/.git
# Removed iac_repos/dishu2511_apprunner/.git
# Removed iac_repos/Neverwas-dev_unchained/.git
# Removed iac_repos/chernandez83_HeroCool/.git
# Removed iac_repos/DanielMSchmidt_cdktf-aws-networking-demo/.git
# Removed iac_repos/npalm_terraform-cdk-blog-experiment/.git
# Removed iac_repos/blackgirlbytes_git-emojis/.git
# Removed iac_repos/snooyen_pulumi/.git
# Removed iac_repos/vfarcic_pulumi-demo/.git
# Removed iac_repos/stack72_pulumi-gitlab-runner/.git
# Removed iac_repos/decentraland_add-mana/.git
# Removed iac_repos/stack72_devops-oslo-2019/.git
# Removed iac_repos/abargstaedt_pulumi-with-unit-tests/.git
# Removed iac_repos/canveshh1_eks-01/.git
# Removed iac_repos/shihtzu-systems_moonlight/.git
# Removed iac_repos/shazi7804_cdktf-samples-python/.git
# Removed iac_repos/shahiddev_pulumi-autoscale-bug/.git
# Removed iac_repos/fits_try_samples/.git
# Removed iac_repos/fits_try_samples/JavaScript/coffee_script/express/sample_custom_view/node_modules
# Removed iac_repos/fits_try_samples/blog/20120616/express_template_sample/node_modules
# Removed iac_repos/pulumi_facet/.git
# Removed iac_repos/nmora53_async-power-dialer-stone-poc/.git
# Removed iac_repos/clstokes_pulumi-policy-aws-iam-accessanalyzer/.git
# Removed iac_repos/zacnickens_learning-pulumi/.git
# Removed iac_repos/sheriff-rango_nft-marketplace-practice/.git
# Removed iac_repos/sheriff-rango_nft-marketplace-practice/webapp/src/modules/vendor
# Removed iac_repos/azeemqf_pulumi-azure/.git
# Removed iac_repos/pulumi_pulumi-databricks/.git
# Removed iac_repos/FriendlyUser_stock-pulumi/.git
# Removed iac_repos/artefactual-sdps_enduro/.git
# Removed iac_repos/MindLeaps_tracker/vendor
# Removed iac_repos/MindLeaps_tracker/.git
# Removed iac_repos/andrekiba_PulumiAzureNative/.git
# Removed iac_repos/thetminko_pulumi-poc/.git
# Removed iac_repos/TheEdgeOfCat_iac_comparison/.git
# Removed iac_repos/ChrisBellew_bellewmi/.git
# Removed iac_repos/jaxxstorm_pulumi-productionapp/.git
# Removed iac_repos/David-VTUK_vSphere-K3s-Rancher-Pulumi/.git
# Removed iac_repos/chakch_pulumiTutorial/.git
# Removed iac_repos/jacquessergio_pulumi-aws-typescript/.git
# Removed iac_repos/muellermatthias_blog-pulumi-modules/.git
# Removed iac_repos/refract-cms_refract-cms/.git
# Removed iac_repos/ikozinov_pulumi-k3s-provisioner/.git
# Removed iac_repos/twilio-infra-as-code_taskrouter-contact-center/.git
# Removed iac_repos/WaryArchanid_Events/.git
# Removed iac_repos/kubarozycki_infra-as-a-code-exercise/.git
# Removed iac_repos/grzegorz-bielski_aws-ci-dashboard/.git
# Removed iac_repos/willgarcia_rotc/.git
# Removed iac_repos/kingster307_localstack_ws_bugs/.git
# Removed iac_repos/pulumi_pulumi-command/.git
# Removed iac_repos/luizhlelis_auth0-IaC/.git
# Removed iac_repos/Mattaparthi321_my-teraform-code/.git
# Removed iac_repos/cecilphillip_servicebus-messaging-patterns/.git
# Removed iac_repos/fedemarchini_TestGitActions/.git
# Removed iac_repos/edalongeville_pulumi_sample_certificate/.git
# Removed iac_repos/rjha0720_cdkterraform/.git
# Removed iac_repos/pulumi_pulumi-synced-folder/.git
# Removed iac_repos/firemanxbr_tchelinux-2021/.git
# Removed iac_repos/LachlanStevens_UntitledStack-3/.git
# Removed iac_repos/justinvp_secret-outputs-repro/.git
# Removed iac_repos/hryang_pulumi-jenkins-example/.git
# Removed iac_repos/wjrm500_heroku-clone/.git
# Removed iac_repos/ksivamuthu_eks-pulumi-demo/.git
# Removed iac_repos/Pocket_curated-corpus-api/.git
# Removed iac_repos/aureq_pulumi-aws-ts-training-session-3/.git
# Removed iac_repos/mizzy_pulumi-playground/.git
# Removed iac_repos/ayls_balthazar/.git
# Removed iac_repos/natmarek_cdktf-learning/.git
# Removed iac_repos/Abdubek_request/.git
# Removed iac_repos/Josh-Tilles_MC-issues/.git
# Removed iac_repos/swgillespie_dockercon18/.git
# Removed iac_repos/shahab7758_marketplace-web/.git
# Removed iac_repos/shahab7758_marketplace-web/src/modules/vendor
# Removed iac_repos/nicklofaso_sandbox-cicd/.git
# Removed iac_repos/tinkerbell_infrastructure/.git
# Removed iac_repos/matthewzhaocc_krust-hello-world/.git
# Removed iac_repos/ministryofjustice_analytical-platform-infrastructure-pulumi/.git
# Removed iac_repos/robodair_pulumi-aws-profile-override/.git
# Removed iac_repos/wwt_pulumi-templates/.git
# Removed iac_repos/shanmu-ss_wp-pulumi/.git
# Removed iac_repos/Vake93_cca.client/.git
# Removed iac_repos/wrasdf_pulumi-world/.git
# Removed iac_repos/fsainovich_tcb-azure-m6/.git
# Removed iac_repos/yoshikyoto_cdktf-sample-app/.git
# Removed iac_repos/CouncilDataProject_boston/.git
# Removed iac_repos/ServiTrace_ReplicationPackage/.git
# Removed iac_repos/ServiTrace_ReplicationPackage/applications/faas-migration-go/aws/vendor
# Removed iac_repos/ServiTrace_ReplicationPackage/applications/faas-migration-go/ibm/vendor
# Removed iac_repos/neilkuan_pulumi-cdk-example/.git
# Removed iac_repos/pulumi_pulumi-newrelic/.git
# Removed iac_repos/orsilarssen_pulumi/.git
# Removed iac_repos/danyloB_24hour-test/.git
# Removed iac_repos/whs-dot-hk_cdktf-test/.git
# Removed iac_repos/localhost-127_IAC_samples/.git
# Removed iac_repos/unmango_safir-infra/.git
# Removed iac_repos/hashicorp_cdktf-provider-yandex/.git
# Removed iac_repos/davidNHK_project-bootstrap/.git
# Removed iac_repos/gravitee-io_gravitee-fargate/.git
# Removed iac_repos/nelbrecht_lambda-s3-go/.git
# Removed iac_repos/NorthStNetworking_NorthStNetworking/.git
# Removed iac_repos/NorthStNetworking_NorthStNetworking/clusterpost/src/clusterpost-model/node_modules
# Removed iac_repos/NorthStNetworking_NorthStNetworking/clusterpost/src/clusterpost-fs/node_modules
# Removed iac_repos/NorthStNetworking_NorthStNetworking/clusterpost/src/clusterpost-server/node_modules
# Removed iac_repos/earafat-oak9_sample-terraform/.git
# Removed iac_repos/ikovac_pulumi-workshop-1/.git
# Removed iac_repos/ryanrasti_pulumi-bazel/.git
# Removed iac_repos/CrystalMethod_devops-meetups/.git
# Removed iac_repos/xonsh_prlint/.git
# Removed iac_repos/azul915_cron-serverless-pulumi/.git
# Removed iac_repos/hackercampcz_core/.git
# Removed iac_repos/EvanBoyle_pupiter/.git
# Removed iac_repos/timmyers_nirvana/.git
# Removed iac_repos/takapi327_sample-cdktf/.git
# Removed iac_repos/DavidLeong98_pulumi/.git
# Removed iac_repos/staeff_aws-infra/.git
# Removed iac_repos/davetrainer_api-container-app/.git
# Removed iac_repos/lhennerley_pulumi-brum-js/.git

# %%
import os, shutil, random

repos = os.listdir("iac_repos")
print("Total repos available:", len(repos))

# Pick all available repos (or up to 1000 if you have more)
sample_size = min(1000, len(repos))
sample = random.sample(repos, sample_size)

subset_dir = "iac_subset"
os.makedirs(subset_dir, exist_ok=True)

# Directories we want to ignore (junk)
ignore_dirs = ["node_modules", ".git", "venv", "__pycache__", "dist", "build"]

def ignore_patterns(_, names):
    return [n for n in names if n in ignore_dirs]

for r in sample:
    src = os.path.join("iac_repos", r)
    dst = os.path.join(subset_dir, r)
    if not os.path.exists(dst):
        try:
            shutil.copytree(src, dst, ignore=ignore_patterns)
            print("Copied:", r)
        except Exception as e:
            print("Failed:", r, e)
# Out:
# Total repos available: 936
# Copied: sgrade_pulumi
# Copied: Jmen_hello-pulumi
# Copied: elbetasal_app-playground
# Copied: Ishanamgai_NFT-DApp
# Copied: justinvp_secret-outputs-repro
# Copied: pulumi_pulumi
# Copied: vavsab_pulumi-aiven-import-issue
# Copied: pulumi_pulumi-confluentcloud
# Copied: rohankumardubey_kubernetes-operator
# Copied: lindydonna_velocity-examples
# Copied: donbing_Pairy
# Copied: syahiaoui_pulumi-deploy-clourun
# Copied: bloominlabs_baseplate-go
# Copied: martinothamar_EasyAzureWebApp
# Copied: kubarozycki_infra-as-a-code-exercise
# Copied: squaremo_pulumi-ociregistry-provider
# Copied: pulumi_pulumi-auth0
# Copied: kingster307_localstack_ws_bugs
# Copied: andrekiba_CrazyBike
# Copied: xiehan_cdktf-integration-alexa-example
# Copied: JulesP96_Sample-Pulumi
# Copied: iac-factory_gitlab-runner-cdktf
# Copied: uma-arai_iac-story-code
# Copied: RahulMR42_pulumi-python-oci-instances
# Copied: RafaelFigueiredo_pulumi-digitalocean-k8s-linkerd
# Copied: marcaurele_pulumi-cloud-demo
# Copied: lakindu2002_pulumi-micro-stacks
# Copied: phillipedwards_pulumi-serverless
# Copied: mysticrenji_pulumi-yaml
# Copied: ajhool_pulumi-aws-apigateway-lambda
# Copied: cjh-cloud_pulumi_fargate
# Copied: alek29c_tf
# Copied: gmiretti_pulumi-aws-py-lambda-api-gateway-ecache
# Copied: korosuke613_playground
# Copied: EvanBoyle_react-serverless
# Copied: lhennerley_pulumi-brum-js
# Copied: eladrapoportcybr_TerraformCdkNotesDemo
# Copied: markeytos_PulumiAzureSample
# Copied: SSWConsulting_Superpowers.Net5.Brendan
# Copied: goto-satoru_pulumi-azure-functions-cs
# Copied: TheTechCompany_HexHive
# Copied: DavidLeong98_pulumi
# Copied: henriklagergren_azure-trigger-benchmark
# Copied: anonymousliem_pulearnmi
# Copied: ludesdeveloper_pulumi-managed-nodes-autoscale-eks
# Copied: muellermatthias_blog-pulumi-modules
# Copied: dvargas92495_terraform-aws-clerk
# Copied: Pocket_curated-corpus-api
# Copied: drrufus_rss
# Copied: pulumi_actions-example-gke-rails
# Copied: vaspoz_pgadmin-aws
# Copied: steinko_continuose-delivery-template
# Copied: janfabian_offtopic-slack-bot
# Copied: aureq_pulumi-aws-ts-training-session-3
# Copied: amielkov_test-pulumi
# Copied: harrismcc_monorepo-starter
# Copied: ultramozg_pulumi
# Copied: Panaetius_pulumi-test
# Failed: marco-stripe_cluster [('iac_repos/marco-stripe_cluster/remote-builder-stack/result', 'iac_subset/marco-stripe_cluster/remote-builder-stack/result', "[Errno 2] No such file or directory: 'iac_repos/marco-stripe_cluster/remote-builder-stack/result'"), ('iac_repos/marco-stripe_cluster/remote-builder-stack/result-2', 'iac_subset/marco-stripe_cluster/remote-builder-stack/result-2', "[Errno 2] No such file or directory: 'iac_repos/marco-stripe_cluster/remote-builder-stack/result-2'")]
# Copied: abhirockzz_azure-pulumi-appservice
# Copied: cwinters8_pulumi-aws-godaddy-dns
# Copied: pulumi_demo-kubecrash-2022
# Copied: JakeGinnivan_pulumi-ecs-debugging
# Copied: yobooooi_tdd-terraform-cdk
# Copied: pulumi_pulumi-opsgenie
# Copied: WallarooLabs_wally
# Copied: pulumi_pulumi-openfaas
# Copied: ihoro-epam_cloudx-aws
# Copied: Aletrevi_Postchain
# Copied: Pocket_recommendation-api
# Copied: amkul99_pulumi-fargate
# Copied: pulumi-in-action_website
# Copied: jayeshsadhwani99_infrastructure_provision
# Copied: ludesdeveloper_pulumi-component-resource-ts
# Copied: CharlieDigital_dn6-mongo-react-valtio
# Copied: phillipedwards_pulumi-ts-import-error
# Copied: Faucitas_aws-lightsail-deploy
# Copied: pulumi_pulumi-snowflake
# Copied: RawkodeAcademy_klustered
# Copied: DanielMSchmidt_terraform-cdk-terraform-module-publishing-on-gh-packages
# Copied: chris-t-fernando_iac-exercises
# Copied: martinjt_pulumi-dotnet5
# Copied: go-sari_sari
# Copied: zedex11_pulumi
# Copied: blakegreendev_vscode-fargate-pulumi
# Copied: vincetiu8_ee-project
# Copied: evamaxfield_cdp-dev
# Copied: neilkuan_cdk-terraform-aws-ecs-fargate
# Copied: Dominik-K_presentation_Pulumi_2019-06-12
# Copied: tangledeveloper_blog-migrating-to-pulumi
# Copied: omegazyadav_iac
# Copied: magoolation_Xamarin.Bookshelf
# Copied: moj-analytical-services_data-engineering-database-access-deploy
# Copied: abvijaykumar_contactlist-blog-infra
# Copied: MitchellGerdisch_github-actions-play
# Copied: sindre-nistad_pulumi-bouvet-one-2021
# Copied: ahmadalibagheri_cdktf-typescript-aws-iam
# Copied: YatipaC_LuckBox
# Copied: EvanBoyle_pupiter
# Copied: hashicorp_kubernetes-on-gcp-with-terraform-cdk
# Copied: ahmadalibagheri_cdktf-typescript-aws-s3bucket
# Copied: 24HourDeveloper_webiny-demo
# Copied: scrthq_js-aks-test
# Copied: jaxxstorm_containers-from-the-couch
# Copied: AaronFriel_awsx-fargate-deps
# Copied: weijing329_pulumi-azure-kubernetes-guestbook
# Copied: wgarcia79_pulumi-aws
# Copied: rjha0720_cdkterraform
# Copied: Eric-Swiftly_PulumiCDNEndpointIssue
# Copied: noriyuki-shimizu_cdk_for_terraform_sample_ec2
# Copied: NillsF_blog
# Copied: jaxxstorm_pulumi-secure-eks-workloads
# Copied: Dev-Thought_nx-deploy-it-examples
# Copied: stack72_pulumi-azure-function
# Copied: robodair_pulumi-aws-profile-override
# Copied: trustfractal_substrate-node-provisioning
# Copied: mastoj_sweetspot
# Copied: noemiko_iac_examples
# Copied: MalleshBonla_pulumi-docs
# Copied: jstans_kubernetes-dashboard
# Copied: XavierGeerinck_PublicProjects
# Copied: vbrinza_modern-full-cycle
# Copied: viveklak_empty-stack
# Copied: goldoneen_nft-marketplace
# Copied: DavidHe1127_Platy
# Copied: Pondidum_pulumi-aws-nomad
# Copied: PanuwatUlis_aws-infrastructure-testing
# Copied: NewOrbit_ClientSideEncryption.Demo
# Copied: pg94au_TerraformGoal
# Copied: jpeach_pulumi-stacks
# Copied: vennabharath_lessons
# Copied: danyloB_24hour-test
# Copied: likecoin_likecoin-chain
# Copied: WaryArchanid_Events
# Copied: viktree_bookish-octo-parakeet
# Copied: jdj333_aws-eks-deployment
# Copied: cesmunoz_cemdev-twitch
# Copied: mattcanty-photography_platform
# Copied: kksudo_devoops-cdktf
# Copied: rekibnikufesin_nextjs-demo
# Copied: nidhiben_terraform-typescript
# Copied: gabomgp4_general_learning
# Copied: cunningj_pulumi_aws_basic
# Copied: tinkerbell_infrastructure
# Copied: CrystalMethod_devops-meetups
# Failed: http4k_examples [('iac_repos/http4k_examples/http4k-core/react-app/frontend/distribution/reactapp', 'iac_subset/http4k_examples/http4k-core/react-app/frontend/distribution/reactapp', "[Errno 2] No such file or directory: 'iac_repos/http4k_examples/http4k-core/react-app/frontend/distribution/reactapp'")]
# Copied: TobiMichael96_pulumi-demo
# Copied: rishirajbansal_Pulumi-IaC-Integrations-Automation
# Copied: macneib_cicd
# Copied: rayct_herocool
# Copied: brandonkal_pulumi-command
# Copied: pulumi_pulumi-rke
# Copied: luizhlelis_auth0-IaC
# Copied: scaffold-sh_aws-serverless-docker
# Copied: AdminTurnedDevOps_Live-Sessions-And-Conferences
# Copied: metral_multicloud-apps
# Copied: gabrielstellini_pulumi-playground
# Copied: GeertVL-zz_eventgrid1
# Copied: pedrodotmc_raki-aws
# Copied: alexmarqs_quickstart-pulumi
# Copied: ServiTrace_ReplicationPackage
# Copied: wyx2014_yb.dev
# Copied: innomic_pulumi-naver-native
# Copied: pierskarsenbarg_policy-pack-stack
# Copied: shazi7804_cdktf-samples-python
# Copied: nimbinatus_circleci-pulumi-sample
# Copied: peytoncasper_tf-cdk-examples
# Copied: iqbaldp_express-ecs-pulumi
# Copied: snooyen_pulumi
# Copied: akash-viswan_spot-mig
# Copied: Silver-birder_social-trend
# Copied: spara_aws-py-faargate
# Copied: psconfeu_2022
# Copied: stack72_aws-stackreference-architecture
# Copied: spareslant_oci_multi_stack_terraform_cdk_python
# Copied: PHONGLEX_fastapi_pizzadelivery_api
# Copied: pierskarsenbarg_aws-iam-demo
# Copied: wwt_pulumi-templates
# Copied: epomatti_az-static-webapps-pulumi
# Copied: decentraland_builder-server
# Copied: zsiefkes_pulumi-aws-imagebuilder
# Copied: chrislennon_pulumi-discord-bot
# Copied: wallabyjs_wallaby-pulumi
# Copied: jjgrinwis_pulumi-edgedns
# Copied: iiglesiasg_elastic-pulumi
# Copied: thetminko_pulumi-poc
# Copied: lbrlabs_pulumi-nginx-ingress
# Copied: srkischa_pulumi-azure
# Copied: devinmcguireOrion_tagging-policy
# Copied: Kapernikov_skaffold-helm-tutorial
# Copied: moment-eng_emojibot
# Copied: s1ntaxe770r_do-pl-k8s
# Copied: skorfmann_drop-kick
# Copied: UnoSD_Pulumi.FSharp.Extensions
# Copied: pierskarsenbarg_pk-test
# Copied: andrekiba_FantasticBike
# Copied: yyvess_kubpoc
# Copied: pedramha_cdktf-azureappservice
# Copied: labelflow_labelflow
# Copied: terekete_eventrun_test
# Copied: spaceoddite_pulumi-azure-vm
# Copied: jforge_iac-samples
# Copied: amrom66_my-practice
# Copied: shraddhamkandpal_healthrecord-verifier
# Copied: spaceoddite_pulumi-azure-vm-component-resource-python
# Copied: adinda-ratna_EncodeHackAfrica
# Copied: ryuheechul_tf-cloud
# Copied: mikesupertrampster-corp_pulumi-azure-csharp
# Copied: liubarnabas_linkfire-demo-pulumi-ts-eks
# Copied: catrielmuller_home-k8s
# Copied: andperks6_otterEats
# Copied: ksivamuthu_eks-pulumi-demo
# Copied: CouncilDataProject_alameda
# Copied: imod_azure-nextgen-migration
# Copied: artefactual-sdps_enduro
# Copied: roylee0704_hello-webiny
# Copied: stack72_testing-pulumi-template
# Copied: dave-burke_pulumi-vitest-example
# Copied: cnunciato_mern-on-aws
# Copied: skirsten_test-pulumi-prisma
# Copied: rgl_dotnet-terraform-cdk-vsphere-ubuntu-example
# Copied: purton-tech_rust-on-nails
# Copied: muhannad0_pulumi-example-iac
# Copied: claudiordgz_udacity--data-engineering-nanodegree
# Copied: Shyam-Chen_Micro-Fullstack
# Copied: phiroict_training-kube-certification
# Copied: timothylambert_puldemo
# Copied: sammck_apihub
# Copied: mortenhbakken_Azure-IaC-comparison
# Copied: rgl_dotnet-pulumi-rke-vsphere-cloud-provider-example
# Copied: pulumi_pulumi-dnsimple
# Copied: vetorsilence_website
# Copied: binzcodes_pulumi-minimal-dynamodb-api
# Copied: modern-energy_pulumi-cljs
# Copied: joeduffy_pulumi-awsvpc
# Copied: pulumi_pulumi-yaml
# Copied: artcoded-net_vendure-pulumi-gcp
# Copied: nojaf_ronnies.be
# Copied: AustinWise_GrpcMicroservicesOnGoogleCloudRun
# Copied: cecilphillip_servicebus-messaging-patterns
# Copied: 0kate_serverless-revshell
# Copied: ThorstenHans_azure-container-apps-samples
# Failed: sammck_cloud-dev-box [('iac_repos/sammck_cloud-dev-box/deployed/projects/be-bucket-492598163938-us-west-2/__main__.py', 'iac_subset/sammck_cloud-dev-box/deployed/projects/be-bucket-492598163938-us-west-2/__main__.py', "[Errno 2] No such file or directory: 'iac_repos/sammck_cloud-dev-box/deployed/projects/be-bucket-492598163938-us-west-2/__main__.py'")]
# Copied: salaboy_from-monolith-to-k8s
# Copied: pulumi_automation-api-examples
# Copied: mitodl_ol-infrastructure
# Copied: metral_modify-default-eks-sg
# Copied: blampe_rocketpool-pulumi
# Copied: matthewzhaocc_krust-hello-world
# Copied: cpretzer_demos
# Copied: bnabis93_model-template
# Copied: rohankumardubey_pulumi
# Copied: revblock_Elastic-Cloud-Terraform-CDK-Example
# Copied: pulumi_eks-blueprint
# Copied: codegram_pulumi-dnsimple
# Copied: rawlingsj_gcp-go
# Copied: whs-dot-hk_cdktf-test
# Copied: nukdcbear_Pulumi-Python-AWS-VPC-EC2
# Copied: jjgrinwis_create_cname_records
# Copied: kuongknight_cdktf-ts-kuber
# Copied: universam1_pulumi-operator
# Copied: BelRarr_confoo2022-iac4devs
# Copied: mskutin_lambda-nodejs-16
# Copied: levankhelo_pullantis
# Copied: lukemerrett_PythonLambdaPulumiExample
# Copied: DanielMSchmidt_cdktf-aws-networking-demo
# Copied: stevesloka_pulumi-sample
# Copied: state-alchemists_zaruba
# Copied: timmyers_brewed-here
# Copied: pulumi_pulumi-kubernetes-ingress-nginx
# Copied: Pocket_firefox-android-home-recommendations
# Copied: christian-brindley_forgeops-demo
# Copied: smpnet74_pulumi-eks
# Copied: vumdao_aws-guardduty-sechub
# Copied: esomore_pulumi-infra
# Copied: vijayreddysura_python
# Copied: tiagob_create-full-stack
# Copied: franciscocunha55_Pulumi-Network-config-AWS
# Copied: jsdeveloperpro_nextjs-gcp-storage
# Copied: wjrm500_heroku-clone
# Copied: Asterium-Blockchain_cardano-explorer
# Copied: Tirke_try-pulumi
# Copied: mikhailshilkov_pulumi-provider-boilerplate-openapi
# Copied: pulumi_pulumi-tls
# Copied: djr-taureau_ideal-parakeet
# Copied: asrivastava786_pulumi
# Copied: arschles_athens-azure
# Copied: mizzy_pulumi-playground
# Copied: wongcyrus_AzureCloudLabEnvironment
# Copied: vfarcic_pulumi-demo
# Copied: Scsabiii_vcf-automation
# Copied: cdkmeetup_taiwan-meetup-august2020
# Copied: pulumi_pulumi-azure-native
# Copied: philjhale_pulumi-gcp
# Copied: anjosluc_pulumi-k8s-stack-base-python
# Copied: matthewzhaocc_cdktf-wordpress
# Copied: anandvimal_pulumi-examples
# Copied: eric-sherrill_ahoy-pulumi
# Copied: adyavanapalli_PulumiTemplate
# Copied: cloudspeak_brew-install-efs-poc
# Copied: ryanrasti_pulumi-bazel
# Copied: pulumi_pulumi-aws-quickstart-redshift
# Copied: shaan1337_ssh2_conn_reset_poc
# Copied: Pjatac_KubTest
# Copied: ServiBench_ReplicationPackage
# Copied: apotter-dixon_tesla-web-manager-infra
# Copied: CerusBots_website
# Copied: cfeenstra67_egghead
# Copied: lwooden_sample-node-api-service
# Copied: codegram_dashy
# Copied: elmoura_backend-restaurant-manager
# Copied: spaceoddite_pulumi-component-provider-py-boilerplate
# Copied: AlfredoPardo-zz_python-for-devsecops
# Copied: Shytaani_vocabs-for-TOEFL-server
# Copied: jonashackt_element-web-azure-pulumi
# Copied: kamisdev_MarketplacePro
# Copied: mtrcn_georchestrator
# Copied: soulasvalentin_pulumi-poc
# Copied: sidpalas_cloud-resume-challenge-aws
# Copied: eminetto_post-pulumi
# Copied: pulumi_pulumi-kubernetesx
# Copied: neitomic_pulumi-gitlab-runner-autoscale-aws
# Copied: tomca32_aws-tomislav
# Copied: MalleshBonla_pulumi-examples
# Copied: katcosgrove_iac-fundamentals
# Copied: pulumi_pulumi-synced-folder
# Copied: CerusBots_runner
# Copied: sturlath_MyTest
# Copied: asynchronous-dev_pulumi-github-builder
# Copied: pulumi_pulumi-hcloud
# Copied: jbogard_AzureMessagingServices
# Copied: DanielMSchmidt_cdktf-multi-stack-tfe
# Copied: AllSafeCyberSecur1ty_Heroku-s
# Copied: PranjayVats_resonate-hackathon
# Copied: aitomatic_melody
# Copied: x0techdad_minecraft-vending-machine
# Copied: mikiya771_terraform-cdk-examples
# Copied: nicholas-yong_Personal-Website
# Copied: AaronFriel_pulumi-wordle
# Copied: MitchellGerdisch_pulumi_azure-pipeline_play
# Copied: blackgirlbytes_git-emojis
# Copied: himsh_pulumi-POC
# Copied: Josh-Tilles_subnet-churn-repro
# Copied: MatthewNeo_frudevops-forgeops-init
# Copied: vine-d_pulumi-tests
# Copied: twecker137_pulumi_azr_kubernetes
# Copied: shazi7804_cdktf-aws-deployment-anywhere
# Copied: perlin-network_perlinx-dashboard
# Copied: avinashpancham_cdktf-explore
# Copied: cloud-hybrid_cloud-factory
# Copied: audunsolemdal_pulumi-demo
# Copied: mikek-ee_PGA
# Copied: fsainovich_tcb-azure-m6
# Copied: AI2Incubator_AI2I_streamlitapp
# Copied: clstokes_example-multicloud-webserver
# Copied: hemantmay07_test
# Copied: foundry-infra_foundry-infra-cs
# Failed: krsche_scratchpad [('iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-blinky/Drivers/CMSIS', 'iac_subset/krsche_scratchpad/stm32/nucleo-wb15cc/prj-blinky/Drivers/CMSIS', "[Errno 2] No such file or directory: 'iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-blinky/Drivers/CMSIS'"), ('iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-blinky/Drivers/STM32WBxx_HAL_Driver', 'iac_subset/krsche_scratchpad/stm32/nucleo-wb15cc/prj-blinky/Drivers/STM32WBxx_HAL_Driver', "[Errno 2] No such file or directory: 'iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-blinky/Drivers/STM32WBxx_HAL_Driver'"), ('iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Utilities/lpm', 'iac_subset/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Utilities/lpm', "[Errno 2] No such file or directory: 'iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Utilities/lpm'"), ('iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Utilities/sequencer', 'iac_subset/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Utilities/sequencer', "[Errno 2] No such file or directory: 'iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Utilities/sequencer'"), ('iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Drivers/CMSIS', 'iac_subset/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Drivers/CMSIS', "[Errno 2] No such file or directory: 'iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Drivers/CMSIS'"), ('iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Drivers/STM32WBxx_HAL_Driver', 'iac_subset/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Drivers/STM32WBxx_HAL_Driver', "[Errno 2] No such file or directory: 'iac_repos/krsche_scratchpad/stm32/nucleo-wb15cc/prj-ble-hr/Drivers/STM32WBxx_HAL_Driver'")]
# Copied: sirJiggles_enabler
# Copied: cloudy-sky-software_pulumi-k8s
# Copied: pierskarsenbarg_pulumi-ts-entrypoint-demo
# Copied: lstkz_live-ide
# Copied: iorchard_bkos
# Copied: clstokes_pulumi-policy-aws-iam-accessanalyzer
# Copied: davidNHK_spotify-music-player
# Copied: vijayringale_Working_With_Terraform
# Copied: pulumi_pulumi-aiven
# Copied: pulumi_pulumi-mailgun
# Copied: hhk7734_k8s-test
# Copied: grzegorz-bielski_aws-ci-dashboard
# Copied: ReviakinAleksey_ls-example
# Copied: WitcherD_k8s-app-layer
# Copied: L0ndra_pulumi-do-ddos
# Copied: viveklak_npm-install
# Copied: romcheck_pulumi-stackgres
# Copied: SmolLeaps_ripplefund-verifier
# Copied: efleming18_pulumi-examples
# Copied: jaxxstorm_pulumi-examples
# Copied: cloudspeak_pulumi-lambda-efs
# Copied: venkatadhatri_Pulumi
# Copied: takapi327_sample-cdktf
# Copied: Lonero-Team_Decentralized-Internet
# Copied: rlyders_guide-me
# Copied: puppetninja_pulumi-polkadot-legacy
# Copied: cveld_pulumi-tester
# Copied: quebic-source_aws-data-migration
# Copied: mphillips97_pulumi-quickstart
# Copied: zachtjones_minecraft-server
# Copied: dustinspecker_pulumi-libvirt-ubuntu-example
# Copied: cpaton_aws-configuration
# Copied: ajeetrai266_PULUMI-K8S-wordpress
# Copied: alfredoem_pulumi-js-aws-example
# Copied: shahab7758_marketplace-web
# Copied: leapingbytes_kenesis-or-bust
# Copied: kaiquelupo_async-power-dialer
# Copied: smartcontractkit_chainlink-solana
# Copied: sirJiggles_archPlayground
# Copied: djsd123_iam-ci-users
# Copied: firemanxbr_tchelinux-2021
# Copied: ezypeeze_car-branding-cloud-exercise
# Copied: grinsteindavid_local-iaas
# Copied: face-transfer_cloud-setup
# Copied: cappyzawa_terraform-provider-concourse
# Copied: pulumi_pulumi-minio
# Copied: jjindrich_jjazure-pulumi
# Copied: c0bra_github-repo-freshness-api
# Copied: rasmus-bn_poetry-example-project
# Copied: brunoa19_wordpress-shipa-pulumi
# Copied: drsahook_pulumi-jenkins-app-deploy-new
# Copied: marcel-slimmer_backend-example
# Copied: Yarel_IaC-with-Pulumi
# Copied: eugenestarchenko_crypto-api-demo
# Copied: akijakya_elk-nagios-test
# Copied: timmyers_nirvana
# Copied: sheriff-rango_nft-marketplace-practice
# Copied: jeanpaulsmit_blog-posts
# Copied: lmaeda_aws-circleci-modernization-workshop-codes
# Copied: AaronFriel_awsx-example
# Copied: takrig_takrig.core
# Copied: X00159364_aws-py-serverless-webapp
# Copied: cmclaughlin_hashiconf-cdktf-2021
# Copied: provenian_judge
# Copied: NorthStNetworking_NorthStNetworking
# Copied: monkey192_pulumi-example
# Copied: cecilphillip_serverless-tweet-scheduler
# Copied: ramene_pulumi-k8s-kubeflow
# Copied: alisondy_presentations
# Copied: earafat-oak9_sample-terraform
# Copied: squaremo_pulumi-warmup
# Copied: cmatskas_pulumi-aad-demo
# Copied: jacquessergio_pulumi-aws-typescript
# Copied: bbiggerr_testing
# Copied: pulumi_pulumi-databricks
# Copied: abargstaedt_pulumi-with-unit-tests
# Copied: blakegreendev_pulumi-lambda-workshop
# Copied: igalfsg_PulumiPlayground
# Copied: EwanNoble_AppCatalog
# Copied: webdev623_marketplace
# Copied: raeffs_ffhs-cas-acc-containers
# Copied: swen128_k8s-pulumi
# Copied: adekoyadapo_managed-k8s
# Copied: GopinathYadavAR_pulumi-workshop
# Copied: joeduffy_pk8syaml
# Copied: TsundereChen_terraform-aws-cloud-gaming
# Copied: paulrobello_localstack-lambda-layer-bug
# Copied: sarwe100_dotnetprod
# Copied: usrbinkat_pulumi-kongee-on-k8s
# Copied: frezbo_infra-do
# Copied: retarders_infrastructure
# Copied: Addono_guide-to-pulumi-demo--frontend-app
# Copied: gs-gs_pulumi-library
# Copied: decentraland_documentation
# Copied: robertkotcher_robertkotcher.github.io
# Copied: steinko_AIMTutorial
# Copied: hashicorp_docker-on-aws-ecs-with-terraform-cdk-using-typescript
# Copied: refract-cms_refract-cms
# Copied: CliffJumper_pulumi-py-tf2-server
# Copied: CPHTer_iac_w_openscap
# Copied: cpayret-KDM_KDM_API
# Copied: phanimullapudi_pulumi-learning
# Copied: BoredTweak_Miscellaneous
# Copied: ameier38_infrastructure
# Copied: chrsmith_pulumi-aws-travis-cicd-demo
# Copied: gravitee-io_gravitee-fargate
# Copied: hashicorp_cdktf-provider-time
# Copied: RichardWLaub_pulumi-repro
# Copied: localhost-127_IAC_samples
# Copied: jharleydev_open-source-workspace
# Copied: phillipedwards_aws-plugin-issue
# Copied: mobin-ux_marketplace-master
# Copied: Bizhop_pulumi-kube
# Copied: vizv-pulumi_module-openldap
# Copied: xonsh_prlint
# Copied: Coren_traefik
# Copied: spron-in_blog-data
# Copied: pulumi_pulumi-policy-opa
# Copied: cyrano5614_pulumi-gcp-network
# Copied: rrajesh1979_pulumi-ublob
# Copied: nunciato_identity
# Copied: cphillips17_terraform-tutorials
# Copied: vinicinbgs_poc-pulumi
# Copied: pulumi_pulumi-terraform
# Copied: stack72_devops-oslo-2019
# Copied: asifyet_https-github.com-asifyet-wikiextractor
# Copied: nikmel2803_pulumi-test
# Copied: shineyid_tgik-playlist
# Copied: shabados_infrastructure
# Copied: natmarek_cdktf-learning
# Copied: mastoj_pulumiaksexperiments
# Copied: yoshieki1992-wk_gke
# Copied: e-dang_App
# Copied: pulumi_facet
# Copied: camilovarela_jenkins-test
# Copied: s4nchez_storage-example
# Copied: dailydotdev_daily-monetization
# Copied: ever-co_dev-pulumi
# Copied: nelbrecht_lambda-s3-go
# Copied: brightsole_solosis
# Copied: hmix_try-terraform-cdk-python
# Copied: yreynhout_escargo
# Copied: tonskey_my-instagram-web
# Copied: pierskarsenbarg_static-website-component
# Copied: addme96_pulumi-first-golang-iaac
# Copied: tec-2000_turborepo
# Failed: ikedaosushi_python-sandbox [('iac_repos/ikedaosushi_python-sandbox/airflow/tutorial/logs/scheduler/latest', 'iac_subset/ikedaosushi_python-sandbox/airflow/tutorial/logs/scheduler/latest', "[Errno 2] No such file or directory: 'iac_repos/ikedaosushi_python-sandbox/airflow/tutorial/logs/scheduler/latest'")]
# Copied: Internet2_CLASS-Advanced
# Copied: ryandcoates_bcw-demos
# Copied: UnoSD_UnoCash.Fable
# Copied: fits_try_samples
# Copied: keyamin_pulumi-tutorial
# Copied: jsteinich_cdktf-ecs-fargate-tokens
# Copied: Octirke_pulumi-import-bug
# Copied: squaremo_stellar-examples
# Copied: Othello1111_Decentralized_Internet
# Copied: dirien_infrastructure-as-code-workshop
# Copied: SimonHoiberg_saas-template
# Copied: pulumi_qcon-workshop
# Copied: DanielMSchmidt_cdktf-issue-1724
# Copied: serverless-architecture_reference-architectures
# Copied: thakkaryash94_terraform-cdk-react-example
# Copied: dixler_apigateway-switchover
# Copied: Avanade_emtech-stretch-labs
# Copied: lordabhi1_cdk-for-terraform
# Copied: uncefact_project-traceability
# Copied: ayls_balthazar
# Copied: ActiveSolution_active-lab-iac2022
# Copied: hashicorp_cdktf-provider-ionoscloud
# Copied: pulumi_pulumi-newrelic
# Copied: dahendel_pulumi-vsphere-k3s
# Copied: Nav-app_pulumiAwsS3LambdaDynamoDB
# Copied: chrsmith_browserhack-demo
# Copied: state-alchemists_amalgam
# Copied: MarcinGadz_iaac-comparision
# Copied: pulumi_pulumi-mysql
# Copied: SDuck4_pulumi-in-practice
# Copied: timmyers_pulumi-github
# Copied: viniciusdc_terraform_cdk
# Copied: ShengzhenFu_azure-pulumi-demo
# Copied: dailydotdev_daily-scraper
# Copied: aydrian_sparkpost-consumer
# Copied: metral_crosswalk-apps
# Copied: DanManson_gcp.iamCustomRole
# Copied: vizv-pulumi_pulumi-hacks
# Copied: mikesupertrampster-corp_pulumi-aws-go
# Copied: sankarpa_iac
# Copied: rugwirobaker_pulumi-example
# Copied: creatorsgarten_configuration
# Copied: pulumi_pulumi-f5bigip
# Copied: ahmadalibagheri_cdktf-typescript-aws-ec2
# Copied: skorfmann_cdktf-container-demo
# Copied: fr123k_pulumi-lab-iac-d4l
# Copied: devopsjourney1_pulumi-helloworld
# Copied: ntonjeta_pulumi_integration_examples
# Copied: kzhou57_pulumi-azure-quickstart
# Copied: yanniz0r_sonq
# Copied: Welsh-Boogie_jkdkajsdnkkkpmplkqwe
# Copied: jtrinklein_trinkle.in-site
# Copied: dixler_jdconf-2022-app-dev-stack
# Copied: ese-erigha_grpc-graphql-kubernetes-microservice
# Copied: ronakbanka_pulumi-kubernetes-aws
# Copied: BKirov_aws-fargate
# Copied: dgg32_ncbi-taxonomy-pulumi
# Copied: chrisjensenuk_pulumi
# Copied: Abdubek_request
# Copied: fanout_apollo-serverless-demo
# Copied: sinanbekar_turborepo-terraform-cdk-aws-vercel
# Copied: shanehull_pulumi-provider-assume-role-repro
# Copied: MattDevy_pulumi-example
# Copied: andrekiba_PulumiAzureNative
# Copied: christian-brindley_forgeops-christian
# Copied: alexlapinski_meal-planner
# Copied: tyrchen_pulumi-examples
# Copied: PhilAndrew_AWSDockerPulumi
# Copied: gbaeke_pulumi-samples
# Copied: visheshgargavi_visheshgargavi-CDKTF-CDK-for-Terraform
# Copied: rarous_rarousnet
# Copied: canveshh1_eks-01
# Copied: hackercampcz_core
# Copied: nimbinatus_pulumi-docker-testing
# Copied: just-run-my_app-azure-edition
# Copied: codedevote_spartakiade2021-pulumi
# Copied: David-VTUK_pulumi-rancher-demos
# Copied: CampbellPedersen_bsdac-api
# Copied: crybaby007_map_aws
# Copied: evleria_pulumi-ecs-fargate-poc
# Copied: vizv-pulumi_module-metallb
# Copied: bjerkio_bot
# Copied: hesbon-osoro_pulumi-gcp
# Copied: Vake93_cca.server
# Copied: asadtariq96_pulumi-test
# Copied: checkly_pulumi-checkly
# Copied: CroixDrinkers_pulumi-1password
# Copied: hemantmay07_AWSCODEPIPELINE
# Copied: byhbt_cdktf-python
# Copied: decentraland_player-documentation
# Copied: wrasdf_pulumi-world
# Copied: annyu321_vpc_redis_mango
# Copied: vssn_terraform-typescript-docker
# Copied: pierskarsenbarg_pulumi-snowflake-repo
# Copied: chakch_pulumiTutorial
# Copied: dirien_digitalocean-kubernetes-challenge
# Copied: Bharathkumarraju_gcp_for_fun
# Copied: steinko_tododeployment2
# Copied: cobraz_pulumi-wordpress
# Copied: fr123k_jenkins-aws-pulumi
# Copied: Addono_guide-to-pulumi-demo--common-infra
# Copied: jdwelch_examples
# Copied: paiml_python_devops_book
# Copied: dishu2511_apprunner
# Copied: ringge_DevSecOps
# Copied: debu99_pulumi_test
# Copied: tilt-dev_tilt-extensions
# Copied: danfhernandez_pulumi-template-app
# Copied: hashicorp_cdktf-provider-random
# Copied: rballeba_pulumiHelloWorld
# Copied: rsinden_gophercon
# Copied: dkarter_neptune
# Copied: ikovac_pulumi-workshop-1
# Copied: w9n_pulumi-kind
# Copied: sdrush-mw_sr-cdktf-test
# Copied: mikhailshilkov_fsharp-advent-pulumi
# Copied: ckaur2409_Pulumi
# Copied: rgl_dotnet-pulumi-libvirt-rke-example
# Copied: Trojan295_pulumi-poc
# Copied: nszaaa3_shididev.com
# Copied: galaxyglobespace_galaxymarket
# Copied: wisemuffin_meroxa-turbine-py-test
# Copied: binhrobles_improved-parakeet
# Copied: si3mshady_Pulumi_Practice
# Copied: nmora53_async-power-dialer-stone-poc
# Copied: SamEdwardes_rstudio-team-pulumi-recipes
# Copied: casimirrex_UntitledStack
# Copied: freyp567_webinyeval2
# Copied: squaremo_pulumi-k8s-ssa-examples
# Copied: dirien_pulumi-scaleway
# Copied: npalm_terraform-cdk-blog-experiment
# Copied: codegram_regalocal
# Copied: akgood_cdp-ann-arbor
# Copied: CouncilDataProject_boston
# Copied: blakegreendev_pulumi-aws-django-voting-app
# Copied: kpitzen_pulumi-aws-py-eks-nginx
# Copied: gofort_lambda-pulumi
# Copied: fjfdepedro_aws-pulumi-ror
# Copied: simonzhow_hello-pulumi
# Copied: JustDjames_Go_api
# Copied: aleksejkozin_hashnode-cover
# Copied: MiguelPazo_pulumi_aws_base_infrastructure
# Copied: janegilring_pspulumidemo
# Copied: PatriciaAnong_Blog
# Copied: vennabharath_aws
# Copied: RahulMR42_oci-pulumi-java-objectstore
# Copied: pulumi_pulumi-command
# Copied: orsilarssen_pulumi
# Copied: prodoelmit_pulumi-slackmanifest
# Copied: phillipedwards_aws-ts-textract
# Copied: cnunciato_pulumi-miniflux
# Copied: hpcjmart_ejemplo_1
# Copied: Fortify-Labs_Fortify
# Copied: cnunciato_pulumi-jamstack-aws
# Copied: Sylvestre67_pulumi-site
# Copied: shabados_viewer
# Copied: kmkatsma_pulumi-az-xwalk
# Copied: scratchmex_mixtemi_infrastructure
# Copied: sasidiropoulos_market
# Copied: sepeng_Dash_Template
# Copied: naveensrinivasan_codeserver
# Copied: erpujabaidya_typescript
# Copied: moinulm_terraform-course
# Copied: madhank93_android-automation-gcp-pulumi
# Copied: David-VTUK_vSphere-K3s-Rancher-Pulumi
# Copied: garylirocks_terraform-demos
# Copied: milanpollock_dark-rush-photography
# Copied: mehmettahameral_IaC-Function-with-Pulumi
# Copied: abatilo_chat
# Copied: hashicorp_cdktf-provider-yandex
# Copied: dimitor115_pulumi-instance-refresh-bug-reproduction
# Copied: binhrobles_SkeletonVueNuxt
# Copied: swgillespie_dockercon18
# Copied: awelsh_pulumi-blog-post
# Copied: innomic_innomic-auth0
# Copied: shaed-parkar_ss-dotnet-api
# Copied: TechWatching_FunctionAppWithoutSecretConnectionString
# Copied: displague_pulumi-linode-webserver-ts
# Copied: mk10969_pulumi-sample
# Copied: bencematyasi_nginx-aws-demo
# Copied: eren-year21_skand
# Copied: AntPAllen_pulumi-cue-examples
# Copied: jslopeza_nx-cdktf-sls-experiment
# Copied: cloudreach_urly-wurly
# Copied: smitasulikal_pulumik8s
# Copied: lreimer_k8s-experts-day
# Copied: zacnickens_learning-pulumi
# Copied: dgeorgievski_aws-eks-pulumi
# Copied: andlju_swetugg-tix
# Copied: darshan-raul_Apollo-11
# Copied: staslebedenko_perfect-infra-via-pulumi
# Copied: MitchellGerdisch_pulumi-play
# Copied: Jorduque16_portfolio
# Copied: losnir_lmade-http-echo
# Copied: tmeadon_clippings
# Copied: daveholst_lawn-man-mono
# Copied: einfachnuralex_gdeploy
# Copied: SzymonSmykala_Pulumi-micro-stacks-csharp
# Copied: CerusBots_api
# Copied: shanurrahman_aws_custom_infra_files
# Copied: muhannad0_pulumi-typescript-aws-template
# Copied: twilio-infra-as-code_taskrouter-contact-center
# Copied: ethan-stone_nodejs-cloud-run
# Copied: canveshh1_nginx-eks
# Copied: phillipedwards_azure-dashboard-error
# Copied: StupidHackTH_stupid-hack-5-api-challenge
# Copied: WaffleHacks_infrastructure
# Copied: MonseGuzman_pulumi-go-learning
# Copied: ths83_pulumi-tutorials
# Copied: abatilo_grpc-timeout-repro
# Copied: ramyaparthiban31_lender
# Copied: modern-energy_wordpress-pulumi-cljs
# Copied: exobase-inc_exobase-stack-builders
# Copied: AdminTurnedDevOps_pulumi-in-aws-go
# Copied: demiban_pulumi-localstack-lambda-example
# Copied: hashicorp_cdktf-provider-postgresql
# Copied: wanghq_image-process-examples
# Copied: discovery-chander_pulumi
# Copied: streamprocessor_starter
# Copied: vigneshsweekaran_pulumi
# Copied: Vake93_cca.client
# Copied: L03TJ3_gd-gc-hc
# Copied: sriazcloud_Terraform-AllClouds-kubernetes
# Copied: pulumi_pulumi-cloud
# Copied: Kannakattisanjana_IRA-Arrant
# Copied: MiguelPazo_pulumi_aws_create_database
# Copied: taskforcesh_pulumi-external-dns
# Copied: mattiasholm_code
# Copied: gobengo_activitypub.com
# Copied: undrash_pulumi-testing
# Copied: deepakkt_digitalocean-pulumi
# Copied: OrejiNet_Practica-Pulumi
# Copied: matrixbegins_uni-demo-deploy
# Copied: aeons_aeons.dk
# Copied: etherdata-blockchain_config
# Copied: yoshikyoto_cdktf-sample-app
# Copied: zack-schrag_snap-secret
# Copied: ansgarm_test-cdktf-go-count
# Copied: chrisguest75_terraform_examples
# Failed: eesvara5512_terraform-samples [('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/internals', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/docs/internals', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/internals'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/cli', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/docs/cli', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/cli'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/configuration', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/docs/configuration', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/configuration'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/language', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/docs/language', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/language'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/configuration-0-11', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/docs/configuration-0-11', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/configuration-0-11'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/providers/index.html.markdown', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/docs/providers/index.html.markdown', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/docs/providers/index.html.markdown'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/layouts/downloads.erb', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/layouts/downloads.erb', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/layouts/downloads.erb'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/layouts/intro.erb', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/layouts/intro.erb', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/layouts/intro.erb'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/layouts/language.erb', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/layouts/language.erb', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/layouts/language.erb'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/layouts/docs.erb', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/layouts/docs.erb', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/layouts/docs.erb'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/intro', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/intro', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/intro'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/guides', 'iac_subset/eesvara5512_terraform-samples/terraform-website/content/source/guides', "[Errno 2] No such file or directory: 'iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/guides'"), ('iac_repos/eesvara5512_terraform-samples/terraform-website/content/source/upgrade-guides', 'iac_sub ...
# Failed: nullify005_HomeAssistant [('iac_repos/nullify005_HomeAssistant/app/config/service_account.json', 'iac_subset/nullify005_HomeAssistant/app/config/service_account.json', "[Errno 2] No such file or directory: 'iac_repos/nullify005_HomeAssistant/app/config/service_account.json'"), ('iac_repos/nullify005_HomeAssistant/app/config/secrets.yaml', 'iac_subset/nullify005_HomeAssistant/app/config/secrets.yaml', "[Errno 2] No such file or directory: 'iac_repos/nullify005_HomeAssistant/app/config/secrets.yaml'")]
# Copied: Mattaparthi321_my-teraform-code
# Copied: Oxiang_AffinidiHotelKYC
# Copied: azul915_cron-serverless-pulumi
# Copied: LachlanStevens_UntitledStack-3
# Copied: weaveworks-training_gitopsdays-2020
# Copied: jaxxstorm_pulumi-component-workshop
# Copied: kim-hangyeol_hcp
# Copied: tenwit_pulumi_examples
# Copied: jaxxstorm_pulumi-automationapi-workshop
# Copied: aaronaddleman_cdktf-typescript-docker
# Copied: Neverwas-dev_unchained
# Copied: sirJiggles_boxing-robot
# Copied: squaremo_pulumi-localprocess
# Copied: dangitsdavid_pulumi-clnode
# Copied: FriendlyUser_stock-pulumi
# Copied: varokas_db-trends
# Copied: ansgarm_cdktf-github-duty
# Copied: zeagord_lightsail-wordpress-cdk-starter
# Copied: shahiddev_pulumi-autoscale-bug
# Copied: cloudvietnam18_git-pulumi
# Copied: ChristoMI_Web_Backend
# Copied: ukautz_cdktf-inconsistent-name-bug
# Copied: vidarbha_pulumi
# Copied: filip-zyzniewski_pulumi
# Copied: phillipedwards_aws-ts-apigw-lambda
# Copied: nmora53_PowerDialer_quero_educ
# Copied: abatilo_ec2throughput.info
# Copied: emilytrau_cloudburst
# Copied: djsd123_s3-static-website
# Copied: staeff_aws-infra
# Copied: DanielMSchmidt_terraform-cdk-hybrid-module-publishing-on-gh-packages
# Copied: MiguelPazo_pulumi_aws_sync_s3
# Copied: kay-is_pulumi-cloudflare-upstash
# Copied: kaiquelupo_preview-dialer
# Copied: pulumi_docs
# Copied: jjgrinwis_pulumi-property
# Copied: dave-burke_rpn-calc
# Copied: kane-armstrong_kanebernetes
# Copied: honghyeong_MLOpsCurriculum-nestjs
# Copied: ElderMael_micronaut-pulumi-k8s-example
# Copied: mbergal_sam-app
# Copied: cheab-org_infra
# Copied: taiyeoguns_pulumi-azure-func-trial
# Copied: mpnsk_xingedin
# Copied: juniorcesar_apresentacao-pulumi
# Copied: Kurabu-chan_Kurabu
# Copied: cjh-cloud_pulumi_ecr_example
# Copied: bdelmas_pulumi-quickstart
# Copied: davetrainer_api-container-app
# Copied: luistrigueiros_quickstart-pulumi-k8s-kotlin
# Copied: mikhailshilkov_fosdem2019
# Copied: rumsrami_drone-ecs
# Copied: ddunkin_pulumi-docker
# Copied: nicklofaso_sandbox-cicd
# Copied: DanielMSchmidt_cdktf-github-actions-local-demo
# Copied: AI2Incubator_AI2I_webapp
# Copied: caiokf_service-template
# Copied: philhub85_51922
# Copied: marcindulak_azure-ml-aks-intro
# Copied: decentraland_add-mana
# Copied: recumbent_ddd-2020
# Copied: DevOpsRandD_iac_cdk_pulumi_terraform
# Copied: koffe0522_cdktf-templates
# Copied: michaeldbianchi_mercury-platform
# Copied: hossambarakat_pulumi-demos
# Copied: decentraland_agora
# Copied: lbrlabs_pulumi-homelab
# Copied: JessicaRudd_mlplatform-infra
# Copied: macagr_cloud-metadata-endpoints-examples
# Copied: pulumi_pulumi-component-provider-go-boilerplate
# Copied: skurik_pulumi-workspace-repro
# Copied: rraval_zeroindexed
# Copied: pulumi_pulumi-azure-quickstart-acr-geo-replication
# Copied: AdminTurnedDevOps_pulumi-in-azure
# Copied: BITOCTA_diagrams-article-example
# Copied: asixdev0082_nft-market
# Copied: ggipson2_herocool
# Copied: jaxxstorm_iac-in-go
# Copied: petabridge_AkkaDotNet.LargeNetworkTests
# Copied: goawsgo_aws-cloud-edge-pulumi
# Copied: lechuckroh_aws-lambda-grpc-proxy-go
# Copied: sacloud_pulumi-sakuracloud
# Copied: pulumiverse_pulumi-aws-eksa
# Copied: davidNHK_project-bootstrap
# Copied: pierskarsenbarg_workshop-labs
# Copied: creatorsgarten_eventkit
# Copied: pulumi_pulumi-aws
# Copied: dnhook123_dsfasdfasdfadsf
# Copied: umerpirwani_Nft.marketplace
# Copied: trifoliumproj_infrastructure
# Copied: pulumi_get.pulumi.com
# Copied: n0npax_lime-comb
# Copied: sashaaKr_aws_pulumi_go
# Copied: cloud-hybrid_constructs
# Copied: Mauwii_azure-pipelines-with-github-repo
# Copied: Aristohack_jowen
# Copied: OctopusSamples_pulumi-python-azure
# Copied: RainRush_generator-react-ci-iac
# Copied: danieldspx_pulumi-ecs-example
# Copied: lreimer_clean-infrastructure-as-code
# Copied: jessicaUP_CloudVisitCount
# Copied: hryang_pulumi-jenkins-example
# Copied: jaxxstorm_pulumi-productionapp
# Copied: stack72_pulumi-gitlab-runner
# Copied: maxmlv_paas-coud
# Copied: goFrendiAsgard_pyconid-pulumi
# Copied: dixler_jdconf-2022-platform-stack
# Copied: LeonidChetverikov_pulumi
# Copied: xai1983kbu_pulumi_appsync_with_direct_lambda_to_dynamodb
# Copied: ikozinov_pulumi-k3s-provisioner
# Copied: jguadagno_jjgnet-broadcast
# Copied: trif0lium_stellaris
# Copied: seandavi_Orchestra
# Copied: andrewlaskey_pulumi-example
# Copied: ringods_aws-lambda-changelogger
# Copied: diego3g_pulumi-lambda-mail-queue
# Copied: Pro-Coded_pro-hybrid-serverless
# Copied: cjh-cloud_esp32_pwa_starter
# Copied: ChanghoonHyun_cdktf-example
# Copied: pulumi_pulumi-artifactory
# Copied: wanghao1891_sample
# Copied: MindLeaps_tracker
# Copied: pulumi_pulumi-sumologic
# Copied: clstokes_pulumi-aws-ts-ecs-existing-vpc
# Copied: edalongeville_pulumi_sample_certificate
# Copied: fedemarchini_TestGitActions
# Copied: lmayorga1980_gcp-cdktf-example
# Copied: coding-flamingo_PulumiAKVwithServicebus
# Copied: ChrisBellew_bellewmi
# Copied: mattstratton_awesome-azure
# Copied: djsd123_s3-static-website-native
# Copied: MitchellGerdisch_pulumi-codefresh
# Copied: pavan8855_enthire
# Copied: jonashackt_tekton-argocd-eks
# Copied: jahskee_mono-seven
# Copied: Pocket_curation-tools-data-sync
# Copied: amart78_tinderFurever
# Copied: dgg32_pulumi_quickstart
# Copied: neilkuan_pulumi-cdk-example
# Copied: danfhernandez_ecs-cluster
# Copied: iotv_web
# Copied: melihyazgan_IaC_pipeline
# Copied: ptavoni_forgeops
# Copied: igoran_dnc-mlops-model-serving
# Copied: frezbo_pulumi-provider-kind
# Copied: pulumi_pulumi-azure-quickstart-compute
# Copied: jmgilman_glab
# Copied: proxima-one_mangrove-offchain-server
# Copied: nojaf_apim
# Copied: alexhwoods_super-pulumi
# Copied: unmango_safir-infra
# Copied: TheEdgeOfCat_iac_comparison
# Copied: redhwannacef_youtube-tutorials
# Copied: fpommerening_DevOpenSpace2019
# Copied: mescam_psr2021
# Copied: rv-terraform_cdktf-test
# Copied: KYSinc_Terraform-firstcourse
# Copied: VestiDev_python_devops_2019-book
# Copied: PHONGLEX_fastapi_pulumi_practice
# Copied: dtorresf_iac
# Copied: goawsgo_aws-ekk-pulumi
# Copied: shtakai_poc-pulumi-aws
# Copied: paulrobello_localstack_cloud_front_bug
# Copied: rhyek_ynab-banco-industrial-connector
# Copied: willgarcia_rotc
# Copied: skorfmann_cdktf-provider-aws
# Copied: swapnilmmane_cicd
# Copied: azeemqf_pulumi-azure
# Copied: unmango_pulumi-homelab
# Copied: benesch_pulumi-bug-eks
# Copied: justinvp_templates
# Copied: JohannesKonings_test-cdktf
# Copied: drsahook_pulumirepo
# Copied: Josh-Tilles_MC-issues
# Copied: populationgenomics_cpg-infrastructure
# Copied: vargasarts_samepage.network
# Copied: nunciato_infra
# Copied: jaxxstorm_brig.gs
# Copied: featurehub-io_featurehub
# Copied: sthuck_duckduckstay
# Copied: shihtzu-systems_moonlight
# Copied: ahmadalibagheri_cdktf-typescript-aws-vpc
# Copied: skill-collectors_agile-poker
# Copied: icgam_Pulumi.Samples
# Copied: ministryofjustice_analytical-platform-infrastructure-pulumi
# Copied: ederst_pulumi-in-a-pickle
# Copied: gkonc001_pulumi-python-pmi
# Copied: shanmu-ss_wp-pulumi
# Copied: fuluteam_honeycomb
# Copied: chernandez83_HeroCool

# %%
import os, pandas as pd

features = []

for root, _, files in os.walk("iac_subset"):
    for f in files:
        if f.endswith((".tf", ".json", ".yml", ".yaml", ".bicep")):
            path = os.path.join(root, f)

            try:
                size = os.path.getsize(path)
                if size > 1_000_000:  # Skip >1MB files
                    continue

                # quick check if file is readable
                valid = False
                try:
                    with open(path, "r", errors="ignore") as raw:
                        snippet = raw.read(300).lower()
                        valid = True if snippet else False
                except:
                    snippet = ""

                features.append({
                    "repo": os.path.basename(root),
                    "file": f,
                    "type": f.split(".")[-1],
                    "size_bytes": size,
                    "lines": sum(1 for _ in open(path, "r", errors="ignore")),
                    "parsed": valid,
                    "raw_text_snippet": snippet
                })
            except Exception:
                pass

df = pd.DataFrame(features)
df.to_csv("iac_features_raw.csv", index=False)
print("✅ Saved parsed base dataset to iac_features_raw.csv")
print("Total IaC files parsed:", len(df))
print(df.head())
# Out:
# ✅ Saved parsed base dataset to iac_features_raw.csv
# Total IaC files parsed: 35816
#                       repo               file  type  size_bytes  lines  \
# 0  gobengo_activitypub.com   Pulumi.prod.yaml  yaml         281      7
# 1  gobengo_activitypub.com  package-lock.json  json      118347   2557
# 2  gobengo_activitypub.com        Pulumi.yaml  yaml          97      3
# 3  gobengo_activitypub.com       package.json  json         343     14
# 4  gobengo_activitypub.com    Pulumi.dev.yaml  yaml         321      7
#
#    parsed                                   raw_text_snippet
# 0    True  config:\n  activitypub.com-cloud:apex-dns-stac...
# 1    True  {\n    "name": "activitypub.com-cloud",\n    "...
# 2    True  name: activitypub.com-cloud\nruntime: nodejs\n...
# 3    True  {\n    "name": "activitypub.com-cloud",\n    "...
# 4    True  config:\n  activitypub.com-cloud:apex-dns-stac...

# %%
import os
import pandas as pd
from tqdm import tqdm

# Define IaC file extensions
iac_exts = (".tf", ".json", ".yaml", ".yml", ".bicep")
base_dir = "iac_repos"

records = []

# Walk all repos
for repo in tqdm(os.listdir(base_dir), desc="Repos"):
    repo_path = os.path.join(base_dir, repo)
    for root, dirs, files in os.walk(repo_path):
        for f in files:
            if f.endswith(iac_exts) or f.lower() in ["cdktf.json", "pulumi.yaml"]:
                file_path = os.path.join(root, f)
                try:
                    with open(file_path, "r", encoding="utf-8", errors="ignore") as fh:
                        content = fh.read()
                    records.append({
                        "repo": repo,
                        "file": os.path.relpath(file_path, repo_path),
                        "type": f.split(".")[-1].lower(),
                        "size_bytes": os.path.getsize(file_path),
                        "lines": content.count("\n") + 1,
                        "full_content": content
                    })
                except Exception as e:
                    print(f"⚠️ Error reading {file_path}: {e}")

# Convert to DataFrame
df = pd.DataFrame(records)
print("Total IaC files parsed:", df.shape[0])

# Save as Parquet (compressed, efficient)
df.to_parquet("iac_files_full.parquet", engine="pyarrow", compression="snappy")

print("✅ Saved full IaC dataset to iac_files_full.parquet")
# Out:
# Repos:  60%|█████▉    | 561/936 [00:13<00:08, 42.91it/s]
# ⚠️ Error reading iac_repos/nullify005_HomeAssistant/app/config/service_account.json: [Errno 2] No such file or directory: 'iac_repos/nullify005_HomeAssistant/app/config/service_account.json'
# ⚠️ Error reading iac_repos/nullify005_HomeAssistant/app/config/secrets.yaml: [Errno 2] No such file or directory: 'iac_repos/nullify005_HomeAssistant/app/config/secrets.yaml'
# Repos: 100%|██████████| 936/936 [00:27<00:00, 34.03it/s]
# Total IaC files parsed: 35278
# ✅ Saved full IaC dataset to iac_files_full.parquet

# %%
# Colab-specific drive mount removed for local execution
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Skipping Google Drive backup when running locally.
print('Skipping Drive backup; running locally.')
# Out:
# ✅ Backup saved to Google Drive at /content/drive/MyDrive/iac_files_full.parquet

# %%
# If checkov is not installed, run: pip install checkov
# Out:
# Collecting checkov
#   Downloading checkov-3.2.473-py3-none-any.whl.metadata (26 kB)
# Collecting bc-python-hcl2==0.4.3 (from checkov)
#   Downloading bc_python_hcl2-0.4.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting bc-detect-secrets==1.5.45 (from checkov)
#   Downloading bc_detect_secrets-1.5.45-py3-none-any.whl.metadata (23 kB)
# Collecting bc-jsonpath-ng==1.6.1 (from checkov)
#   Downloading bc_jsonpath_ng-1.6.1-py3-none-any.whl.metadata (17 kB)
# Collecting pycep-parser==0.5.1 (from checkov)
#   Downloading pycep_parser-0.5.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (0.9.0)
# Collecting colorama<0.5.0,>=0.4.3 (from checkov)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting termcolor<2.4.0,>=1.1.0 (from checkov)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting junit-xml<2.0,>=1.9 (from checkov)
#   Downloading junit_xml-1.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting dpath==2.1.3 (from checkov)
#   Downloading dpath-2.1.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (6.0.2)
# Collecting boto3==1.35.49 (from checkov)
#   Downloading boto3-1.35.49-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.30 in /usr/local/lib/python3.12/dist-packages (from checkov) (3.1.45)
# Collecting jmespath<2.0.0,>=1.0.0 (from checkov)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (4.67.1)
# Collecting packaging<24.0,>=23.0 (from checkov)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting cloudsplaining<0.8.0,>=0.7.0 (from checkov)
#   Downloading cloudsplaining-0.7.0-py3-none-any.whl.metadata (21 kB)
# Collecting networkx<2.7 (from checkov)
#   Downloading networkx-2.6.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting dockerfile-parse<3.0.0,>=2.0.0 (from checkov)
#   Downloading dockerfile_parse-2.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting docker<8.0.0,>=6.0.1 (from checkov)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting configargparse<2.0.0,>=1.5.3 (from checkov)
#   Downloading configargparse-1.7.1-py3-none-any.whl.metadata (24 kB)
# Collecting argcomplete<4.0.0,>=3.0.0 (from checkov)
#   Downloading argcomplete-3.6.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (4.15.0)
# Collecting importlib-metadata<8.0.0,>=6.0.0 (from checkov)
#   Downloading importlib_metadata-7.2.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: cachetools<6.0.0,>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (5.5.2)
# Collecting cyclonedx-python-lib<8.0.0,>=6.0.0 (from checkov)
#   Downloading cyclonedx_python_lib-7.6.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting packageurl-python<0.14.0,>=0.11.1 (from checkov)
#   Downloading packageurl_python-0.13.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (8.2.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (3.12.15)
# Collecting aiodns<4.0.0,>=3.0.0 (from checkov)
#   Downloading aiodns-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting aiomultiprocess<0.10.0,>=0.9.0 (from checkov)
#   Downloading aiomultiprocess-0.9.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting schema<=0.7.5 (from checkov)
#   Downloading schema-0.7.5-py2.py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.17.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (4.25.1)
# Requirement already satisfied: prettytable<4.0.0,>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (3.16.0)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (3.4.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (2.32.4)
# Requirement already satisfied: yarl<2.0.0,>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from checkov) (1.20.1)
# Collecting spdx-tools<0.9.0,>=0.8.0 (from checkov)
#   Downloading spdx_tools-0.8.3-py3-none-any.whl.metadata (14 kB)
# Collecting license-expression<31.0.0,>=30.1.0 (from checkov)
#   Downloading license_expression-30.4.4-py3-none-any.whl.metadata (11 kB)
# Collecting rustworkx<1.0.0,>=0.13.0 (from checkov)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from checkov) (2.11.9)
# Collecting asteval==1.0.5 (from checkov)
#   Downloading asteval-1.0.5-py3-none-any.whl.metadata (6.2 kB)
# Collecting urllib3==1.26.20 (from checkov)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.5 MB/s eta 0:00:00
# Collecting unidiff (from bc-detect-secrets==1.5.45->checkov)
#   Downloading unidiff-0.7.5-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: ply in /usr/local/lib/python3.12/dist-packages (from bc-jsonpath-ng==1.6.1->checkov) (3.11)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from bc-jsonpath-ng==1.6.1->checkov) (4.4.2)
# Requirement already satisfied: lark>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bc-python-hcl2==0.4.3->checkov) (1.2.2)
# Collecting botocore<1.36.0,>=1.35.49 (from boto3==1.35.49->checkov)
#   Downloading botocore-1.35.99-py3-none-any.whl.metadata (5.7 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3==1.35.49->checkov)
#   Downloading s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from pycep-parser==0.5.1->checkov) (2024.11.6)
# Collecting pycares>=4.9.0 (from aiodns<4.0.0,>=3.0.0->checkov)
#   Downloading pycares-4.11.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->checkov) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->checkov) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->checkov) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->checkov) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->checkov) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->checkov) (0.3.2)
# Collecting cached-property (from cloudsplaining<0.8.0,>=0.7.0->checkov)
#   Downloading cached_property-2.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting click-option-group (from cloudsplaining<0.8.0,>=0.7.0->checkov)
#   Downloading click_option_group-0.5.7-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from cloudsplaining<0.8.0,>=0.7.0->checkov) (3.1.6)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from cloudsplaining<0.8.0,>=0.7.0->checkov) (3.9)
# Collecting policy-sentry<0.14,>=0.13.0 (from cloudsplaining<0.8.0,>=0.7.0->checkov)
#   Downloading policy_sentry-0.13.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting py-serializable<2.0.0,>=1.1.0 (from cyclonedx-python-lib<8.0.0,>=6.0.0->checkov)
#   Downloading py_serializable-1.1.2-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from cyclonedx-python-lib<8.0.0,>=6.0.0->checkov) (2.4.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4.0.0,>=3.1.30->checkov) (4.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.0.0,>=6.0.0->checkov) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.17.0->checkov) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.17.0->checkov) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.17.0->checkov) (0.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from junit-xml<2.0,>=1.9->checkov) (1.17.0)
# Collecting boolean.py>=4.0 (from license-expression<31.0.0,>=30.1.0->checkov)
#   Downloading boolean_py-5.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable<4.0.0,>=3.6.0->checkov) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->checkov) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->checkov) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->checkov) (0.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.0->checkov) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.0->checkov) (2025.8.3)
# Requirement already satisfied: numpy<3,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from rustworkx<1.0.0,>=0.13.0->checkov) (2.0.2)
# Collecting contextlib2>=0.5.5 (from schema<=0.7.5->checkov)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting xmltodict (from spdx-tools<0.9.0,>=0.8.0->checkov)
#   Downloading xmltodict-1.0.2-py3-none-any.whl.metadata (15 kB)
# Collecting rdflib (from spdx-tools<0.9.0,>=0.8.0->checkov)
#   Downloading rdflib-7.2.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beartype in /usr/local/lib/python3.12/dist-packages (from spdx-tools<0.9.0,>=0.8.0->checkov) (0.21.0)
# Collecting uritools (from spdx-tools<0.9.0,>=0.8.0->checkov)
#   Downloading uritools-5.0.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: semantic-version in /usr/local/lib/python3.12/dist-packages (from spdx-tools<0.9.0,>=0.8.0->checkov) (2.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.36.0,>=1.35.49->boto3==1.35.49->checkov) (2.9.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.30->checkov) (5.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from policy-sentry<0.14,>=0.13.0->cloudsplaining<0.8.0,>=0.7.0->checkov) (4.13.5)
# Requirement already satisfied: orjson in /usr/local/lib/python3.12/dist-packages (from policy-sentry<0.14,>=0.13.0->cloudsplaining<0.8.0,>=0.7.0->checkov) (3.11.3)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from py-serializable<2.0.0,>=1.1.0->cyclonedx-python-lib<8.0.0,>=6.0.0->checkov) (0.7.1)
# Requirement already satisfied: cffi>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from pycares>=4.9.0->aiodns<4.0.0,>=3.0.0->checkov) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->cloudsplaining<0.8.0,>=0.7.0->checkov) (3.0.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from rdflib->spdx-tools<0.9.0,>=0.8.0->checkov) (3.2.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.5.0->pycares>=4.9.0->aiodns<4.0.0,>=3.0.0->checkov) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->policy-sentry<0.14,>=0.13.0->cloudsplaining<0.8.0,>=0.7.0->checkov) (2.8)
# Downloading checkov-3.2.473-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 37.6 MB/s eta 0:00:00
# Downloading asteval-1.0.5-py3-none-any.whl (21 kB)
# Downloading bc_detect_secrets-1.5.45-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 9.7 MB/s eta 0:00:00
# Downloading bc_jsonpath_ng-1.6.1-py3-none-any.whl (29 kB)
# Downloading bc_python_hcl2-0.4.3-py3-none-any.whl (15 kB)
# Downloading boto3-1.35.49-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 14.1 MB/s eta 0:00:00
# Downloading dpath-2.1.3-py3-none-any.whl (17 kB)
# Downloading pycep_parser-0.5.1-py3-none-any.whl (23 kB)
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 13.2 MB/s eta 0:00:00
# Downloading aiodns-3.5.0-py3-none-any.whl (8.1 kB)
# Downloading aiomultiprocess-0.9.1-py3-none-any.whl (17 kB)
# Downloading argcomplete-3.6.2-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.3 MB/s eta 0:00:00
# Downloading cloudsplaining-0.7.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 71.5 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading configargparse-1.7.1-py3-none-any.whl (25 kB)
# Downloading cyclonedx_python_lib-7.6.2-py3-none-any.whl (361 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.4/361.4 kB 29.6 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 12.6 MB/s eta 0:00:00
# Downloading dockerfile_parse-2.0.1-py2.py3-none-any.whl (14 kB)
# Downloading importlib_metadata-7.2.1-py3-none-any.whl (25 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading junit_xml-1.9-py2.py3-none-any.whl (7.1 kB)
# Downloading license_expression-30.4.4-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.6/120.6 kB 9.8 MB/s eta 0:00:00
# Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 76.9 MB/s eta 0:00:00
# Downloading packageurl_python-0.13.4-py3-none-any.whl (26 kB)
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.4 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 76.3 MB/s eta 0:00:00
# Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Downloading spdx_tools-0.8.3-py3-none-any.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.4/285.4 kB 22.2 MB/s eta 0:00:00
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Downloading boolean_py-5.0-py3-none-any.whl (26 kB)
# Downloading botocore-1.35.99-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 105.4 MB/s eta 0:00:00
# Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Downloading policy_sentry-0.13.2-py3-none-any.whl (966 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 966.6/966.6 kB 58.9 MB/s eta 0:00:00
# Downloading py_serializable-1.1.2-py3-none-any.whl (22 kB)
# Downloading pycares-4.11.0-cp312-cp312-manylinux_2_28_x86_64.whl (641 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 641.1/641.1 kB 47.8 MB/s eta 0:00:00
# Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 7.9 MB/s eta 0:00:00
# Downloading cached_property-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading click_option_group-0.5.7-py3-none-any.whl (11 kB)
# Downloading rdflib-7.2.1-py3-none-any.whl (565 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.4/565.4 kB 42.7 MB/s eta 0:00:00
# Downloading unidiff-0.7.5-py2.py3-none-any.whl (14 kB)
# Downloading uritools-5.0.0-py3-none-any.whl (10 kB)
# Downloading xmltodict-1.0.2-py3-none-any.whl (13 kB)
# Installing collected packages: unidiff, boolean.py, xmltodict, urllib3, uritools, termcolor, rustworkx, rdflib, pycep-parser, py-serializable, packaging, packageurl-python, networkx, license-expression, junit-xml, jmespath, importlib-metadata, dpath, dockerfile-parse, contextlib2, configargparse, colorama, click-option-group, cached-property, bc-python-hcl2, bc-jsonpath-ng, asteval, argcomplete, aiomultiprocess, spdx-tools, schema, pycares, cyclonedx-python-lib, botocore, s3transfer, policy-sentry, docker, bc-detect-secrets, aiodns, boto3, cloudsplaining, checkov
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.1.0
#     Uninstalling termcolor-3.1.0:
#       Successfully uninstalled termcolor-3.1.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.5
#     Uninstalling networkx-3.5:
#       Successfully uninstalled networkx-3.5
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.7.0
#     Uninstalling importlib_metadata-8.7.0:
#       Successfully uninstalled importlib_metadata-8.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 3.38.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# scikit-image 0.25.2 requires networkx>=3.0, but you have networkx 2.6.3 which is incompatible.
# nx-cugraph-cu12 25.6.0 requires networkx>=3.2, but you have networkx 2.6.3 which is incompatible.
# xarray 2025.9.0 requires packaging>=24.1, but you have packaging 23.2 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# Successfully installed aiodns-3.5.0 aiomultiprocess-0.9.1 argcomplete-3.6.2 asteval-1.0.5 bc-detect-secrets-1.5.45 bc-jsonpath-ng-1.6.1 bc-python-hcl2-0.4.3 boolean.py-5.0 boto3-1.35.49 botocore-1.35.99 cached-property-2.0.1 checkov-3.2.473 click-option-group-0.5.7 cloudsplaining-0.7.0 colorama-0.4.6 configargparse-1.7.1 contextlib2-21.6.0 cyclonedx-python-lib-7.6.2 docker-7.1.0 dockerfile-parse-2.0.1 dpath-2.1.3 importlib-metadata-7.2.1 jmespath-1.0.1 junit-xml-1.9 license-expression-30.4.4 networkx-2.6.3 packageurl-python-0.13.4 packaging-23.2 policy-sentry-0.13.2 py-serializable-1.1.2 pycares-4.11.0 pycep-parser-0.5.1 rdflib-7.2.1 rustworkx-0.17.1 s3transfer-0.10.4 schema-0.7.5 spdx-tools-0.8.3 termcolor-2.3.0 unidiff-0.7.5 uritools-5.0.0 urllib3-1.26.20 xmltodict-1.0.2

# %%
import pandas as pd
df = pd.read_parquet("iac_files_full.parquet")
print(df.shape)
# Out:
# (35278, 6)

# %%
import os

subset_dir = "iac_subset"
iac_files = []

for root, _, files in os.walk(subset_dir):
    for f in files:
        if f.endswith((".tf", ".yaml", ".yml", ".json", ".bicep")):
            path = os.path.join(root, f)
            with open(path, "r", errors="ignore") as fh:
                head = fh.read(200).lower()
                # Look for IaC markers
                if any(keyword in head for keyword in ["resource", "provider", "apiVersion", "kind", "Resources:"]):
                    iac_files.append(path)

print("Found IaC-like files:", len(iac_files))
print("Examples:")
for f in iac_files[:5]:
    print(" -", f)
# Out:
# Found IaC-like files: 11895
# Examples:
#  - iac_subset/paiml_python_devops_book/src/chap10-InfraAsCode/terraform/main.tf
#  - iac_subset/paiml_python_devops_book/src/chap10-InfraAsCode/terraform/modules/route53/main.tf
#  - iac_subset/paiml_python_devops_book/src/chap10-InfraAsCode/terraform/modules/s3/main.tf
#  - iac_subset/paiml_python_devops_book/src/chap10-InfraAsCode/terraform/modules/cloudfront/main.tf
#  - iac_subset/paiml_python_devops_book/src/chap10-InfraAsCode/terraform/modules/acm/main.tf

# %%
import subprocess, json

# Use explicit Checkov command path found on this Windows system
CHECKOV_CMD = r"C:\Users\chava\AppData\Roaming\Python\Python311\Scripts\checkov.cmd"

def run_checkov(file_path, timeout=30):
    """Run Checkov on one file and return parsed JSON result."""
    try:
        cmd = [CHECKOV_CMD, "-f", file_path, "-o", "json"]
        out = subprocess.run(cmd, capture_output=True, text=True, timeout=timeout)
        if out.returncode == 0 and out.stdout.strip():
            return json.loads(out.stdout)
        else:
            # Print stderr for clearer diagnostics
            stderr = out.stderr.strip() if out and out.stderr else ''
            print(f"⚠️ Checkov returned no results or error on {file_path}: rc={out.returncode}, stderr={stderr}")
    except subprocess.TimeoutExpired:
        print(f"⏳ Timeout on {file_path}")
    except Exception as e:
        print(f"⚠️ Error running Checkov on {file_path}: {e}")
    return None

# %%
test_file = "iac_subset/paiml_python_devops_book/src/chap10-InfraAsCode/terraform/main.tf"
result = run_checkov(test_file, timeout=30)

if result and "results" in result:
    failed = result["results"].get("failed_checks", [])
    print("🔍 File:", test_file)
    print("   Failed checks:", len(failed))
    if failed:
        print("   Example issue:", failed[0].get("check_id"), "-", failed[0].get("check_name"))
else:
    print("❌ No result")
# Out:
# 🔍 File: iac_subset/paiml_python_devops_book/src/chap10-InfraAsCode/terraform/main.tf
#    Failed checks: 0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
df = pd.DataFrame(results)

# Save initial Checkov results locally
save_path = "checkov_results_local.csv"
df.to_csv(save_path, index=False)

print(f"✅ Initial Checkov results saved to {save_path}")
print("Shape:", df.shape)
print(df.head())
# Out:
# ✅ Initial Checkov results saved to /content/drive/MyDrive/checkov_results_partial.csv
# Shape: (2, 6)
#                                                 file     check_id  \
# 0  iac_subset/paiml_python_devops_book/src/chap10...   CKV_AWS_70
# 1  iac_subset/paiml_python_devops_book/src/chap10...  CKV_AWS_310
#
#                                           check_name severity  \
# 0  Ensure S3 bucket does not allow an action with...     HIGH
# 1  Ensure CloudFront distributions should have or...   MEDIUM
#
#                               resource  \
# 0                aws_s3_bucket.example
# 1  aws_cloudfront_distribution.example
#
#                                            guideline
# 0  https://docs.bridgecrew.io/docs/s3_1-acl-read-...
# 1  https://docs.bridgecrew.io/docs/cloudfront_1-e...

# %%
# Running locally: Google Colab drive mount is not available in this environment.
# If you run on Colab and need to remount, call: drive.mount('/content/drive', force_remount=True)
print('Running locally; not attempting to mount /content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# Load local parquet and checkov CSV if available
try:
    df = pd.read_parquet("iac_files_full.parquet")
except Exception as e:
    print('Failed to load iac_files_full.parquet:', e)
    df = pd.DataFrame()
try:
    scanned = pd.read_csv("checkov_results_local.csv")
except Exception:
    scanned = pd.DataFrame()
print('IaC rows:', getattr(df, 'shape', None), 'Checkov rows:', getattr(scanned, 'shape', None))
# Out:
# (35278, 6) (2, 6)

# %%
# Colab-specific drive mount removed for local execution

# Load parsed IaC dataset from local path if available
import pandas as pd
try:
    iac_files = pd.read_parquet("iac_files_full.parquet")
    print("IaC dataset loaded:", iac_files.shape)
except FileNotFoundError:
    print("Local iac_files_full.parquet not found. Skipping this step.")

# Load Checkov results (if exists)
try:
    checkov_results = pd.read_csv("checkov_results_partial.csv")
    print("Checkov results loaded:", checkov_results.shape)
except FileNotFoundError:
    checkov_results = pd.DataFrame(columns=["file","check_id","check_name","severity","resource","guideline"])
    print("No existing Checkov results, starting fresh")

# Show samples (if available)
try:
    display(iac_files.head())
except Exception:
    pass
try:
    display(checkov_results.head())
except Exception:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# IaC dataset loaded: (35278, 6)
# Checkov results loaded: (2, 6)
#                       repo               file  type  size_bytes  lines  \
# 0  gobengo_activitypub.com   Pulumi.prod.yaml  yaml         281      8
# 1  gobengo_activitypub.com  package-lock.json  json      118347   2558
# 2  gobengo_activitypub.com        Pulumi.yaml  yaml          97      4
# 3  gobengo_activitypub.com       package.json  json         343     15
# 4  gobengo_activitypub.com    Pulumi.dev.yaml  yaml         321      8
#
#                                         full_content
# 0  config:\n  activitypub.com-cloud:apex-dns-stac...
# 1  {\n    "name": "activitypub.com-cloud",\n    "...
# 2  name: activitypub.com-cloud\nruntime: nodejs\n...
# 3  {\n    "name": "activitypub.com-cloud",\n    "...
# 4  config:\n  activitypub.com-cloud:apex-dns-stac...
#                                                 file     check_id  \
# 0  iac_subset/paiml_python_devops_book/src/chap10...   CKV_AWS_70
# 1  iac_subset/paiml_python_devops_book/src/chap10...  CKV_AWS_310
#
#                                           check_name severity  \
# 0  Ensure S3 bucket does not allow an action with...     HIGH
# 1  Ensure CloudFront distributions should have or...   MEDIUM
#
#                               resource  \
# 0                aws_s3_bucket.example
# 1  aws_cloudfront_distribution.example
#
#                                            guideline
# 0  https://docs.bridgecrew.io/docs/s3_1-acl-read-...
# 1  https://docs.bridgecrew.io/docs/cloudfront_1-e...

# %%
# Aggregate Checkov findings per file and merge with IaC dataset
import pandas as pd

# Ensure datasets exist
try:
    iac_files = pd.read_parquet("iac_files_full.parquet")
    print('Loaded iac_files_full.parquet:', iac_files.shape)
except Exception as e:
    print('iac_files_full.parquet not available locally:', e)
    iac_files = pd.DataFrame()

try:
    checkov_results = pd.read_csv("checkov_results_local.csv")
    print('Loaded checkov_results_local.csv:', checkov_results.shape)
except Exception as e:
    print('checkov_results_local.csv not available:', e)
    checkov_results = pd.DataFrame(columns=["file","check_id","check_name","severity","resource","guideline"]) 

# If Checkov results are present, aggregate per file
if not checkov_results.empty:
    # Group check_ids and severities per file
    agg = checkov_results.groupby('file').agg({
        'check_id': lambda ids: list(pd.unique([i for i in ids if pd.notna(i)])),
        'severity': lambda s: list(pd.unique([i for i in s if pd.notna(i)])),
        'check_name': lambda names: list(pd.unique([n for n in names if pd.notna(n)])),
        'resource': lambda r: list(pd.unique([x for x in r if pd.notna(x)])),
    }).reset_index()
    agg = agg.rename(columns={'check_id': 'check_ids', 'severity': 'severities', 'check_name': 'check_names', 'resource': 'resources'})
else:
    agg = pd.DataFrame(columns=['file','check_ids','severities','check_names','resources'])

# Merge with IaC files (if available). The 'file' column in checkov_results likely contains full paths; attempt to match on suffix.
if not iac_files.empty and not agg.empty:
    # Normalize file paths: make both use forward slashes and compare suffixes
    iac_files['normalized_path'] = iac_files['file'].str.replace('\\\\', '/', regex=True)
    agg['normalized_file'] = agg['file'].str.replace('\\\\', '/', regex=True)

    # Attempt direct join first
    merged = iac_files.merge(agg, left_on='file', right_on='file', how='left')

    # If no matches, try matching by suffix (endswith)
    if merged['check_ids'].isna().all():
        print('Direct file join yielded no matches; attempting suffix match')
        # Build a mapping from basename or suffix to agg row
        agg_indexed = agg.set_index('file')
        def find_checks_for_path(path):
            # exact
            if path in agg_indexed.index:
                return agg_indexed.loc[path].to_dict()
            # suffix match
            for k in agg_indexed.index:
                if path.endswith(k):
                    return agg_indexed.loc[k].to_dict()
            return {'check_ids': [], 'severities': [], 'check_names': [], 'resources': []}

        merged_rows = []
        for _, row in iac_files.iterrows():
            path = row['file']
            checks = find_checks_for_path(path)
            new = row.to_dict()
            new.update(checks)
            merged_rows.append(new)
        merged = pd.DataFrame(merged_rows)
else:
    # If IaC files not available, just save aggregated Checkov results
    if not agg.empty:
        merged = agg.copy()
    else:
        merged = pd.DataFrame()

# Save merged output
out_path = 'iac_with_checkov.csv'
try:
    merged.to_csv(out_path, index=False)
    print('Saved merged IaC + Checkov to', out_path)
    print('Merged shape:', getattr(merged, 'shape', None))
except Exception as e:
    print('Failed to save merged CSV:', e)

# Show sample rows
try:
    display(merged.head())
except Exception:
    print('Merged preview not available')
# Out:
# iac_files_full.parquet not available locally: [Errno 2] No such file or directory: 'iac_files_full.parquet'
# Loaded checkov_results_local.csv: (206, 2)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 22
#      19 # If Checkov results are present, aggregate per file
#      20 if not checkov_results.empty:
#      21     # Group check_ids and severities per file
# ---> 22     agg = checkov_results.groupby('file').agg({
#      23         'check_id': lambda ids: list(pd.unique([i for i in ids if pd.notna(i)])),
#      24         'severity': lambda s: list(pd.unique([i for i in s if pd.notna(i)])),
#      25         'check_name': lambda names: list(pd.unique([n for n in names if pd.notna(n)])),
#      26         'resource': lambda r: list(pd.unique([x for x in r if pd.notna(x)])),
#      27     }).reset_index()
#      28     agg = agg.rename(columns={'check_id': 'check_ids', 'severity': 'severities', 'check_name': 'check_names', 'resource': 'resources'})
#      29 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'file'

# %%
# Diagnostic: inspect checkov results CSV structure
import pandas as pd
import os

csv_path = 'checkov_results_local.csv'
if os.path.exists(csv_path):
    df_check = pd.read_csv(csv_path)
    print('Shape:', df_check.shape)
    print('\nColumns:')
    print(df_check.columns.tolist())
    print('\nDtypes:')
    print(df_check.dtypes)
    print('\nSample rows:')
    display(df_check.head(10))
else:
    print('No checkov_results_local.csv found')
# Out:
# Shape: (103, 2)
#
# Columns:
# ['target', 'error']
#
# Dtypes:
# target    object
# error     object
# dtype: object
#
# Sample rows:
#                                               target  \
# 0  d:\CloudGuardAI\iac_subset\DanManson_gcp.iamCu...
# 1  d:\CloudGuardAI\iac_subset\ChanghoonHyun_cdktf...
# 2  d:\CloudGuardAI\iac_subset\Bharathkumarraju_gc...
# 3  d:\CloudGuardAI\iac_subset\AlfredoPardo-zz_pyt...
# 4  d:\CloudGuardAI\iac_subset\DanielMSchmidt_cdkt...
# 5  d:\CloudGuardAI\iac_subset\DanielMSchmidt_cdkt...
# 6  d:\CloudGuardAI\iac_subset\DanielMSchmidt_cdkt...
# 7  d:\CloudGuardAI\iac_subset\DanielMSchmidt_terr...
# 8  d:\CloudGuardAI\iac_subset\JakeGinnivan_pulumi...
# 9  d:\CloudGuardAI\iac_subset\DevOpsRandD_iac_cdk...
#
#                                                error
# 0  [WinError 193] %1 is not a valid Win32 applica...
# 1  [WinError 193] %1 is not a valid Win32 applica...
# 2  [WinError 193] %1 is not a valid Win32 applica...
# 3  [WinError 193] %1 is not a valid Win32 applica...
# 4  [WinError 193] %1 is not a valid Win32 applica...
# 5  [WinError 193] %1 is not a valid Win32 applica...
# 6  [WinError 193] %1 is not a valid Win32 applica...
# 7  [WinError 193] %1 is not a valid Win32 applica...
# 8  [WinError 193] %1 is not a valid Win32 applica...
# 9  [WinError 193] %1 is not a valid Win32 applica...

# %%
import os, subprocess, json, pandas as pd
from tqdm import tqdm

# Paths
subset_dir = "iac_subset"
results_path = "/content/drive/MyDrive/checkov_results_partial.csv"

# Load existing results
try:
    checkov_results = pd.read_csv(results_path)
    print("Loaded existing results:", checkov_results.shape)
except FileNotFoundError:
    checkov_results = pd.DataFrame(columns=["file","check_id","check_name","severity","resource","guideline"])
    print("No existing results, starting fresh")

# Collect IaC files
iac_files = []
for root, _, files in os.walk(subset_dir):
    for f in files:
        if f.endswith((".tf", ".json", ".yml", ".yaml", ".bicep")):
            iac_files.append(os.path.join(root, f))

print("Total IaC files:", len(iac_files))

# Remove files already scanned
done_files = set(checkov_results["file"].tolist())
pending_files = [f for f in iac_files if f not in done_files]
print("Already scanned:", len(done_files))
print("Pending:", len(pending_files))

def run_checkov(file_path, timeout=30):
    """Run checkov on one file with a timeout."""
    try:
        cmd = ["checkov", "-f", file_path, "-o", "json"]
        out = subprocess.run(cmd, capture_output=True, text=True, timeout=timeout)
        if out.returncode == 0 and out.stdout.strip():
            return json.loads(out.stdout)
    except subprocess.TimeoutExpired:
        print(f"⏳ Timeout on {file_path}")
    except Exception as e:
        print(f"⚠️ Error on {file_path}: {e}")
    return None

# Batch scanning (small chunks to be safe)
batch_size = 20
for i in tqdm(range(0, len(pending_files), batch_size), desc="Batches"):
    batch = pending_files[i:i+batch_size]
    new_results = []

    for file_path in batch:
        result = run_checkov(file_path, timeout=30)
        if result and "results" in result:
            for failed_check in result["results"].get("failed_checks", []):
                new_results.append({
                    "file": file_path,
                    "check_id": failed_check.get("check_id"),
                    "check_name": failed_check.get("check_name"),
                    "severity": failed_check.get("severity"),
                    "resource": failed_check.get("resource"),
                    "guideline": failed_check.get("guideline")
                })

    # Append new batch results
    if new_results:
        checkov_results = pd.concat([checkov_results, pd.DataFrame(new_results)], ignore_index=True)
        checkov_results.to_csv(results_path, index=False)
        print(f"💾 Saved progress: {checkov_results.shape}")

print("✅ Scanning finished")
# Out:
# Loaded existing results: (2, 6)
# Total IaC files: 35966
# Already scanned: 2
# Pending: 35964
# Batches:   0%|          | 0/1799 [00:33<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1526393695.py in <cell line: 0>()
#      49
#      50     for file_path in batch:
# ---> 51         result = run_checkov(file_path, timeout=30)
#      52         if result and "results" in result:
#      53             for failed_check in result["results"].get("failed_checks", []):
#
# /tmp/ipython-input-1526393695.py in run_checkov(file_path, timeout)
#      33     try:
#      34         cmd = ["checkov", "-f", file_path, "-o", "json"]
# ---> 35         out = subprocess.run(cmd, capture_output=True, text=True, timeout=timeout)
#      36         if out.returncode == 0 and out.stdout.strip():
#      37             return json.loads(out.stdout)
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
import os
for root, _, files in os.walk("iac_subset"):
    for f in files[:10]:  # show 10 examples
        print(os.path.join(root, f))
# Out:
# Streaming output truncated to the last 5000 lines.
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-console-slack-notification/main.go
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-console-slack-notification/go.sum
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-console-slack-notification/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-console-slack-notification/handler/handler.go
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/echoserver.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/utils.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/iam.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/nginx.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/nginx-ing-cntlr-rbac.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/scripts/delete-t3.2xlarge-nodes.sh
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/scripts/load-testing.sh
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-eks-migrate-nodegroups/scripts/drain-t3.2xlarge-nodes.sh
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-py-webserver/requirements.txt
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-py-webserver/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-py-webserver/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-py-webserver/__main__.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-ec2-provisioners/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-ec2-provisioners/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-ec2-provisioners/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-ec2-provisioners/util.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-ec2-provisioners/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-ec2-provisioners/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-ec2-provisioners/myapp.conf
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-ec2-provisioners/provisioners/provisioner.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-ec2-provisioners/provisioners/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-stream-analytics/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-stream-analytics/token.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-stream-analytics/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-stream-analytics/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-stream-analytics/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-stream-analytics/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-vm-scaleset/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-vm-scaleset/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-vm-scaleset/Program.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-vm-scaleset/Azure.VmScaleset.csproj
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-vm-scaleset/VmScalesetStack.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-vm-scaleset/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-static-website/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-static-website/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-static-website/Program.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-static-website/Azure.StaticWebsite.csproj
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-static-website/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-static-website/StaticWebsite.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-static-website/wwwroot/404.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-static-website/wwwroot/index.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/kubernetes-ts-sock-shop/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/kubernetes-ts-sock-shop/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/kubernetes-ts-sock-shop/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/kubernetes-ts-sock-shop/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/kubernetes-ts-sock-shop/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-aks/AksStack.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-aks/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-aks/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-aks/Program.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-aks/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-aks/Azure.Aks.csproj
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/vms.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/functionApp.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/aci.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/unittests.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/cosmosApp.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/images/globalapp.png
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/vm/vmCustomData.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/policy/azureRegions.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/policy/distance.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/policy/PulumiPolicy.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/policy/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/policy/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/policy/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/container/.dockerignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/container/Dockerfile
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/container/app/index.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/container/app/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-cosmosapp-component/container/app/index.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-serverless-raw/requirements.txt
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-serverless-raw/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-serverless-raw/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-serverless-raw/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-serverless-raw/__main__.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-serverless-raw/pythonfunc/main.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-serverless-raw/gofunc/function.go
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/twilio-ts-component/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/twilio-ts-component/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/twilio-ts-component/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/twilio-ts-component/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/twilio-ts-component/twilio.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/twilio-ts-component/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/azure-pipelines.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/alternative-pipeline/azure-pipelines.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/alternative-pipeline/scripts/setup.sh
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/alternative-pipeline/scripts/run-pulumi.sh
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/infra/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/infra/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/infra/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/infra/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Startup.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Program.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/DotNetCoreSqlDb.csproj
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/appsettings.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Properties/launchSettings.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Data/MyDatabaseContext.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Migrations/MyDatabaseContextModelSnapshot.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Migrations/20170901142627_Initial.Designer.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Migrations/20170901142627_Initial.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Controllers/HomeController.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Controllers/TodoesController.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/wwwroot/favicon.ico
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/wwwroot/images/banner2.svg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/wwwroot/images/banner3.svg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/wwwroot/images/banner4.svg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/wwwroot/images/banner1.svg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/wwwroot/css/site.css
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/wwwroot/css/site.min.css
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/wwwroot/js/site.min.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/wwwroot/js/site.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Models/Todo.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/_ViewImports.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/_ViewStart.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Todos/Index.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Todos/Edit.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Todos/Create.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Todos/Details.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Todos/Delete.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Shared/Error.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Shared/_Layout.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Shared/_ValidationScriptsPartial.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Home/About.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Home/Index.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-appservice-devops/src/Views/Home/Contact.cshtml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder/go.mod
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder/main.go
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder/go.sum
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder/images/part2-website.png
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder/www/index.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder/www/favicon.png
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-aks-multicluster/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-aks-multicluster/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-aks-multicluster/config.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-aks-multicluster/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-aks-multicluster/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-aks-multicluster/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-aks-multicluster/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-cs-webserver/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-cs-webserver/WebServerStack.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-cs-webserver/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-cs-webserver/Program.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-cs-webserver/Aws.WebServer.csproj
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-cs-webserver/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/voting-app-webpage.png
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/frontend/Dockerfile
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/frontend/LICENSE
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/frontend/app/main.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/frontend/app/config_file.cfg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/frontend/app/templates/index.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/cloud-ts-voting-app/frontend/app/static/default.css
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-static-website/requirements.txt
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-static-website/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-static-website/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-static-website/__main__.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-static-website/www/404.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-static-website/www/index.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/.github/workflows/deployCMS.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/Readme-Screenshots/entery_page.jpg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/Readme-Screenshots/Editorial_Workflow.jpg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/Readme-Screenshots/cms-config-setings.jpg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/Readme-Screenshots/login.jpg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/Readme-Screenshots/publish_change.jpg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/Readme-Screenshots/collection_page.jpg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/Readme-Screenshots/Workflow_button.jpg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/infrastructure/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/infrastructure/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/infrastructure/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/infrastructure/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/infrastructure/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/public/manifest.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/public/index.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/public/config.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/public/favicon.ico
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/src/index.css
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/src/logo.svg
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/src/App.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/src/index.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/src/App.test.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/src/components/NetlifyCMS/index.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/src/components/NetlifyCMS/setup.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms/src/components/NetlifyCMS/components/previewStyles.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/Makefile
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/go.mod
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/main.go
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/go.sum
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/Dockerfile
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/.github/workflows/build-and-deploy.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/infrastructure/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/infrastructure/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/infrastructure/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/infrastructure/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-netlify-cms-and-oauth/cms-oauth/infrastructure/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-webserver/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-webserver/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-webserver/go.mod
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-webserver/main.go
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-webserver/go.sum
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-webserver/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-py-aci/requirements.txt
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-py-aci/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-py-aci/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-py-aci/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-py-aci/__main__.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-network-component/requirements.txt
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-network-component/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-network-component/instance.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-network-component/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-network-component/network.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-network-component/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-network-component/__main__.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-py-network-component/config.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/s3folder.go
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/go.mod
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/main.go
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/go.sum
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/images/part2-website.png
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/www/index.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-go-s3-folder-component/www/favicon.png
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/cache.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/config.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/www/bootstrap.min.css
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/www/index.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-ts-url-shortener-cache-http/www/favicon.png
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-serverless-raw/requirements.txt
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-serverless-raw/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-serverless-raw/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-serverless-raw/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-serverless-raw/__main__.py
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-serverless-raw/app/Functions.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/aws-py-serverless-raw/app/app.csproj
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-cs-credential-rotation-one-set/AppStack.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-cs-credential-rotation-one-set/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-cs-credential-rotation-one-set/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-cs-credential-rotation-one-set/Program.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-cs-credential-rotation-one-set/Azure.CredentialRotation.OneSet.csproj
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-nextgen-cs-credential-rotation-one-set/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/digitalocean-ts-k8s/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/digitalocean-ts-k8s/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/digitalocean-ts-k8s/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/digitalocean-ts-k8s/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/digitalocean-ts-k8s/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/digitalocean-ts-k8s/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-vm-scaleset/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-vm-scaleset/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-vm-scaleset/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-ts-vm-scaleset/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/tests/PulumiPolicy.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/tests/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/tests/index.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/testing-pac-ts/tests/tsconfig.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/AppStack.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/Azure.KeyVault.csproj
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/Program.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/webapp/Startup.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/webapp/Reader.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/webapp/Program.cs
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/azure-cs-msi-keyvault-rbac/webapp/webapp.csproj
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/Gemfile
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/Gemfile.lock
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/.ruby-version
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/start
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config.ru
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/package.json
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/README.md
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/Rakefile
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/Dockerfile
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/helpers/application_helper.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/helpers/todo_lists_helper.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/controllers/application_controller.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/controllers/todo_lists_controller.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/controllers/concerns/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/models/application_record.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/models/todo_list.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/models/concerns/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/jobs/application_job.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/todo_lists/_form.html.erb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/todo_lists/show.html.erb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/todo_lists/_todo_list.json.jbuilder
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/todo_lists/new.html.erb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/todo_lists/edit.html.erb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/todo_lists/index.json.jbuilder
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/todo_lists/index.html.erb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/todo_lists/show.json.jbuilder
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/layouts/mailer.text.erb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/layouts/mailer.html.erb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/views/layouts/application.html.erb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/channels/application_cable/connection.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/channels/application_cable/channel.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/mailers/application_mailer.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/assets/images/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/assets/config/manifest.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/assets/javascripts/cable.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/assets/javascripts/application.js
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/assets/javascripts/todo_lists.coffee
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/assets/javascripts/channels/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/assets/stylesheets/todo_lists.scss
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/assets/stylesheets/application.css
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/app/assets/stylesheets/scaffolds.scss
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/storage/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/log/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/application.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/storage.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/routes.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/environment.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/database.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/puma.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/boot.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/spring.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/cable.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/credentials.yml.enc
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/locales/en.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/environments/production.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/environments/development.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/environments/test.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/initializers/assets.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/initializers/mime_types.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/initializers/wrap_parameters.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/initializers/application_controller_renderer.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/initializers/cookies_serializer.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/initializers/inflections.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/initializers/filter_parameter_logging.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/initializers/backtrace_silencers.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/config/initializers/content_security_policy.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/db/seeds.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/db/migrate/20181010202843_create_todo_lists.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/application_system_test_case.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/test_helper.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/helpers/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/controllers/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/controllers/todo_lists_controller_test.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/integration/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/models/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/models/todo_list_test.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/fixtures/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/fixtures/todo_lists.yml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/fixtures/files/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/system/todo_lists_test.rb
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/system/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/test/mailers/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/public/apple-touch-icon.png
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/public/500.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/public/404.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/public/robots.txt
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/public/apple-touch-icon-precomposed.png
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/public/favicon.ico
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/public/422.html
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/app/tmp/.keep
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/scripts/setup.sh
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/scripts/migrate.sh
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/infra/.gitignore
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/infra/Pulumi.yaml
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/infra/config.ts
# iac_subset/ServiTrace_ReplicationPackage/applications/pulumi-examples/gcp-ts-k8s-ruby-on-rails-postgresql/infra/cluster.ts
# ...
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/stylesheets/openprops-ui.css
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/stylesheets/admin.css
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/stylesheets/header.css
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/help/slack-login.md
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/help/change-email.md
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/help/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/hackers/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/layouts/application.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/feedback/2024.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/feedback/2024.md
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/registrace/volunteer-greeting.md
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/registrace/hacker-greeting.md
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/registrace/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/registrace/potvrzeno/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/admin/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/admin/transfer.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/admin/invoice.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/admin/volunteers/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/admin/dashboard/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/ubytovani/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/ubytovani/ulozeno/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/shared/rollbar.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/shared/logo.html
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/shared/hacker.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/shared/styles.html
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/shared/app-icons.html
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/shared/fonts.html
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/macros/helpers.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/html/program/index.njk
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/cloudflare/_headers
# iac_subset/hackercampcz_core/donut.hackercamp.cz/src/cloudflare/_redirects
# iac_subset/hackercampcz_core/api.hackercamp.cz/.gitignore
# iac_subset/hackercampcz_core/api.hackercamp.cz/package.json
# iac_subset/hackercampcz_core/api.hackercamp.cz/index.ts
# iac_subset/hackercampcz_core/api.hackercamp.cz/README.md
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/env.d.ts
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/_middleware.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/tsconfig.json
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v1/_middleware.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/lib/gauth.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/lib/auth.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/lib/middleware.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/_middleware.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/auth/sign-out.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/admin/dashboard.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/admin/volunteers.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/admin/_middleware.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/fakturoid/invoice.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/fakturoid/_middleware.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/fakturoid/subject.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/nfctron/[chipID].js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/nfctron/index.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/functions/v2/program/calendar.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/public/_headers
# iac_subset/hackercampcz_core/api.hackercamp.cz/public/index.html
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/tsconfig.json
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/slack.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/auth.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/http.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/algolia.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/postmark.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/ares.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/attendees.js
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/rollbar.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/postmark/webhook.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/slack/webhook.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/auth/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/auth/sign-out.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/dynamodb/postmark/subscription-change.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/dynamodb/registrations/paid.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/dynamodb/registrations/search-index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/dynamodb/attendees/search-index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/dynamodb/attendees/checkin.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/dynamodb/contacts/image-changed.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/authorization.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/csv.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/registrations/post.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/registrations/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/registrations/get.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/attendees/post.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/attendees/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/attendees/get.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/housing/post.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/housing/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/admin/housing/get.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/optout/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/attendees/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/fakturoid/webhook.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/registration/post.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/registration/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/registration/get.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/sqs/slack/handler.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/sqs/nfctron/handler.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/contacts/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/housing/post.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/housing/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/housing/get.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/program/post.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/program/index.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/program/get.mjs
# iac_subset/hackercampcz_core/api.hackercamp.cz/src/lambda/ares/index.mjs
# iac_subset/EvanBoyle_pupiter/Makefile
# iac_subset/EvanBoyle_pupiter/go.mod
# iac_subset/EvanBoyle_pupiter/go.sum
# iac_subset/EvanBoyle_pupiter/README.md
# iac_subset/EvanBoyle_pupiter/pkged.go
# iac_subset/EvanBoyle_pupiter/server/main.go
# iac_subset/EvanBoyle_pupiter/repl/repl.go
# iac_subset/EvanBoyle_pupiter/eval/eval.go
# iac_subset/EvanBoyle_pupiter/eval/eval_test.go
# iac_subset/EvanBoyle_pupiter/cmd/pupiter/pupiter.go
# iac_subset/EvanBoyle_pupiter/cmd/pupiter/main.go
# iac_subset/EvanBoyle_pupiter/cmd/pupiter/notebook.go
# iac_subset/EvanBoyle_pupiter/cmd/pupiter/pkged.go
# iac_subset/EvanBoyle_pupiter/write/write.go
# iac_subset/EvanBoyle_pupiter/session/session.go
# iac_subset/EvanBoyle_pupiter/exec/exec.go
# iac_subset/EvanBoyle_pupiter/notebook/.gitignore
# iac_subset/EvanBoyle_pupiter/notebook/yarn.lock
# iac_subset/EvanBoyle_pupiter/notebook/package.json
# iac_subset/EvanBoyle_pupiter/notebook/README.md
# iac_subset/EvanBoyle_pupiter/notebook/tsconfig.json
# iac_subset/EvanBoyle_pupiter/notebook/public/logo192.png
# iac_subset/EvanBoyle_pupiter/notebook/public/manifest.json
# iac_subset/EvanBoyle_pupiter/notebook/public/robots.txt
# iac_subset/EvanBoyle_pupiter/notebook/public/index.html
# iac_subset/EvanBoyle_pupiter/notebook/public/favicon.ico
# iac_subset/EvanBoyle_pupiter/notebook/public/logo512.png
# iac_subset/EvanBoyle_pupiter/notebook/src/index.css
# iac_subset/EvanBoyle_pupiter/notebook/src/App.test.tsx
# iac_subset/EvanBoyle_pupiter/notebook/src/index.tsx
# iac_subset/EvanBoyle_pupiter/notebook/src/logo.svg
# iac_subset/EvanBoyle_pupiter/notebook/src/App.css
# iac_subset/EvanBoyle_pupiter/notebook/src/serviceWorker.ts
# iac_subset/EvanBoyle_pupiter/notebook/src/setupTests.ts
# iac_subset/EvanBoyle_pupiter/notebook/src/App.tsx
# iac_subset/EvanBoyle_pupiter/notebook/src/react-app-env.d.ts
# iac_subset/EvanBoyle_pupiter/auto/up_test.go
# iac_subset/EvanBoyle_pupiter/auto/stack.go
# iac_subset/EvanBoyle_pupiter/auto/README.md
# iac_subset/EvanBoyle_pupiter/auto/up.go
# iac_subset/EvanBoyle_pupiter/auto/test/testproj/Pulumi.yaml
# iac_subset/EvanBoyle_pupiter/auto/test/testproj/go.mod
# iac_subset/EvanBoyle_pupiter/auto/test/testproj/main.go
# iac_subset/EvanBoyle_pupiter/auto/test/testproj/go.sum
# iac_subset/EvanBoyle_pupiter/auto/test/testproj/Pulumi.dev.yaml
# iac_subset/timmyers_nirvana/.gitignore
# iac_subset/timmyers_nirvana/Pulumi.yaml
# iac_subset/timmyers_nirvana/.python-version
# iac_subset/timmyers_nirvana/Jenkinsfile
# iac_subset/timmyers_nirvana/yarn.lock
# iac_subset/timmyers_nirvana/package.json
# iac_subset/timmyers_nirvana/.eslintrc.yml
# iac_subset/timmyers_nirvana/infrastructure.yml
# iac_subset/timmyers_nirvana/Pulumi.dev.yaml
# iac_subset/timmyers_nirvana/README.md
# iac_subset/timmyers_nirvana/.vscode/settings.json
# iac_subset/timmyers_nirvana/.circleci/config.yml
# iac_subset/timmyers_nirvana/src/read-yaml.d.ts
# iac_subset/timmyers_nirvana/src/index.ts
# iac_subset/timmyers_nirvana/src/gcp_dns_zone/index.ts
# iac_subset/timmyers_nirvana/src/identity/gcp/index.ts
# iac_subset/timmyers_nirvana/src/config/index.ts
# iac_subset/timmyers_nirvana/src/eks_cluster/iam.ts
# iac_subset/timmyers_nirvana/src/eks_cluster/index.ts
# iac_subset/timmyers_nirvana/src/eks_cluster/asg.ts
# iac_subset/timmyers_nirvana/src/eks_cluster/vpc.ts
# iac_subset/timmyers_nirvana/src/eks_cluster/eks.ts
# iac_subset/timmyers_nirvana/src/k8s_argo/index.ts
# iac_subset/timmyers_nirvana/src/k8s_argo/manifests/install.yml
# iac_subset/timmyers_nirvana/src/k8s_argo/manifests/cd.yml
# iac_subset/timmyers_nirvana/src/k8s_cluster/index.ts
# iac_subset/timmyers_nirvana/src/k8s_cluster/gcp/gke.ts
# iac_subset/timmyers_nirvana/src/k8s_cluster/gcp/index.ts
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_prometheus/index.ts
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_ingress_nginx/index.ts
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_opsview/index.ts
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_opsview/manifests/ingress.yml
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_opsview/manifests/auth.yml
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_opsview/manifests/deployment.yml
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_opsview/manifests/service.yml
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_cert_manager/letsencrypt-issuer.yml
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_cert_manager/index.ts
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_external_dns/external-dns.yml
# iac_subset/timmyers_nirvana/src/k8s_cluster/k8s_external_dns/index.ts
# iac_subset/timmyers_nirvana/src/name_com_nameservers/index.ts
# iac_subset/timmyers_nirvana/src/k8s_ingress/index.ts
# iac_subset/timmyers_nirvana/src/k8s_jenkins/index.ts
# iac_subset/takapi327_sample-cdktf/package-lock.json
# iac_subset/takapi327_sample-cdktf/help
# iac_subset/takapi327_sample-cdktf/main.ts
# iac_subset/takapi327_sample-cdktf/.gitignore
# iac_subset/takapi327_sample-cdktf/package.json
# iac_subset/takapi327_sample-cdktf/README.md
# iac_subset/takapi327_sample-cdktf/cdktf.json
# iac_subset/takapi327_sample-cdktf/tsconfig.json
# iac_subset/takapi327_sample-cdktf/src/main/typescript/notification-to-Slack/package-lock.json
# iac_subset/takapi327_sample-cdktf/src/main/typescript/notification-to-Slack/.gitignore
# iac_subset/takapi327_sample-cdktf/src/main/typescript/notification-to-Slack/build.sh
# iac_subset/takapi327_sample-cdktf/src/main/typescript/notification-to-Slack/yarn.lock
# iac_subset/takapi327_sample-cdktf/src/main/typescript/notification-to-Slack/package.json
# iac_subset/takapi327_sample-cdktf/src/main/typescript/notification-to-Slack/tsconfig.json
# iac_subset/takapi327_sample-cdktf/src/main/typescript/notification-to-Slack/src/index.ts
# iac_subset/DavidLeong98_pulumi/package-lock.json
# iac_subset/DavidLeong98_pulumi/.gitignore
# iac_subset/DavidLeong98_pulumi/test.js
# iac_subset/DavidLeong98_pulumi/Pulumi.yaml
# iac_subset/DavidLeong98_pulumi/index.js
# iac_subset/DavidLeong98_pulumi/package.json
# iac_subset/DavidLeong98_pulumi/Pulumi.dev.yaml
# iac_subset/DavidLeong98_pulumi/README.md
# iac_subset/DavidLeong98_pulumi/Dockerfile
# iac_subset/DavidLeong98_pulumi/.github/workflows/build.yml
# iac_subset/DavidLeong98_pulumi/.github/workflows/php.yml
# iac_subset/staeff_aws-infra/requirements.txt
# iac_subset/staeff_aws-infra/.gitignore
# iac_subset/staeff_aws-infra/Pulumi.yaml
# iac_subset/staeff_aws-infra/Pulumi.dev.yaml
# iac_subset/staeff_aws-infra/README.md
# iac_subset/staeff_aws-infra/__main__.py
# iac_subset/davetrainer_api-container-app/.gitignore
# iac_subset/davetrainer_api-container-app/.dockerignore
# iac_subset/davetrainer_api-container-app/README.md
# iac_subset/davetrainer_api-container-app/Api.Container.App.sln
# iac_subset/davetrainer_api-container-app/Dockerfile
# iac_subset/davetrainer_api-container-app/Api.Container.App.Api/appsettings.Development.json
# iac_subset/davetrainer_api-container-app/Api.Container.App.Api/Program.cs
# iac_subset/davetrainer_api-container-app/Api.Container.App.Api/Api.Container.App.Api.csproj
# iac_subset/davetrainer_api-container-app/Api.Container.App.Api/appsettings.json
# iac_subset/davetrainer_api-container-app/Api.Container.App.Api/Properties/launchSettings.json
# iac_subset/davetrainer_api-container-app/Api.Container.App.IAC/.gitignore
# iac_subset/davetrainer_api-container-app/Api.Container.App.IAC/Pulumi.yaml
# iac_subset/davetrainer_api-container-app/Api.Container.App.IAC/Program.cs
# iac_subset/davetrainer_api-container-app/Api.Container.App.IAC/Pulumi.dev.yaml
# iac_subset/davetrainer_api-container-app/Api.Container.App.IAC/Api.Container.App.IAC.csproj
# iac_subset/davetrainer_api-container-app/Api.Container.App.IAC/ApiStack.cs
# iac_subset/lhennerley_pulumi-brum-js/package-lock.json
# iac_subset/lhennerley_pulumi-brum-js/.gitignore
# iac_subset/lhennerley_pulumi-brum-js/Readme.md
# iac_subset/lhennerley_pulumi-brum-js/Pulumi.yaml
# iac_subset/lhennerley_pulumi-brum-js/Pulumi.local.yaml
# iac_subset/lhennerley_pulumi-brum-js/package.json
# iac_subset/lhennerley_pulumi-brum-js/index.ts
# iac_subset/lhennerley_pulumi-brum-js/Pulumi.dev.yaml
# iac_subset/lhennerley_pulumi-brum-js/tsconfig.json
# iac_subset/lhennerley_pulumi-brum-js/.github/workflows/pull_request.yml
# iac_subset/lhennerley_pulumi-brum-js/postgres/types.ts
# iac_subset/lhennerley_pulumi-brum-js/postgres/index.ts

# %%
import pandas as pd

df = pd.read_parquet("/content/drive/MyDrive/iac_files_full.parquet")
print("IaC dataset restored:", df.shape)
# Out:
# IaC dataset restored: (35278, 6)

# %%
import os

subset_dir = "iac_temp"
os.makedirs(subset_dir, exist_ok=True)

# Save 100 sample files for Checkov testing
for i, row in df.head(100).iterrows():
    fpath = os.path.join(subset_dir, f"{row['repo']}_{i}.{row['type']}")
    with open(fpath, "w") as f:
        f.write(row["full_content"])

# %%
import subprocess, json

def run_checkov(file_path):
    try:
        cmd = ["checkov", "-f", file_path, "-o", "json"]
        out = subprocess.run(cmd, capture_output=True, text=True, timeout=30)
        if out.returncode == 0 and out.stdout.strip():
            return json.loads(out.stdout)
    except Exception as e:
        print("⚠️", e)
    return None

# %%
import os

subset_dir = "iac_subset"   # or "iac_repos" if you kept all repos
iac_files = []

for root, _, files in os.walk(subset_dir):
    for f in files:
        if f.endswith((".tf", ".json", ".yml", ".yaml", ".bicep")):
            iac_files.append(os.path.join(root, f))

print("Found IaC files:", len(iac_files))
print("Examples:", iac_files[:5])
# Out:
# Found IaC files: 35966
# Examples: ['iac_subset/gobengo_activitypub.com/Pulumi.prod.yaml', 'iac_subset/gobengo_activitypub.com/package-lock.json', 'iac_subset/gobengo_activitypub.com/Pulumi.yaml', 'iac_subset/gobengo_activitypub.com/package.json', 'iac_subset/gobengo_activitypub.com/Pulumi.dev.yaml']

# %%
import subprocess, json

def run_checkov(file_path, timeout=60):
    """Run Checkov on a file and return JSON results if available."""
    try:
        cmd = ["checkov", "-f", file_path, "-o", "json"]
        out = subprocess.run(cmd, capture_output=True, text=True, timeout=timeout)
        if out.returncode == 0 and out.stdout.strip():
            return json.loads(out.stdout)
    except subprocess.TimeoutExpired:
        print(f"⏳ Timeout on {file_path}")
    except Exception as e:
        print(f"⚠️ Error on {file_path}: {e}")
    return None

# %%
import pandas as pd, os, subprocess, json
from tqdm import tqdm

# Load IaC files
subset_dir = "iac_subset"
iac_files = []
for root, _, files in os.walk(subset_dir):
    for f in files:
        if f.endswith((".tf", ".json", ".yml", ".yaml", ".bicep")):
            iac_files.append(os.path.join(root, f))

print("Total IaC files:", len(iac_files))

# Load already scanned
if os.path.exists("checkov_results_partial.csv"):
    scanned = pd.read_csv("checkov_results_partial.csv")["file"].unique().tolist()
else:
    scanned = []

pending_files = [f for f in iac_files if f not in scanned]
print("Pending files:", len(pending_files))


def run_checkov(file_path, timeout=60):
    try:
        cmd = ["checkov", "-f", file_path, "-o", "json"]
        out = subprocess.run(cmd, capture_output=True, text=True, timeout=timeout)
        if out.returncode == 0 and out.stdout.strip():
            return json.loads(out.stdout)
    except subprocess.TimeoutExpired:
        print(f"⏳ Timeout on {file_path}")
    except Exception as e:
        print(f"⚠️ Error on {file_path}: {e}")
    return None


# Batch size small for testing
batch_size = 100
results = []

for i in tqdm(range(0, len(pending_files), batch_size), desc="Batches"):
    batch = pending_files[i:i+batch_size]

    for file_path in batch:
        result = run_checkov(file_path, timeout=30)
        if result and "results" in result:
            for failed_check in result["results"].get("failed_checks", []):
                results.append({
                    "file": file_path,
                    "check_id": failed_check.get("check_id"),
                    "check_name": failed_check.get("check_name"),
                    "severity": failed_check.get("severity"),
                    "resource": failed_check.get("resource"),
                    "guideline": failed_check.get("guideline")
                })

    # Append results to file (instead of overwrite)
    df = pd.DataFrame(results)
    if os.path.exists("checkov_results_partial.csv"):
        df.to_csv("checkov_results_partial.csv", mode="a", header=False, index=False)
    else:
        df.to_csv("checkov_results_partial.csv", index=False)

    results = []  # clear memory
    break  # <-- REMOVE later; for now, process only 1 batch to test
# Out:
# Total IaC files: 35966
# Pending files: 35966
# Batches:   0%|          | 0/360 [01:44<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-892097159.py in <cell line: 0>()
#      43
#      44     for file_path in batch:
# ---> 45         result = run_checkov(file_path, timeout=30)
#      46         if result and "results" in result:
#      47             for failed_check in result["results"].get("failed_checks", []):
#
# /tmp/ipython-input-892097159.py in run_checkov(file_path, timeout)
#      25     try:
#      26         cmd = ["checkov", "-f", file_path, "-o", "json"]
# ---> 27         out = subprocess.run(cmd, capture_output=True, text=True, timeout=timeout)
#      28         if out.returncode == 0 and out.stdout.strip():
#      29             return json.loads(out.stdout)
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
import os, subprocess, json, pandas as pd
from tqdm import tqdm

subset_dir = "iac_subset"

# Collect IaC-like files
iac_files = []
for root, _, files in os.walk(subset_dir):
    for f in files:
        if f.endswith((".tf", ".json", ".yml", ".yaml", ".bicep")):
            iac_files.append(os.path.join(root, f))

print("Total IaC files:", len(iac_files))

# Load already scanned
if os.path.exists("checkov_results_partial.csv"):
    scanned = pd.read_csv("checkov_results_partial.csv")["file"].unique().tolist()
else:
    scanned = []

pending_files = [f for f in iac_files if f not in scanned]
print("Pending files:", len(pending_files))


def run_checkov(file_path, timeout=30):
    """Run Checkov on one file and return parsed results."""
    try:
        cmd = ["checkov", "-f", file_path, "-o", "json"]
        out = subprocess.run(cmd, capture_output=True, text=True, timeout=timeout)
        if out.returncode == 0 and out.stdout.strip():
            return json.loads(out.stdout)
    except subprocess.TimeoutExpired:
        print(f"⏳ Timeout on {file_path}")
    except Exception as e:
        print(f"⚠️ Error on {file_path}: {e}")
    return None


# Use batch size = 10
batch_size = 10
results = []

for i in tqdm(range(0, len(pending_files), batch_size), desc="Batches"):
    batch = pending_files[i:i+batch_size]

    for file_path in batch:
        result = run_checkov(file_path, timeout=30)
        if result and "results" in result:
            for failed_check in result["results"].get("failed_checks", []):
                results.append({
                    "file": file_path,
                    "check_id": failed_check.get("check_id"),
                    "check_name": failed_check.get("check_name"),
                    "severity": failed_check.get("severity"),
                    "resource": failed_check.get("resource"),
                    "guideline": failed_check.get("guideline")
                })

    # Save after each batch (resume safe)
    df = pd.DataFrame(results)
    if not df.empty:
        if os.path.exists("checkov_results_partial.csv"):
            df.to_csv("checkov_results_partial.csv", mode="a", header=False, index=False)
        else:
            df.to_csv("checkov_results_partial.csv", index=False)

    results = []  # free memory
    break  # <-- only run 1 batch for testing
# Out:
# Total IaC files: 35966
# Pending files: 35966
# Batches:   0%|          | 0/3597 [00:48<?, ?it/s]
